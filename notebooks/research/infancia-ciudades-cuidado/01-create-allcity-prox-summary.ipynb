# %% [markdown]
# # 01-create-allcity-prox-summary

# %% [markdown]
# This notebook analysis requested data on a proximity table in order to compare city to city data.
#
# The notebook has a function which takes in as arguments:
# - schema - (str) - Where data of interest is located
# - table - (str) - Where data of interest is located
# - city_list list - (list) - List of cities to query and analyse separately
# - prox_column - (str) -Used to create proximity categories (0a15, 15a30, 30a45, 45a60, másde60)
# - data_toagg - (str) - Data of interest to analyse by group and by proximity category
#
# And creates a summary of data_toagg data by prox_column categories city by city.

# %%
import os
import sys

import pandas as pd
import geopandas as gpd
import osmnx as ox
import numpy as np

from shapely import wkt

import matplotlib.pyplot as plt
import seaborn as sns

from pandas.api.types import CategoricalDtype

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

module_path = os.path.abspath(os.path.join('../../../'))
if module_path not in sys.path:
    sys.path.append(module_path)
    import aup
# Out:
# /usr/local/python/lib/python3.10/site-packages/osmnx/utils.py:192: UserWarning: The `utils.config` function is deprecated and will be removed in a future release. Instead, use the `settings` module directly to configure a global setting's value. For example, `ox.settings.log_console=True`.
#   warnings.warn(

# %%
def create_allcity_prox_summary(schema, table, city_list, prox_column, data_toagg):
    #schema - (str) - Where data of interest is located
    #table - (str) - Where data of interest is located
    #city_list list - (list) - List of cities to query and analyse separately
    #prox_column - (str) -Used to create proximity categories (0a15, 15a30, 30a45, 45a60, másde60)
    #data_toagg - (str) - Data of interest to analyse by group and by proximity category
                           
    # Data frame where summary data by city will be storaged
    data_output = pd.DataFrame()

    for city in city_list:

        print(f'STARTING ANALYSIS FOR {city}')

        #--------------- DOWNLOAD DATA ---------------
        # Load proximity hexres9 for group
        query = f"SELECT * FROM {schema}.{table} WHERE \"city\" LIKE \'{city}\'"
        prox_city = aup.gdf_from_query(query, geometry_col='geometry')

        #--------------- PROCESS DATA ---------------
        # Create time categories
        prox_city['prox_cat'] = np.nan
        prox_city.loc[prox_city[prox_column]>60 , 'prox_cat'] = '+60'
        prox_city.loc[(prox_city[prox_column]>45 )&
                     (prox_city[prox_column]<=60), 'prox_cat'] = '45a60'
        prox_city.loc[(prox_city[prox_column]>30)&
                     (prox_city[prox_column]<=45), 'prox_cat'] = '30a45'
        prox_city.loc[(prox_city[prox_column]>15)&
                     (prox_city[prox_column]<=30), 'prox_cat'] = '15a30'
        prox_city.loc[(prox_city[prox_column]<=15), 'prox_cat'] = '0a15'

        categories = ['0a15', '15a30', '30a45', '45a60', '+60']
        prox_city['prox_cat'] = pd.Categorical(prox_city['prox_cat'], categories=categories, ordered=True)

        # Group by data
        tot_data = prox_city[data_toagg].sum()
        print(f'Total {data_toagg} in {city}: {tot_data}.')
        city_data_summary = prox_city.groupby('prox_cat').agg({data_toagg:np.sum})

        # Format and create pop_data gdf
        city_data_summary.rename(columns={data_toagg:city},inplace=True)
        data_transposed = city_data_summary.transpose()
        data_transposed['city_total'] = data_transposed['0a15']+data_transposed['15a30']+data_transposed['30a45']+data_transposed['45a60']+data_transposed['+60']
        
        data_output = pd.concat([data_output,data_transposed])

    # Finally, add share to data
    for cat in categories:
        data_output[f'{cat}_share'] = data_output[cat] / data_output['city_total']

    print(f'ANALIZED DATA FOR {city}')
    
    return data_output

# %% [markdown]
# ### City data

# %%
#Load mun data
mun_schema = 'metropolis'
mun_table = 'metro_gdf'
query = f"SELECT * FROM {mun_schema}.{mun_table}" 
gdf_mun = aup.gdf_from_query(query, geometry_col='geometry')
city_list = gdf_mun.city.unique()

# %% [markdown]
# ### Create data summary by city and by proximity category for "pobtot" in "proximityanalysis_hexres9"

# %%
schema = 'prox_analysis'
table = 'proximityanalysis_hexres9'
prox_column = 'max_time'
data_toagg = 'pobtot'

pop_data_output = create_allcity_prox_summary(schema, table, city_list, prox_column, data_toagg)
# Out:
# STARTING ANALYSIS FOR Aguascalientes
# Total pobtot in Aguascalientes: 1043173.0.
# STARTING ANALYSIS FOR Ensenada
# Total pobtot in Ensenada: 396423.0.
# STARTING ANALYSIS FOR Mexicali
# Total pobtot in Mexicali: 956287.0.
# STARTING ANALYSIS FOR Tijuana
# Total pobtot in Tijuana: 2092757.0.
# STARTING ANALYSIS FOR La Paz
# Total pobtot in La Paz: 268798.0.
# STARTING ANALYSIS FOR Campeche
# Total pobtot in Campeche: 266692.0.
# STARTING ANALYSIS FOR Laguna
# Total pobtot in Laguna: 1253652.0.
# STARTING ANALYSIS FOR Monclova
# Total pobtot in Monclova: 366324.0.
# STARTING ANALYSIS FOR Piedras Negras
# Total pobtot in Piedras Negras: 205169.0.
# STARTING ANALYSIS FOR Saltillo
# Total pobtot in Saltillo: 995097.0.
# STARTING ANALYSIS FOR Colima
# Total pobtot in Colima: 348569.0.
# STARTING ANALYSIS FOR Tecoman
# Total pobtot in Tecoman: 129714.0.
# STARTING ANALYSIS FOR Tapachula
# Total pobtot in Tapachula: 251222.0.
# STARTING ANALYSIS FOR Tuxtla
# Total pobtot in Tuxtla: 728601.0.
# STARTING ANALYSIS FOR Chihuahua
# Total pobtot in Chihuahua: 967069.0.
# STARTING ANALYSIS FOR Delicias
# Total pobtot in Delicias: 173054.0.
# STARTING ANALYSIS FOR Juarez
# Total pobtot in Juarez: 1506714.0.
# STARTING ANALYSIS FOR Parral
# Total pobtot in Parral: 118232.0.
# STARTING ANALYSIS FOR ZMVM
# Total pobtot in ZMVM: 9126319.0.
# STARTING ANALYSIS FOR Durango
# Total pobtot in Durango: 619903.0.
# STARTING ANALYSIS FOR Celaya
# Total pobtot in Celaya: 616877.0.
# STARTING ANALYSIS FOR Guanajuato
# Total pobtot in Guanajuato: 149953.0.
# STARTING ANALYSIS FOR Leon
# Total pobtot in Leon: 1751796.0.
# STARTING ANALYSIS FOR Moroleon
# Total pobtot in Moroleon: 94014.0.
# STARTING ANALYSIS FOR San Francisco
# Total pobtot in San Francisco: 145995.0.
# STARTING ANALYSIS FOR Acapulco
# Total pobtot in Acapulco: 708312.0.
# STARTING ANALYSIS FOR Chilpancingo
# Total pobtot in Chilpancingo: 294269.0.
# STARTING ANALYSIS FOR Pachuca
# Total pobtot in Pachuca: 576918.0.
# STARTING ANALYSIS FOR Tula
# Total pobtot in Tula: 198024.0.
# STARTING ANALYSIS FOR Tulancingo
# Total pobtot in Tulancingo: 199209.0.
# STARTING ANALYSIS FOR Guadalajara
# Total pobtot in Guadalajara: 5116627.0.
# STARTING ANALYSIS FOR Ocotlan
# Total pobtot in Ocotlan: 155302.0.
# STARTING ANALYSIS FOR Vallarta
# Total pobtot in Vallarta: 444301.0.
# STARTING ANALYSIS FOR Tianguistenco
# Total pobtot in Tianguistenco: 130015.0.
# STARTING ANALYSIS FOR Toluca
# Total pobtot in Toluca: 1963730.0.
# STARTING ANALYSIS FOR Piedad
# Total pobtot in Piedad: 148699.0.
# STARTING ANALYSIS FOR Morelia
# Total pobtot in Morelia: 861490.0.
# STARTING ANALYSIS FOR Zamora
# Total pobtot in Zamora: 248898.0.
# STARTING ANALYSIS FOR Cuautla
# Total pobtot in Cuautla: 362064.0.
# STARTING ANALYSIS FOR Cuernavaca
# Total pobtot in Cuernavaca: 906582.0.
# STARTING ANALYSIS FOR Tepic
# Total pobtot in Tepic: 442881.0.
# STARTING ANALYSIS FOR Monterrey
# Total pobtot in Monterrey: 5249288.0.
# STARTING ANALYSIS FOR Oaxaca
# Total pobtot in Oaxaca: 644343.0.
# STARTING ANALYSIS FOR Tehuantepec
# Total pobtot in Tehuantepec: 149438.0.
# STARTING ANALYSIS FOR Puebla
# Total pobtot in Puebla: 2987486.0.
# STARTING ANALYSIS FOR Tehuacan
# Total pobtot in Tehuacan: 333208.0.
# STARTING ANALYSIS FOR Teziutlan
# Total pobtot in Teziutlan: 103968.0.
# STARTING ANALYSIS FOR Queretaro
# Total pobtot in Queretaro: 1414379.0.
# STARTING ANALYSIS FOR Cancun
# Total pobtot in Cancun: 914847.0.
# STARTING ANALYSIS FOR Chetumal
# Total pobtot in Chetumal: 184791.0.
# STARTING ANALYSIS FOR Rio Verde
# Total pobtot in Rio Verde: 91303.0.
# STARTING ANALYSIS FOR SLP
# Total pobtot in SLP: 1205006.0.
# STARTING ANALYSIS FOR Culiacan
# Total pobtot in Culiacan: 885183.0.
# STARTING ANALYSIS FOR Mazatlan
# Total pobtot in Mazatlan: 475565.0.
# STARTING ANALYSIS FOR Guaymas
# Total pobtot in Guaymas: 173852.0.
# STARTING ANALYSIS FOR Hermosillo
# Total pobtot in Hermosillo: 904486.0.
# STARTING ANALYSIS FOR Nogales
# Total pobtot in Nogales: 261006.0.
# STARTING ANALYSIS FOR Villahermosa
# Total pobtot in Villahermosa: 618271.0.
# STARTING ANALYSIS FOR Victoria
# Total pobtot in Victoria: 331953.0.
# STARTING ANALYSIS FOR Matamoros
# Total pobtot in Matamoros: 515566.0.
# STARTING ANALYSIS FOR Nuevo Laredo
# Total pobtot in Nuevo Laredo: 423385.0.
# STARTING ANALYSIS FOR Reynosa
# Total pobtot in Reynosa: 810143.0.
# STARTING ANALYSIS FOR Tampico
# Total pobtot in Tampico: 861288.0.
# STARTING ANALYSIS FOR Tlaxcala
# Total pobtot in Tlaxcala: 512356.0.
# STARTING ANALYSIS FOR Acayucan
# Total pobtot in Acayucan: 81939.0.
# STARTING ANALYSIS FOR Coatzacoalcos
# Total pobtot in Coatzacoalcos: 339772.0.
# STARTING ANALYSIS FOR Cordoba
# Total pobtot in Cordoba: 240547.0.
# STARTING ANALYSIS FOR Minatitlan
# Total pobtot in Minatitlan: 273088.0.
# STARTING ANALYSIS FOR Orizaba
# Total pobtot in Orizaba: 378957.0.
# STARTING ANALYSIS FOR Poza Rica
# Total pobtot in Poza Rica: 340284.0.
# STARTING ANALYSIS FOR Veracruz
# Total pobtot in Veracruz: 825694.0.
# STARTING ANALYSIS FOR Xalapa
# Total pobtot in Xalapa: 678137.0.
# STARTING ANALYSIS FOR Merida
# Total pobtot in Merida: 1235042.0.
# STARTING ANALYSIS FOR Zacatecas
# Total pobtot in Zacatecas: 369930.0.
# ANALIZED DATA FOR Zacatecas

# %%
# Show 
pop_data_output
# Out:
# prox_cat           0a15     15a30     30a45     45a60        +60  city_total  \
# Aguascalientes  36458.0  192168.0  182111.0  155767.0   476669.0   1043173.0
# Ensenada         2158.0   35086.0   61877.0   58841.0   238461.0    396423.0
# Mexicali        10184.0  199975.0  177178.0  110849.0   458101.0    956287.0
# Tijuana          4123.0  229374.0  425852.0  418870.0  1014538.0   2092757.0
# La Paz           5516.0   74032.0   52734.0   32835.0   103681.0    268798.0
# ...                 ...       ...       ...       ...        ...         ...
# Poza Rica       17790.0   89646.0   57100.0   43586.0   132162.0    340284.0
# Veracruz        43828.0  210241.0  161128.0   95158.0   315339.0    825694.0
# Xalapa          65232.0  205661.0  139924.0  117661.0   149659.0    678137.0
# Merida          49143.0  284660.0  237178.0  184244.0   479817.0   1235042.0
# Zacatecas       11030.0   99356.0   82710.0   39826.0   137008.0    369930.0
#
# prox_cat        0a15_share  15a30_share  30a45_share  45a60_share  +60_share
# Aguascalientes    0.034949     0.184215     0.174574     0.149320   0.456941
# Ensenada          0.005444     0.088506     0.156088     0.148430   0.601532
# Mexicali          0.010650     0.209116     0.185277     0.115916   0.479041
# Tijuana           0.001970     0.109604     0.203489     0.200152   0.484785
# La Paz            0.020521     0.275419     0.196184     0.122155   0.385721
# ...                    ...          ...          ...          ...        ...
# Poza Rica         0.052280     0.263445     0.167801     0.128087   0.388387
# Veracruz          0.053080     0.254623     0.195143     0.115246   0.381908
# Xalapa            0.096193     0.303274     0.206336     0.173506   0.220691
# Merida            0.039791     0.230486     0.192040     0.149180   0.388503
# Zacatecas         0.029816     0.268581     0.223583     0.107658   0.370362
#
# [74 rows x 11 columns]

# %%
pop_data_output.to_csv('../../../data/external/temporal_fromjupyter/poptot_proxhexres9.csv')

# %% [markdown]
# ### Create data summary by city and by proximity category for "pob_0a5" in "cdcuidadoras_popageb_2020_hex"

# %%
schema = 'prox_analysis'
table = 'cdcuidadoras_popageb_2020_hex'
prox_column = 'max_idx_15_min'
data_toagg = 'pob_0a5'

data_output = create_allcity_prox_summary(schema, table, city_list, prox_column, data_toagg)

# %%
data_output.to_csv('../../../data/external/temporal_fromjupyter/pob_0a5_cdcuidado.csv')

# %% [markdown]
# ### Create data summary by city and by proximity category for "pob_0a5" in "proximityanalysis_20_ageb_hex8"

# %%
schema = 'prox_analysis'
table = 'proximityanalysis_20_ageb_hex8'
prox_column = 'max_idx_15_min'
data_toagg = 'pob_0a5'

data_output = create_allcity_prox_summary(schema, table, city_list, prox_column, data_toagg)
# Out:
# STARTING ANALYSIS FOR Aguascalientes
# Total pob_0a5 in Aguascalientes: 104671.77065957601.
# STARTING ANALYSIS FOR Ensenada
# Total pob_0a5 in Ensenada: 34588.64926271.
# STARTING ANALYSIS FOR Mexicali
# Total pob_0a5 in Mexicali: 73747.36127354001.
# STARTING ANALYSIS FOR Tijuana
# Total pob_0a5 in Tijuana: 179720.14984799002.
# STARTING ANALYSIS FOR La Paz
# Total pob_0a5 in La Paz: 21486.807822659997.
# STARTING ANALYSIS FOR Campeche
# Total pob_0a5 in Campeche: 22970.59942866.
# STARTING ANALYSIS FOR Laguna
# Total pob_0a5 in Laguna: 128634.57215102.
# STARTING ANALYSIS FOR Monclova
# Total pob_0a5 in Monclova: 38671.71460819.
# STARTING ANALYSIS FOR Piedras Negras
# Total pob_0a5 in Piedras Negras: 22519.508575554.
# STARTING ANALYSIS FOR Saltillo
# Total pob_0a5 in Saltillo: 109871.00086377999.
# STARTING ANALYSIS FOR Colima
# Total pob_0a5 in Colima: 27783.00050781.
# STARTING ANALYSIS FOR Tecoman
# Total pob_0a5 in Tecoman: 12452.99987648.
# STARTING ANALYSIS FOR Tapachula
# Total pob_0a5 in Tapachula: 26002.3812481.
# STARTING ANALYSIS FOR Tuxtla
# Total pob_0a5 in Tuxtla: 72643.00017834001.
# STARTING ANALYSIS FOR Chihuahua
# Total pob_0a5 in Chihuahua: 84491.99911862501.
# STARTING ANALYSIS FOR Delicias
# Total pob_0a5 in Delicias: 16588.7369657.
# STARTING ANALYSIS FOR Juarez
# Total pob_0a5 in Juarez: 135606.805632943.
# STARTING ANALYSIS FOR Parral
# Total pob_0a5 in Parral: 11571.999945880001.
# STARTING ANALYSIS FOR ZMVM
# Total pob_0a5 in ZMVM: 1599960.0039387322.
# STARTING ANALYSIS FOR Durango
# Total pob_0a5 in Durango: 62057.99968376.
# STARTING ANALYSIS FOR Celaya
# Total pob_0a5 in Celaya: 59499.45724567.
# STARTING ANALYSIS FOR Guanajuato
# Total pob_0a5 in Guanajuato: 13715.00036806.
# STARTING ANALYSIS FOR Leon
# Total pob_0a5 in Leon: 180472.00052458.
# STARTING ANALYSIS FOR Moroleon
# Total pob_0a5 in Moroleon: 7372.763688.
# STARTING ANALYSIS FOR San Francisco
# Total pob_0a5 in San Francisco: 16255.355578309998.
# STARTING ANALYSIS FOR Acapulco
# Total pob_0a5 in Acapulco: 61534.639430731.
# STARTING ANALYSIS FOR Chilpancingo
# Total pob_0a5 in Chilpancingo: 31846.473307479995.
# STARTING ANALYSIS FOR Pachuca
# Total pob_0a5 in Pachuca: 42427.67570638.
# STARTING ANALYSIS FOR Tula
# Total pob_0a5 in Tula: 17660.29473115.
# STARTING ANALYSIS FOR Tulancingo
# Total pob_0a5 in Tulancingo: 18808.23894603.
# STARTING ANALYSIS FOR Guadalajara
# Total pob_0a5 in Guadalajara: 472382.537628875.
# STARTING ANALYSIS FOR Ocotlan
# Total pob_0a5 in Ocotlan: 17147.37762895.
# STARTING ANALYSIS FOR Vallarta
# Total pob_0a5 in Vallarta: 45838.57551562.
# STARTING ANALYSIS FOR Tianguistenco
# Total pob_0a5 in Tianguistenco: 13107.000013859999.
# STARTING ANALYSIS FOR Toluca
# Total pob_0a5 in Toluca: 170828.94775229.
# STARTING ANALYSIS FOR Piedad
# Total pob_0a5 in Piedad: 15722.999881949998.
# STARTING ANALYSIS FOR Morelia
# Total pob_0a5 in Morelia: 76497.00025533.
# STARTING ANALYSIS FOR Zamora
# Total pob_0a5 in Zamora: 26224.625734800004.
# STARTING ANALYSIS FOR Cuautla
# Total pob_0a5 in Cuautla: 31920.74422304.
# STARTING ANALYSIS FOR Cuernavaca
# Total pob_0a5 in Cuernavaca: 73689.74840893.
# STARTING ANALYSIS FOR Tepic
# Total pob_0a5 in Tepic: 39798.999847160005.
# STARTING ANALYSIS FOR Monterrey
# Total pob_0a5 in Monterrey: 501616.99932752.
# STARTING ANALYSIS FOR Oaxaca
# Total pob_0a5 in Oaxaca: 57019.99649227.
# STARTING ANALYSIS FOR Tehuantepec
# Total pob_0a5 in Tehuantepec: 13490.542453020002.
# STARTING ANALYSIS FOR Puebla
# Total pob_0a5 in Puebla: 277859.59587127995.
# STARTING ANALYSIS FOR Tehuacan
# Total pob_0a5 in Tehuacan: 34698.000125700004.
# STARTING ANALYSIS FOR Teziutlan
# Total pob_0a5 in Teziutlan: 10723.8570455.
# STARTING ANALYSIS FOR Queretaro
# Total pob_0a5 in Queretaro: 123990.44458504001.
# STARTING ANALYSIS FOR Cancun
# Total pob_0a5 in Cancun: 82156.84683675.
# STARTING ANALYSIS FOR Chetumal
# Total pob_0a5 in Chetumal: 15157.99983742.
# STARTING ANALYSIS FOR Rio Verde
# Total pob_0a5 in Rio Verde: 9405.000137399998.
# STARTING ANALYSIS FOR SLP
# Total pob_0a5 in SLP: 107811.00029274.
# STARTING ANALYSIS FOR Culiacan
# Total pob_0a5 in Culiacan: 82352.99925276.
# STARTING ANALYSIS FOR Mazatlan
# Total pob_0a5 in Mazatlan: 40310.77784323.
# STARTING ANALYSIS FOR Guaymas
# Total pob_0a5 in Guaymas: 15986.95463565.
# STARTING ANALYSIS FOR Hermosillo
# Total pob_0a5 in Hermosillo: 76744.376513932.
# STARTING ANALYSIS FOR Nogales
# Total pob_0a5 in Nogales: 49917.683552.
# STARTING ANALYSIS FOR Villahermosa
# Total pob_0a5 in Villahermosa: 49787.000006990005.
# STARTING ANALYSIS FOR Victoria
# Total pob_0a5 in Victoria: 29541.99983544.
# STARTING ANALYSIS FOR Matamoros
# Total pob_0a5 in Matamoros: 50151.09763863999.
# STARTING ANALYSIS FOR Nuevo Laredo
# Total pob_0a5 in Nuevo Laredo: 42344.61087745.
# STARTING ANALYSIS FOR Reynosa
# Total pob_0a5 in Reynosa: 81531.14555859001.
# STARTING ANALYSIS FOR Tampico
# Total pob_0a5 in Tampico: 71437.50489139001.
# STARTING ANALYSIS FOR Tlaxcala
# Total pob_0a5 in Tlaxcala: 44444.58180824.
# STARTING ANALYSIS FOR Acayucan
# Total pob_0a5 in Acayucan: 7277.00005467.
# STARTING ANALYSIS FOR Coatzacoalcos
# Total pob_0a5 in Coatzacoalcos: 28801.44416938.
# STARTING ANALYSIS FOR Cordoba
# Total pob_0a5 in Cordoba: 19568.09233885.
# STARTING ANALYSIS FOR Minatitlan
# Total pob_0a5 in Minatitlan: 22117.00006124.
# STARTING ANALYSIS FOR Orizaba
# Total pob_0a5 in Orizaba: 30681.109936009998.
# STARTING ANALYSIS FOR Poza Rica
# Total pob_0a5 in Poza Rica: 26170.00027397.
# STARTING ANALYSIS FOR Veracruz
# Total pob_0a5 in Veracruz: 56657.02673932.
# STARTING ANALYSIS FOR Xalapa
# Total pob_0a5 in Xalapa: 51162.00797967.
# STARTING ANALYSIS FOR Merida
# Total pob_0a5 in Merida: 100411.99978449.
# STARTING ANALYSIS FOR Zacatecas
# Total pob_0a5 in Zacatecas: 36587.000161905.
# ANALIZED DATA FOR Zacatecas

# %%
data_output
# Out:
# prox_cat               0a15         15a30         30a45         45a60  \
# Aguascalientes  3387.159325  12377.438723  15790.916205  16045.393512
# Ensenada         183.243556   3122.532691   3514.003269   4178.883347
# Mexicali        1012.849138  11457.798853   9870.211637   8001.072993
# Tijuana          316.639080  17952.745018  29164.751646  36697.110130
# La Paz           267.921962   4108.066981   4101.117234   3105.791244
# ...                     ...           ...           ...           ...
# Poza Rica       2166.541099   5324.822314   4988.821176   2774.663914
# Veracruz        2146.079927  12534.263383   9528.738755   6100.710935
# Xalapa          3121.855889  15214.627004  10423.603013   9474.798357
# Merida          2663.035614  16942.963388  16518.532190  15105.947139
# Zacatecas        687.768950   8225.027677   5941.369862   4879.606345
#
# prox_cat                 +60     city_total  0a15_share  15a30_share  \
# Aguascalientes  57070.862895  104671.770660    0.032360     0.118250
# Ensenada        23589.986400   34588.649263    0.005298     0.090276
# Mexicali        43405.428652   73747.361274    0.013734     0.155366
# Tijuana         95588.903974  179720.149848    0.001762     0.099893
# La Paz           9903.910401   21486.807823    0.012469     0.191190
# ...                      ...            ...         ...          ...
# Poza Rica       10915.151772   26170.000274    0.082787     0.203470
# Veracruz        26347.233740   56657.026739    0.037878     0.221231
# Xalapa          12927.123717   51162.007980    0.061019     0.297381
# Merida          49181.521453  100411.999784    0.026521     0.168734
# Zacatecas       16853.227329   36587.000162    0.018798     0.224807
#
# prox_cat        30a45_share  45a60_share  +60_share
# Aguascalientes     0.150861     0.153292   0.545236
# Ensenada           0.101594     0.120817   0.682015
# Mexicali           0.133838     0.108493   0.588569
# Tijuana            0.162279     0.204190   0.531876
# La Paz             0.190867     0.144544   0.460930
# ...                     ...          ...        ...
# Poza Rica          0.190631     0.106025   0.417086
# Veracruz           0.168183     0.107678   0.465030
# Xalapa             0.203737     0.185192   0.252670
# Merida             0.164508     0.150440   0.489797
# Zacatecas          0.162390     0.133370   0.460634
#
# [74 rows x 11 columns]

# %%
data_output.to_csv('../../../data/external/temporal_fromjupyter/pob_0a5_proxhexres8.csv')
