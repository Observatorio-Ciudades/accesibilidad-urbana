# %% [markdown]
# # 99a - Script 21 nodes output comparison

# %% [markdown]
# This notebook compares times by osmid for the original proxanalysis (2020) the Script 21 output for Aguascalientes.
#
# * First result was successful but not perfect. After analysing the small difference node by node, the result was successful. The difference is due to very very very (e-13) small decimals.
# * Also, there are differences in the amount of nodes. Tests indicate that aup.graph_from_hippo can still generate disconected networks.
# * * This could be easly solved by deleting rows that have nan values in all examined amenities.

# %% [markdown]
# ## Import libraries

# %%
import os
import sys

import pandas as pd
import geopandas as gpd
import osmnx as ox
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

module_path = os.path.abspath(os.path.join('../../../'))
if module_path not in sys.path:
    sys.path.append(module_path)
    import aup
# Out:
# /home/jovyan/accesibilidad-urbana/aup/data.py:25: UserWarning: The `utils.config` function is deprecated and will be removed in a future release. Instead, use the `settings` module directly to configure a global setting's value. For example, `ox.settings.log_console=True`.
#   ox.config(

# %% [markdown]
# ## Load data

# %% [markdown]
# ### Load data - Load original data (Already in database)

# %%
city = 'Aguascalientes'
schema = 'prox_analysis'
table = 'nodes_proximity_2020'
query = f"SELECT * FROM {schema}.{table} WHERE \"metropolis\" LIKE \'{city}\'"
nodes_gdf = aup.gdf_from_query(query, geometry_col='geometry')

# Show
print(nodes_gdf.shape)
nodes_gdf.head(1)
# Out:
# (2208953, 7)
#        osmid           x          y                     geometry       time  \
# 0  272921360 -102.295073  21.872876  POINT (-102.29507 21.87288)  12.607833
#
#             amenity      metropolis
# 0  sip_centro_admin  Aguascalientes

# %%
# Transform original nodes data (rows to columns)
nodes_analysis = nodes_gdf.drop_duplicates(subset='osmid', keep="last")[['osmid','geometry','metropolis']].copy()
for amenidad in list(nodes_gdf.amenity.unique()):
    nodes_tmp = nodes_gdf.loc[nodes_gdf.amenity == amenidad,['osmid','time']]
    nodes_tmp = nodes_tmp.rename(columns={'time':amenidad})

    if nodes_tmp[amenidad].mean() == 0:
        nodes_tmp[amenidad] = np.nan

    nodes_analysis = nodes_analysis.merge(nodes_tmp, on='osmid')

# Show
print(nodes_analysis.shape)
nodes_analysis.head(1)
# Out:
# (51371, 46)
#        osmid                     geometry      metropolis  sip_centro_admin  \
# 0  301187451  POINT (-102.25150 21.87168)  Aguascalientes          0.764097
#
#    sip_teatro  sip_cancha  sip_unidad_deportiva  sip_espacio_publico  \
# 0   54.641889  151.583113             55.092683             5.590739
#
#    sip_mercado  clues_primer_nivel  ...  denue_cines  denue_centro_cultural  \
# 0    27.916878            1.911369  ...    22.428319              11.485214
#
#    denue_parque_natural  denue_papelerias  denue_libros  \
# 0                   NaN          4.332055     49.528436
#
#    denue_revistas_periodicos  denue_ferreteria_tlapaleria  denue_art_limpieza  \
# 0                  15.744918                    12.132738            1.172275
#
#    denue_pintura  denue_peluqueria
# 0       5.034638          5.654589
#
# [1 rows x 46 columns]

# %%
# There are no parques naturales in Aguascalientes
nodes_analysis.denue_parque_natural.unique()
# Out:
# array([nan])

# %% [markdown]
# ## Load data - Load prox script 21 data (Aguascalientes, version 1)

# %%
# test
dir = "../../../data/processed/proximity_v2/test_ags_proxanalysis_scriptv1_nodes.gpkg"
nodes_test = gpd.read_file(dir)

# Show
print(nodes_test.shape)
nodes_test.head(1)
# Out:
# (51434, 34)
#        osmid  denue_preescolar  denue_primaria  denue_secundaria  \
# 0  272921360         10.770629        5.615674         11.812107
#
#    clues_primer_nivel  denue_guarderias  denue_dif  denue_supermercado  \
# 0            6.486561           5.09561   6.486561            3.592175
#
#    denue_abarrotes  denue_carnicerias  ...  denue_cafe  sip_cancha  \
# 0         1.673421           6.486561  ...     5.25473  156.885198
#
#    sip_unidad_deportiva  sip_espacio_publico  denue_parque_natural  \
# 0              28.44305             5.692959                  None
#
#    denue_cines  denue_museos           x          y  \
# 0    26.069111      7.589368 -102.295073  21.872876
#
#                       geometry
# 0  POINT (-102.29507 21.87288)
#
# [1 rows x 34 columns]

# %% [markdown]
# ## Compare data

# %%
# Create amenities list which will be compared
amenities_list = list(nodes_test.columns)
amenities_list.remove('osmid')
amenities_list.remove('x')
amenities_list.remove('y')
amenities_list.remove('geometry')
amenities_list
# Out:
# ['denue_preescolar',
#  'denue_primaria',
#  'denue_secundaria',
#  'clues_primer_nivel',
#  'denue_guarderias',
#  'denue_dif',
#  'denue_supermercado',
#  'denue_abarrotes',
#  'denue_carnicerias',
#  'sip_mercado',
#  'denue_peluqueria',
#  'denue_farmacias',
#  'denue_ferreteria_tlapaleria',
#  'denue_art_limpieza',
#  'denue_ropa',
#  'denue_calzado',
#  'denue_muebles',
#  'denue_lavanderia',
#  'denue_revistas_periodicos',
#  'denue_pintura',
#  'denue_restaurante_insitu',
#  'denue_restaurante_llevar',
#  'denue_bares',
#  'denue_cafe',
#  'sip_cancha',
#  'sip_unidad_deportiva',
#  'sip_espacio_publico',
#  'denue_parque_natural',
#  'denue_cines',
#  'denue_museos']

# %%
# Inner merge (to compare same osmids)
compare = nodes_analysis.merge(nodes_test,on='osmid',how='inner')

# Compare old and new amenities
compare_list = []
for amenity in amenities_list:

    old_amenity = f"{amenity}_x"
    new_amenity = f"{amenity}_y"
    compare[f"{amenity}_diff"] = compare[new_amenity] - compare[old_amenity]

    compare_list.append(f"{amenity}_diff")

# Save df with time differences only
compare_diff = compare[compare_list]

# Visualize sum of time differences
summary = pd.DataFrame()
i = 0
for compare_amenity in compare_list:

    diff_value = compare[compare_amenity].sum()
    summary.loc[i,'amenity'] = compare_amenity
    summary.loc[i,'diff'] = diff_value

    i = i+1

# Show
# denue_parque_natural_diff is 0 because there are no parques naturales in Aguascalientes
summary
# Out:
#                              amenity          diff
# 0              denue_preescolar_diff -7.665077e-12
# 1                denue_primaria_diff -1.437461e-12
# 2              denue_secundaria_diff  1.616421e-11
# 3            clues_primer_nivel_diff -6.788167e-12
# 4              denue_guarderias_diff -6.542461e-12
# 5                     denue_dif_diff -1.041363e-11
# 6            denue_supermercado_diff -2.764117e-11
# 7               denue_abarrotes_diff -8.497182e-12
# 8             denue_carnicerias_diff -2.564849e-11
# 9                   sip_mercado_diff -1.812901e-11
# 10             denue_peluqueria_diff  8.332432e-13
# 11              denue_farmacias_diff -2.549037e-12
# 12  denue_ferreteria_tlapaleria_diff -2.609614e-12
# 13           denue_art_limpieza_diff  3.890013e-13
# 14                   denue_ropa_diff  2.625580e-11
# 15                denue_calzado_diff  1.011891e-11
# 16                denue_muebles_diff -1.669026e-12
# 17             denue_lavanderia_diff -1.656483e-11
# 18    denue_revistas_periodicos_diff -4.396021e-11
# 19                denue_pintura_diff  7.225553e-12
# 20     denue_restaurante_insitu_diff -2.099952e-13
# 21     denue_restaurante_llevar_diff -5.350304e-13
# 22                  denue_bares_diff -4.303974e-12
# 23                   denue_cafe_diff  2.197499e-12
# 24                   sip_cancha_diff  2.122307e-10
# 25         sip_unidad_deportiva_diff -4.796397e-11
# 26          sip_espacio_publico_diff  6.279040e-12
# 27         denue_parque_natural_diff  0.000000e+00
# 28                  denue_cines_diff  3.818437e-11
# 29                 denue_museos_diff -3.297639e-11

# %% [markdown]
# ## Find difference in nodes time value

# %% [markdown]
# Successful: the difference in times is due to small decimals (e-13 mins at least) in each node.

# %%
# How much is the difference between old and new time by node?
differences_to_analyse = [1,0.000000000001,0.0000000000001,0.00000000000001,0.000000000000001]

nodes_diff_df = pd.DataFrame()

for time in differences_to_analyse:
    i = 0
    for diff_col in compare_list:
        nodes_diff_df.loc[i,'amenity'] = diff_col
        
        nodes_with_positive_diff = compare.loc[(compare[diff_col]>time)].shape[0]
        nodes_with_negative_diff = compare.loc[(compare[diff_col]<-time)].shape[0]

        nodes_diff_df.loc[i,f"{time}mins_diff"] = nodes_with_positive_diff
        nodes_diff_df.loc[i,f"{-time}mins_diff"] = nodes_with_negative_diff

        i = i+1

# There are 51,371 nodes
nodes_diff_df
# Out:
#                              amenity  1mins_diff  -1mins_diff  1e-12mins_diff  \
# 0              denue_preescolar_diff         0.0          0.0             0.0
# 1                denue_primaria_diff         0.0          0.0             0.0
# 2              denue_secundaria_diff         0.0          0.0             0.0
# 3            clues_primer_nivel_diff         0.0          0.0             0.0
# 4              denue_guarderias_diff         0.0          0.0             0.0
# 5                     denue_dif_diff         0.0          0.0             0.0
# 6            denue_supermercado_diff         0.0          0.0             0.0
# 7               denue_abarrotes_diff         0.0          0.0             0.0
# 8             denue_carnicerias_diff         0.0          0.0             0.0
# 9                   sip_mercado_diff         0.0          0.0             0.0
# 10             denue_peluqueria_diff         0.0          0.0             0.0
# 11              denue_farmacias_diff         0.0          0.0             0.0
# 12  denue_ferreteria_tlapaleria_diff         0.0          0.0             0.0
# 13           denue_art_limpieza_diff         0.0          0.0             0.0
# 14                   denue_ropa_diff         0.0          0.0             0.0
# 15                denue_calzado_diff         0.0          0.0             0.0
# 16                denue_muebles_diff         0.0          0.0             0.0
# 17             denue_lavanderia_diff         0.0          0.0             0.0
# 18    denue_revistas_periodicos_diff         0.0          0.0             0.0
# 19                denue_pintura_diff         0.0          0.0             0.0
# 20     denue_restaurante_insitu_diff         0.0          0.0             0.0
# 21     denue_restaurante_llevar_diff         0.0          0.0             0.0
# 22                  denue_bares_diff         0.0          0.0             0.0
# 23                   denue_cafe_diff         0.0          0.0             0.0
# 24                   sip_cancha_diff         0.0          0.0             0.0
# 25         sip_unidad_deportiva_diff         0.0          0.0             0.0
# 26          sip_espacio_publico_diff         0.0          0.0             0.0
# 27         denue_parque_natural_diff         0.0          0.0             0.0
# 28                  denue_cines_diff         0.0          0.0             0.0
# 29                 denue_museos_diff         0.0          0.0             0.0
#
#     -1e-12mins_diff  1e-13mins_diff  -1e-13mins_diff  1e-14mins_diff  \
# 0               0.0             0.0              0.0           262.0
# 1               0.0             0.0              0.0           373.0
# 2               0.0             0.0              0.0          1054.0
# 3               0.0             0.0              0.0           434.0
# 4               0.0             0.0              0.0           257.0
# 5               0.0             0.0              4.0           475.0
# 6               0.0             0.0              0.0           461.0
# 7               0.0             0.0              0.0           144.0
# 8               0.0             8.0              0.0           321.0
# 9               0.0             3.0             45.0          2245.0
# 10              0.0             1.0              0.0           114.0
# 11              0.0             0.0              0.0           163.0
# 12              0.0             0.0              0.0           133.0
# 13              0.0             1.0              0.0           399.0
# 14              0.0             1.0              0.0           921.0
# 15              0.0             0.0              0.0           662.0
# 16              0.0             0.0              0.0           721.0
# 17              0.0             5.0            100.0           342.0
# 18              0.0           173.0            192.0          2761.0
# 19              0.0             0.0              0.0           772.0
# 20              0.0             0.0              0.0           138.0
# 21              0.0             0.0              0.0           212.0
# 22              0.0             0.0              0.0           607.0
# 23              0.0             0.0              0.0           533.0
# 24              0.0             0.0              0.0         10290.0
# 25              0.0             0.0             18.0          2191.0
# 26              0.0             0.0              0.0           476.0
# 27              0.0             0.0              0.0             0.0
# 28              0.0             8.0              1.0          2884.0
# 29              0.0             0.0            168.0          4533.0
#
#     -1e-14mins_diff  1e-15mins_diff  -1e-15mins_diff
# 0             430.0          3397.0           3315.0
# 1             360.0          3937.0           4239.0
# 2             495.0          6649.0           4463.0
# 3             877.0          4070.0           4585.0
# 4             576.0          3856.0           4394.0
# 5             636.0          3910.0           4022.0
# 6            1517.0          4270.0           6266.0
# 7             370.0          1973.0           1814.0
# 8             837.0          2992.0           3935.0
# 9            2854.0          4850.0           7525.0
# 10             54.0          1922.0           1883.0
# 11            387.0          3190.0           3089.0
# 12            358.0          2902.0           2980.0
# 13            625.0          3878.0           3719.0
# 14            237.0          3322.0           2590.0
# 15            411.0          4431.0           3348.0
# 16            641.0          3258.0           3832.0
# 17            541.0          2637.0           3529.0
# 18           3494.0          6030.0           5906.0
# 19            461.0          4040.0           5502.0
# 20            138.0          1699.0           1901.0
# 21            234.0          2400.0           2661.0
# 22            593.0          4141.0           4648.0
# 23            383.0          3165.0           2776.0
# 24           1715.0         11462.0           2671.0
# 25           2684.0          3525.0           3942.0
# 26            167.0          4015.0           3728.0
# 27              0.0             0.0              0.0
# 28           1905.0          4175.0           3649.0
# 29           3743.0          7249.0           4441.0

# %% [markdown]
# ## Find difference in amount of nodes on both gdfs

# %% [markdown]
# * nodes_analysis (original, from db) has __51,371__ unique nodes for Aguascalientes
# * nodes_test (Script 21) has more, __51,434__ unique nodes.
# * Why?

# %%
# FIND NODES ON NODES ANALYSIS THAT ARE NOT IN NODES_TEST
# Find how osmids relate (through indicator)
missing_nodes_1 = nodes_analysis.merge(nodes_test, on='osmid', how='left', indicator=True)
# Select nodes which are in left_gdf only ('left_only')
missing_nodes_1 = missing_nodes_1.loc[missing_nodes_1['_merge']=='left_only']
missing_nodes_1 = missing_nodes_1.drop(columns=['_merge'])
missing_nodes_1
# Out:
# Empty DataFrame
# Columns: [osmid, geometry_x, metropolis, sip_centro_admin, sip_teatro, sip_cancha_x, sip_unidad_deportiva_x, sip_espacio_publico_x, sip_mercado_x, clues_primer_nivel_x, clues_segundo_nivel, clues_tercer_nivel, sigade_preescolar, sigade_primaria, sigade_secundaria, denue_preescolar_x, denue_primaria_x, denue_secundaria_x, denue_escuela_mixta, denue_casa_adultos_mayores, denue_guarderias_x, denue_dif_x, denue_biblioteca, denue_supermercado_x, denue_abarrotes_x, denue_carnicerias_x, denue_farmacias_x, denue_ropa_x, denue_calzado_x, denue_muebles_x, denue_lavanderia_x, denue_cafe_x, denue_restaurante_insitu_x, denue_restaurante_llevar_x, denue_bares_x, denue_museos_x, denue_cines_x, denue_centro_cultural, denue_parque_natural_x, denue_papelerias, denue_libros, denue_revistas_periodicos_x, denue_ferreteria_tlapaleria_x, denue_art_limpieza_x, denue_pintura_x, denue_peluqueria_x, denue_preescolar_y, denue_primaria_y, denue_secundaria_y, clues_primer_nivel_y, denue_guarderias_y, denue_dif_y, denue_supermercado_y, denue_abarrotes_y, denue_carnicerias_y, sip_mercado_y, denue_peluqueria_y, denue_farmacias_y, denue_ferreteria_tlapaleria_y, denue_art_limpieza_y, denue_ropa_y, denue_calzado_y, denue_muebles_y, denue_lavanderia_y, denue_revistas_periodicos_y, denue_pintura_y, denue_restaurante_insitu_y, denue_restaurante_llevar_y, denue_bares_y, denue_cafe_y, sip_cancha_y, sip_unidad_deportiva_y, sip_espacio_publico_y, denue_parque_natural_y, denue_cines_y, denue_museos_y, x, y, geometry_y]
# Index: []
#
# [0 rows x 79 columns]

# %%
# FIND NODES ON NODES_TEST ANALYSIS THAT ARE NOT IN NODES ANALYSIS
# Find how osmids relate (through indicator)
missing_nodes_2 = nodes_test.merge(nodes_analysis, on='osmid', how='left', indicator=True)
# Select nodes which are in left_gdf only ('left_only')
missing_nodes_2 = missing_nodes_2.loc[missing_nodes_2['_merge']=='left_only']
missing_nodes_2 = missing_nodes_2.drop(columns=['_merge'])

#Show
print(missing_nodes_2.shape)
missing_nodes_2.head(1)
# Out:
# (63, 79)
#            osmid  denue_preescolar_x  denue_primaria_x  denue_secundaria_x  \
# 5783  1103032963                 NaN               NaN                 NaN
#
#       clues_primer_nivel_x  denue_guarderias_x  denue_dif_x  \
# 5783                   NaN                 NaN          NaN
#
#       denue_supermercado_x  denue_abarrotes_x  denue_carnicerias_x  ...  \
# 5783                   NaN                NaN                  NaN  ...
#
#       denue_cines_y  denue_centro_cultural  denue_parque_natural_y  \
# 5783            NaN                    NaN                     NaN
#
#       denue_papelerias  denue_libros  denue_revistas_periodicos_y  \
# 5783               NaN           NaN                          NaN
#
#       denue_ferreteria_tlapaleria_y  denue_art_limpieza_y  denue_pintura_y  \
# 5783                            NaN                   NaN              NaN
#
#       denue_peluqueria_y
# 5783                 NaN
#
# [1 rows x 79 columns]

# %%
# Find those nodes in nodes_test
# Result: all 63 missing nodes appear to have NaN values only.
missing_nodes_lst = list(missing_nodes_2.osmid.unique())
look = nodes_test.loc[nodes_test.osmid.isin(missing_nodes_lst)].copy()

#Show
print(look.shape)
look.head(1)
# Out:
# (63, 34)
#            osmid  denue_preescolar  denue_primaria  denue_secundaria  \
# 5783  1103032963               NaN             NaN               NaN
#
#       clues_primer_nivel  denue_guarderias  denue_dif  denue_supermercado  \
# 5783                 NaN               NaN        NaN                 NaN
#
#       denue_abarrotes  denue_carnicerias  ...  denue_cafe  sip_cancha  \
# 5783              NaN                NaN  ...         NaN         NaN
#
#       sip_unidad_deportiva  sip_espacio_publico  denue_parque_natural  \
# 5783                   NaN                  NaN                  None
#
#       denue_cines  denue_museos          x          y  \
# 5783          NaN           NaN -102.33579  22.051572
#
#                          geometry
# 5783  POINT (-102.33579 22.05157)
#
# [1 rows x 34 columns]

# %%
# Find if all columns in nodes_test have exactly 63 nans (if true, find those nodes in GIS)
# Result: affirmative.
for amenity in amenities_list:
    nans = nodes_test.loc[nodes_test[amenity].isna()]
    print(f"{amenity} has {nans.shape[0]} nans.")
# Out:
# denue_preescolar has 63 nans.
# denue_primaria has 63 nans.
# denue_secundaria has 63 nans.
# clues_primer_nivel has 63 nans.
# denue_guarderias has 63 nans.
# denue_dif has 63 nans.
# denue_supermercado has 63 nans.
# denue_abarrotes has 63 nans.
# denue_carnicerias has 63 nans.
# sip_mercado has 63 nans.
# denue_peluqueria has 63 nans.
# denue_farmacias has 63 nans.
# denue_ferreteria_tlapaleria has 63 nans.
# denue_art_limpieza has 63 nans.
# denue_ropa has 63 nans.
# denue_calzado has 63 nans.
# denue_muebles has 63 nans.
# denue_lavanderia has 63 nans.
# denue_revistas_periodicos has 63 nans.
# denue_pintura has 63 nans.
# denue_restaurante_insitu has 63 nans.
# denue_restaurante_llevar has 63 nans.
# denue_bares has 63 nans.
# denue_cafe has 63 nans.
# sip_cancha has 63 nans.
# sip_unidad_deportiva has 63 nans.
# sip_espacio_publico has 63 nans.
# denue_parque_natural has 51434 nans.
# denue_cines has 63 nans.
# denue_museos has 63 nans.

# %%
# Analyse situation in QGIS
look.to_file("../../../data/external/temporal_fromjupyter/proximity_v2/ags_scriptv2_nan_nodes.gpkg", driver='GPKG')

# %% [markdown]
# ### Data to analyse nodes difference situation in QGIS

# %%
city = 'Aguascalientes'
metro_schema = 'metropolis'
metro_table = 'metro_gdf_2020'

# Download area of interest
query = f"SELECT * FROM {metro_schema}.{metro_table} WHERE \"city\" LIKE \'{city}\'"
mun_gdf = aup.gdf_from_query(query, geometry_col='geometry')
mun_gdf = mun_gdf.set_crs("EPSG:4326")
aoi = mun_gdf.dissolve()

# Download Network used to calculate nearest note to each poi
network_schema = 'osmnx'
edges_table = 'edges_speed'
nodes_table = 'nodes'
G, nodes, edges = aup.graph_from_hippo(aoi, schema=network_schema, edges_folder=edges_table, nodes_folder=nodes_table)

# %%
# Analyse situation in QGIS
nodes.to_file("../../../data/external/temporal_fromjupyter/proximity_v2/ags_nodes_2020.gpkg", driver='GPKG')
edges.to_file("../../../data/external/temporal_fromjupyter/proximity_v2/ags_edges_2020.gpkg", driver='GPKG')
