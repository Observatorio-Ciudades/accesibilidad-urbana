# %% [markdown]
# # Blocks 800

# %% [markdown]
# This notebook runs parts of Script 22 and function calculate_censo_nan_values() in order to print logs on the identification of blocks_800 AGEBs.
# Then one random AGEB containing blocks_800 is loaded to __confirm that blocks_800 are needed to fill the pop data of blocks when using data from AGEBs 2020__.

# %%
accesibilidad_urbana = '../../../'

import os
import sys

import pandas as pd
import geopandas as gpd
import osmnx as ox
import numpy as np

# Para obtener el punto central de una línea en los tests,
# Y para convertir MultiLineStrings a LineStrings.
from shapely.geometry import LineString, MultiLineString

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

module_path = os.path.abspath(os.path.join(accesibilidad_urbana))
if module_path not in sys.path:
    sys.path.append(module_path)
    import aup

# %% [markdown]
# ## Running Script 22 [up to calculate_censo_nan_values()] [up to where AGEBs and blocks 800 are identified]

# %%
def main(city,save=False,local_save=True):

	##########################################################################################
	# STEP 1: LOAD DATA
    aup.log("--"*30)
    aup.log("--- LOADING CITY POP DATA.")
    
    # 1.1 --------------- CREATE AREA OF INTEREST FOR CITY 
    city_gdf = metro_gdf.loc[metro_gdf.city == city]
    city_gdf = city_gdf.set_crs("EPSG:4326")
    aoi = city_gdf.dissolve()
    
    # 1.2 --------------- LOAD POP DATA (AGEBs and Blocks)
    aup.log("--- Loading blocks and AGEBs for area of interest.")
    pop_ageb_gdf = gpd.GeoDataFrame()
    pop_mza_gdf = gpd.GeoDataFrame()

    # Create a list with all unique cvegeo_mun ('CVE_ENT'+'CVE_MUN') of current city
    city_gdf['cvegeo_mun'] = city_gdf['CVE_ENT']+city_gdf['CVE_MUN']
    cvegeo_mun_lst = list(city_gdf.cvegeo_mun.unique())
    # To avoid error that happens when there's only one MUN in State: 
    # SQL e.g.: <<< SELECT * FROM censo.censo_inegi_{year[:2]}_mza WHERE ("entidad" = '02') AND "mun" IN ('001',) >>>
    # Duplicate mun inside tupple if there's only one MUN.
    if len(cvegeo_mun_lst) >= 2:
        cvegeo_mun_tpl = str(tuple(cvegeo_mun_lst))
    else:
        cvegeo_mun_lst.append(cvegeo_mun_lst[0])
        cvegeo_mun_tpl = str(tuple(cvegeo_mun_lst))

    # Load AGEBs and blocks
    query = f"SELECT * FROM censo.censo_inegi_{year[:2]}_ageb WHERE \"cvegeo_mun\" IN {cvegeo_mun_tpl}"
    pop_ageb_gdf = aup.gdf_from_query(query, geometry_col='geometry')
    query = f"SELECT * FROM censo.censo_inegi_{year[:2]}_ageb WHERE \"cvegeo_mun\" IN {cvegeo_mun_tpl}"
    pop_mza_gdf = aup.gdf_from_query(query, geometry_col='geometry')

    # Set CRS
    pop_ageb_gdf = pop_ageb_gdf.set_crs("EPSG:4326")
    pop_mza_gdf = pop_mza_gdf.set_crs("EPSG:4326")
    aup.log(f"--- Loaded AGEBs with total population {pop_ageb_gdf['pobtot'].sum()} for area of interest.")
    aup.log(f"--- Loaded blocks with total population {pop_mza_gdf['pobtot'].sum()} for area of interest.")
    
    ##########################################################################################
	# STEP 2: CALCULATE NaN VALUES for pop fields (most of them, check function) of gdf containing blocks.
    aup.log("--"*30)
    aup.log(f"--- CALCULATING NAN VALUES FOR POP FIELDS IN {city.upper()}.")
    
    # 2.1 --------------- CALCULATE_CENSO_NAN_VALUES FUNCTION
    pop_mza_gdf_calc = aup.calculate_censo_nan_values_v1(pop_ageb_gdf,pop_mza_gdf,year=year,extended_logs=False)

# %%
# ------------------------------ BASE DATA REQUIRED ------------------------------
# Cities
metro_schema = 'metropolis'
metro_table = 'metro_gdf_2020'
# Year of analysis
year = '2020' # '2010' or '2020'. ('2010' still WIP, not tested)
# List of skip cities (If failed / want to skip city)
skip_city_list = ['CDMX', 'ZMVM']
# Hexgrid res of output
res_list = [8,9,10] #Only 8,9,10 and 11 available, run 8 and 9 only for prox. analysis v2.

# Save output to database?
save = False
save_schema = 'censo'
nodes_save_table = f'pobcenso_inegi_{year[:2]}_mzaageb_node'
save_table = f'pobcenso_inegi_{year[:2]}_mzaageb_hex'

# Save outputs to local? (Make sure directory exists)
local_save = False
local_save_dir = f"../data/processed/pop_data/"

# Test - (If testing, Script runs res 8 for one city ONLY and saves it ONLY locally, adding the word 'test' at the beggining of the outputs.)
test = False
test_city = 'Aguascalientes'

# ------------------------------ SCRIPT ------------------------------
# If test,
if test:
    # Simplifies script parameters
    skip_city_list = []
    res_list = [8]
    save = False
    local_save = True
    # Only loads one city
    missing_cities_list = [test_city]
    i = 0
    k = len(missing_cities_list)
    city = test_city
    query = f"SELECT * FROM {metro_schema}.{metro_table} WHERE \"city\" LIKE \'{city}\'"
    metro_gdf = aup.gdf_from_query(query, geometry_col='geometry')
    metro_gdf = metro_gdf.set_crs("EPSG:4326")

    aup.log(f"Processing test for {missing_cities_list} at res {res_list}.")

# If not test, runs Mexico's cities
else:
    # Load cities (municipalities)
    query = f"SELECT * FROM {metro_schema}.{metro_table}"
    metro_gdf = aup.gdf_from_query(query, geometry_col='geometry')
    metro_gdf = metro_gdf.set_crs("EPSG:4326")
    # Create a city list
    city_list = list(metro_gdf.city.unique())
    k = len(city_list)
    aup.log(f'--- Loaded city list with {k} cities.')

    # Prevent cities being analyzed several times in case of a crash
    processed_city_list = []
    try:
        query = f"SELECT city FROM {save_schema}.{save_table}"
        cities_processed = aup.df_from_query(query)
        processed_city_list = list(cities_processed.city.unique())
    except:
        pass

    # LOG CODE - Print progress of script so far
    missing_cities_list = []
    for city in city_list:
        if city not in processed_city_list:
            missing_cities_list.append(city)
    i = len(processed_city_list)
    aup.log(f'--- Already processed ({i}/{k}) cities.')
    aup.log(f'--- Missing procesing for cities: {missing_cities_list}')

# Main function run
for city in missing_cities_list:
    if city not in skip_city_list:
        print("--"*30)
        i = i + 1
        if i > 35:
            print(f"--- Skipping city {i}/{k}: {city}")
        else:
            print(f"--- Starting city {i}/{k}: {city}")
            main(city, save, local_save)
# Out:
# ------------------------------------------------------------
# --- Starting city 1/71: Aguascalientes
# INSPECTING AGEBs.
# FOUND 13 blocks_800 in current municipalities.
# ADDED 12 blocks_800 for 12 AGEBs.
# Printing AGEBs with blocks_800 list:
# ['0100100013721', '0100100014113', '010010237458A', '0100102374594', '0100102933929', '0100103674607', '0100103674611', '0100104793933', '0100500010497', '0100500010656', '0101100110193', '0101100110206']
# REMOVED blocks_800 from 1 other AGEBs not available in pop_gdf_ageb.
# Printing AGEBs from blocks_800 that won't be used.
# 

# REMOVED blocks_800 from 1 other AGEBs not available in pop_gdf_ageb.
# Printing AGEBs from blocks_800 that won't be used.
# ['1610200900016']
# ------------------------------------------------------------
# --- Starting city 34/71: Cuautla
# INSPECTING AGEBs.
# FOUND 11 blocks_800 in current municipalities.
# ADDED 9 blocks_800 for 9 AGEBs.
# Printing AGEBs with blocks_800 list:
# ['1700400120382', '1700400230594', '1700400230607', '1700400270043', '1700400270058', '1700400270081', '1703000010217', '170300002001A', '1703000180221']
# REMOVED blocks_800 from 2 other AGEBs not available in pop_gdf_ageb.
# Printing AGEBs from blocks_800 that won't be used.
# ['1700400110166', '1703000400077']
# ------------------------------------------------------------
# --- Starting city 35/71: Cuernavaca
# INSPECTING AGEBs.
# FOUND 14 blocks_800 in current municipalities.
# ADDED 11 blocks_800 for 11 AGEBs.
# Printing AGEBs with blocks_800 list:
# ['1700800030610', '1700800030644', '170080004017A', '1701800010706', '1702000060136', '1702000060210', '1702800010666', '1702800030473', '1702900010305', '1703500010020', '1703400010057']
# REMOVED blocks_800 from 3 other AGEBs not available in pop_gdf_ageb.
# Printing AGEBs from blocks_800 that won't be used.
# ['1701100050457', '1702000850085', '1702000990085']
# ------------------------------------------------------------
# --- Skipping city 36/71: Tepic
# ------------------------------------------------------------
# --- Skipping city 37/71: Monterrey
# ------------------------------------------------------------
# --- Skipping city 38/71: Oaxaca
# ------------------------------------------------------------
# --- Skipping city 39/71: Puebla
# ------------------------------------------------------------
# --- Skipping city 40/71: San Martin
# ------------------------------------------------------------
# --- Skipping city 41/71: Tehuacan
# ------------------------------------------------------------
# --- Skipping city 42/71: Queretaro
# ------------------------------------------------------------
# --- Skipping city 43/71: Cancun
# ------------------------------------------------------------
# --- Skipping city 44/71: Chetumal
# ------------------------------------------------------------
# --- Skipping city 45/71: Playa
# ------------------------------------------------------------
# --- Skipping city 46/71: SLP
# ------------------------------------------------------------
# --- Skipping city 47/71: Culiacan
# ------------------------------------------------------------
# --- Skipping city 48/71: Los Mochis
# ------------------------------------------------------------
# --- Skipping city 49/71: Mazatlan
# ------------------------------------------------------------
# --- Skipping city 50/71: Guaymas
# ------------------------------------------------------------
# --- Skipping city 51/71: Ciudad Obregon
# ------------------------------------------------------------
# --- Skipping city 52/71: Hermosillo
# ------------------------------------------------------------
# --- Skipping city 53/71: Nogales
# ------------------------------------------------------------
# --- Skipping city 54/71: Villahermosa
# ------------------------------------------------------------
# --- Skipping city 55/71: Victoria
# ------------------------------------------------------------
# --- Skipping city 56/71: Matamoros
# ------------------------------------------------------------
# --- Skipping city 57/71: Nuevo Laredo
# ------------------------------------------------------------
# --- Skipping city 58/71: Reynosa
# ------------------------------------------------------------
# --- Skipping city 59/71: Tampico
# ------------------------------------------------------------
# --- Skipping city 60/71: Tlaxcala
# ------------------------------------------------------------
# --- Skipping city 61/71: Coatzacoalcos
# ------------------------------------------------------------
# --- Skipping city 62/71: Cordoba
# ------------------------------------------------------------
# --- Skipping city 63/71: Minatitlan
# ------------------------------------------------------------
# --- Skipping city 64/71: Orizaba
# ------------------------------------------------------------
# --- Skipping city 65/71: Poza Rica
# ------------------------------------------------------------
# --- Skipping city 66/71: Veracruz
# ------------------------------------------------------------
# --- Skipping city 67/71: Xalapa
# ------------------------------------------------------------
# --- Skipping city 68/71: Merida
# ------------------------------------------------------------
# --- Skipping city 69/71: Zacatecas

# %%
# ------------------------------ BASE DATA REQUIRED ------------------------------
# Cities
metro_schema = 'metropolis'
metro_table = 'metro_gdf_2020'
# Year of analysis
year = '2020' # '2010' or '2020'. ('2010' still WIP, not tested)
# List of skip cities (If failed / want to skip city)
skip_city_list = ['CDMX', 'ZMVM']
# Hexgrid res of output
res_list = [8,9,10] #Only 8,9,10 and 11 available, run 8 and 9 only for prox. analysis v2.

# Save output to database?
save = False
save_schema = 'censo'
nodes_save_table = f'pobcenso_inegi_{year[:2]}_mzaageb_node'
save_table = f'pobcenso_inegi_{year[:2]}_mzaageb_hex'

# Save outputs to local? (Make sure directory exists)
local_save = False
local_save_dir = f"../data/processed/pop_data/"

# Test - (If testing, Script runs res 8 for one city ONLY and saves it ONLY locally, adding the word 'test' at the beggining of the outputs.)
test = False
test_city = 'Aguascalientes'

# ------------------------------ SCRIPT ------------------------------
# If test,
if test:
    # Simplifies script parameters
    skip_city_list = []
    res_list = [8]
    save = False
    local_save = True
    # Only loads one city
    missing_cities_list = [test_city]
    i = 0
    k = len(missing_cities_list)
    city = test_city
    query = f"SELECT * FROM {metro_schema}.{metro_table} WHERE \"city\" LIKE \'{city}\'"
    metro_gdf = aup.gdf_from_query(query, geometry_col='geometry')
    metro_gdf = metro_gdf.set_crs("EPSG:4326")

    aup.log(f"Processing test for {missing_cities_list} at res {res_list}.")

# If not test, runs Mexico's cities
else:
    # Load cities (municipalities)
    query = f"SELECT * FROM {metro_schema}.{metro_table}"
    metro_gdf = aup.gdf_from_query(query, geometry_col='geometry')
    metro_gdf = metro_gdf.set_crs("EPSG:4326")
    # Create a city list
    city_list = list(metro_gdf.city.unique())
    k = len(city_list)
    aup.log(f'--- Loaded city list with {k} cities.')

    # Prevent cities being analyzed several times in case of a crash
    processed_city_list = []
    try:
        query = f"SELECT city FROM {save_schema}.{save_table}"
        cities_processed = aup.df_from_query(query)
        processed_city_list = list(cities_processed.city.unique())
    except:
        pass

    # LOG CODE - Print progress of script so far
    missing_cities_list = []
    for city in city_list:
        if city not in processed_city_list:
            missing_cities_list.append(city)
    i = len(processed_city_list)
    aup.log(f'--- Already processed ({i}/{k}) cities.')
    aup.log(f'--- Missing procesing for cities: {missing_cities_list}')

# Main function run
for city in missing_cities_list:
    if city not in skip_city_list:
        print("--"*40)
        i = i + 1
        if i < 35:
            print(f"--- Skipping city {i}/{k}: {city}")
        else:
            print(f"--- Starting city {i}/{k}: {city}")
            main(city, save, local_save)
# Out:
# --------------------------------------------------------------------------------
# --- Skipping city 1/71: Aguascalientes
# --------------------------------------------------------------------------------
# --- Skipping city 2/71: Ensenada
# --------------------------------------------------------------------------------
# --- Skipping city 3/71: Mexicali
# --------------------------------------------------------------------------------
# --- Skipping city 4/71: Tijuana
# --------------------------------------------------------------------------------
# --- Skipping city 5/71: La Paz
# --------------------------------------------------------------------------------
# --- Skipping city 6/71: Los Cabos
# --------------------------------------------------------------------------------
# --- Skipping city 7/71: Campeche
# --------------------------------------------------------------------------------
# --- Skipping city 8/71: Laguna
# --------------------------------------------------------------------------------
# --- Skipping city 9/71: Monclova
# --------------------------------------------------------------------------------
# --- Skipping city 10/71: Piedras Negras
# --------------------------------------------------------------------------------
# --- Skipping city 11/71: Saltillo
# --------------------------------------------------------------------------------
# --- Skipping city 12/71: Colima
# --------------------------------------------------------------------------------
# --- Skipping city 13/71: Tapachula
# --------------------------------------------------------------------------------
# --- Skipping city 14/71: Tuxtla
# --------------------------------------------------------------------------------
# --- Skipping city 15/71: Chihuahua
# --------------------------------------------------------------------------------
# --- Skipping city 16/71: Delicias
# --------------------------------------------------------------------------------
# --- Skipping city 17/71: Juarez
# --------------------------------------------------------------------------------
# --- Skipping city 18/71: Durango
# --------------------------------------------------------------------------------
# --- Skipping city 19/71: Celaya
# --------------------------------------------------------------------------------
# --- Skipping city 20/71: Guanajuato
# --------------------------------------------------------------------------------
# --- Skipping city 21/71: Leon
# --------------------------------------------------------------------------------
# --- Skipping city 22/71: Irapuato
# --------------------------------------------------------------------------------
# --- Skipping city 23/71: Acapulco
# --------------------------------------------------------------------------------
# --- Skipping city 24/71: Chilpancingo
# --------------------------------------------------------------------------------
# --- Skipping city 25/71: Pachuca
# --------------------------------------------------------------------------------
# --- Skipping city 26/71: Tulancingo
# --------------------------------------------------------------------------------
# --- Skipping city 27/71: Guadalajara
# --------------------------------------------------------------------------------
# --- Skipping city 28/71: Vallarta
# --------------------------------------------------------------------------------
# --- Skipping city 29/71: Piedad
# --------------------------------------------------------------------------------
# --- Skipping city 30/71: Toluca
# --------------------------------------------------------------------------------
# --- Skipping city 31/71: Morelia
# --------------------------------------------------------------------------------
# --- Skipping city 32/71: Zamora
# --------------------------------------------------------------------------------
# --- Skipping city 33/71: Uruapan
# --------------------------------------------------------------------------------
# --- Skipping city 34/71: Cuautla
# --------------------------------------------------------------------------------
# --- Starting city 35/71: Cuernavaca
# INSPECTING AGEBs.
# FOUND 14 blocks_800 in current municipalities.
# ADDED 11 blocks_800 for 11 AGEBs.
# Printing AGEBs with blocks_800 list:
# ['1700800030610', '1700800030644', '170080004017A', '1701800010706', '1702000060136', '1702000060210', '1702800010666', '1702800030473', '1702900010305', '1703500010020', '1703400010057']
# REMOVED blocks_800 from 3 other AGEBs not available in pop_gdf_ageb.
# Printing AGEBs from blocks_800 that won't be used.
# ['1701100050457', '1702000850085', '1702000990085']
# --------------------------------------------------------------------------------
# --- Starting city 36/71: Tepic
# INSPECTING AGEBs.
# FOUND 29 blocks_800 in current municipalities.
# ADDED 27 blocks_800 for 27 AGEBs.
# Printing AGEBs with blocks_800 list:
# ['1800800010244', '1800800150263', '1801700010046', '1801700011519', '1801700010807', '180170001092A', '1801700010934', '1801700011294', '1801700011542', '1801700011576', '1801700011627', '1801700011646', '1801700011650', '180170001167A', '1801700012004', '1801700012080', '1801700012324', '1801700012589', '1801700012606', '1801700012818', '1801701110084', '1801701110099', '1801701110116', '180170122085A', '1801701220879', '1801701221839', '1801701511792']
# REMOVED blocks_800 from 2 other AGEBs not available in pop_gdf_ageb.
# Printing AGEBs from blocks_800 that won't be used.
# ['1800800210028', '1801701100417']
# --------------------------------------------------------------------------------
# --- Starting city 37/71: Monterrey
# INSPECTING AGEBs.
# FOUND 40 blocks_800 in current municipalities.
# ADDED 40 blocks_800 for 40 AGEBs.
# Printing AGEBs with blocks_800 list:
# 
AGEBs.
# Printing AGEBs with blocks_800 list:
# ['2300800012398', '2300800012364', '230080308192A', '2300803082006']
# REMOVED blocks_800 from 0 other AGEBs not available in pop_gdf_ageb.
# Printing AGEBs from blocks_800 that won't be used.
# []
# --------------------------------------------------------------------------------
# --- Starting city 46/71: SLP
# INSPECTING AGEBs.
# FOUND 23 blocks_800 in current municipalities.
# ADDED 23 blocks_800 for 23 AGEBs.
# Printing AGEBs with blocks_800 list:
# ['2402800010115', '2402800010929', '2402800012785', '2402800014512', '2402800015421', '2402800015347', '2402800015506', '2402800015510', '2402800015525', '2402800015563', '2402800015614', '2402800015633', '2402802370647', '2402802370651', '2402802370666', '2402802370702', '2402802395205', '2402802395629', '2402802522751', '2402802522770', '2402802522766', '2402802642747', '2403500261599']
# REMOVED blocks_800 from 0 other AGEBs not available in pop_gdf_ageb.
# Printing AGEBs from blocks_800 that won't be used.
# []
# --------------------------------------------------------------------------------
# --- Starting city 47/71: Culiacan
# INSPECTING AGEBs.
# FOUND 44 blocks_800 in current municipalities.
# ADDED 44 blocks_800 for 44 AGEBs.
# Printing AGEBs with blocks_800 list:
# ['2500600018279', '2500600010822', '2500600014609', '2500600014651', '2500600015289', '2500600015664', '2500600016319', '2500600016569', '2500600017139', '250060001736A', '250060001743A', '250060001750A', '2500600017586', '250060001775A', '2500600017976', '2500600018014', '2500600018052', '2500600018071', '250060001818A', '2500600017872', '2500600018508', '2500600019370', '250060001946A', '2500600019525', '2500603122176', '2500603124543', '2500603125359', '2500603128673', '2500603412180', '2500603413193', '2500603414257', '2500603415397', '2500603416094', '2500603416215', '2500603416234', '2500604435768', '2500604435772', '2500605914191', '2500605914219', '2500605916111', '2500611943085', '250061194309A', '2500613460803', '2500613606732']
# REMOVED blocks_800 from 0 other AGEBs not available in pop_gdf_ageb.
# Printing AGEBs from blocks_800 that won't be used.
# []
# --------------------------------------------------------------------------------
# --- Starting city 48/71: Los Mochis
# INSPECTING AGEBs.
# FOUND 32 blocks_800 in current municipalities.
# ADDED 32 blocks_800 for 32 AGEBs.
# Printing AGEBs with blocks_800 list:
# ['2500100010012', '250010119295A', '2500100010440', '2500100010987', '250010001231A', '2500100013182', '250010001320A', '2500100013981', '2500100701218', '2500100701311', '2500100701326', '2500100702381', '2500100703411', '2500100832409', '2500100832413', '2500100833055', '2500101151650', '2500101154284', '2500101200489', '250010156217A', '2500101831684', '2500101831699', '2500102051631', '2500102271913', '2500102271330', '2500102401025', '2500103961665', '2500103961858', '2500103962678', '2500103964547', '2500108184301', '250010818466A']
# REMOVED blocks_800 from 0 other AGEBs not available in pop_gdf_ageb.
# Printing AGEBs from blocks_800 that won't be used.
# []
# --------------------------------------------------------------------------------
# --- Starting city 49/71: Mazatlan
# INSPECTING AGEBs.
# FOUND 21 blocks_800 in current municipalities.
# ADDED 20 blocks_800 for 20 AGEBs.
# Printing AGEBs with blocks_800 list:
# ['2501200011353', '2501200011565', '2501200012027', '2501200012192', '250120001303A', '2501200013114', '2501200013275', '250120001328A', '2501200013843', '2501200013754', '2501200013858', '2501200013881', '2501200013932', '250120001431A', '2501200014343', '250120304125A', '2501203041264', '2501203481283', '2501203481298', '2501203484324']
# REMOVED blocks_800 from 1 other AGEBs not available in pop_gdf_ageb.
# Printing AGEBs from blocks_800 that won't be used.
# ['2501201621211']
# --------------------------------------------------------------------------------
# --- Starting city 50/71: Guaymas
# INSPECTING AGEBs.
# FOUND 7 blocks_800 in current municipalities.
# ADDED 7 blocks_800 for 7 AGEBs.
# Printing AGEBs with blocks_800 list:
# ['2602900012067', '2602900012461', '2602900013154', '2602900013188', '2602900013258', '2602903252226', '2602903252230']
# REMOVED blocks_800 from 0 other AGEBs not available in pop_gdf_ageb.
# Printing AGEBs from blocks_800 that won't be used.
# []
# --------------------------------------------------------------------------------
# --- Starting city 51/71: Ciudad Obregon
# INSPECTING AGEBs.
# Found zero blocks_800 in current municipalities.
# --------------------------------------------------------------------------------
# --- Starting city 52/71: Hermosillo
# INSPECTING AGEBs.
# FOUND 8 blocks_800 in current municipalities.
# ADDED 8 blocks_800 for 8 AGEBs.
# Printing AGEBs with blocks_800 list:
# ['2603000010593', '2603000017001', '2603003431341', '2603000018866', '2603001370057', '2603003430860', '2603003431021', '2603005358851']
# REMOVED blocks_800 from 0 other AGEBs not available in pop_gdf_ageb.
# Printing AGEBs from blocks_800 that won't be used.
# []
# --------------------------------------------------------------------------------
# --- Starting city 53/71: Nogales
# INSPECTING AGEBs.
# FOUND 2 blocks_800 in current municipalities.
# ADDED 2 blocks_800 for 2 AGEBs.
# Printing AGEBs with blocks_800 list:
# ['2604300012511', '2604300012899']
# REMOVED blocks_800 from 0 other AGEBs not available in pop_gdf_ageb.
# Printing AGEBs from blocks_800 that won't be used.
# []
# --------------------------------------------------------------------------------
# --- Starting city 54/71: Villahermosa
# INSPECTING AGEBs.
# FOUND 57 blocks_800 in current municipalities.
# ADDED 37 blocks_800 for 37 AGEBs.
# Printing AGEBs with blocks_800 list:
# ['2700400011331', '2700400012575', '2700400341810', '2700400611717', '2700401231007', '2700401450969', '270040134183A', '2700401451420', '2700401462397', '2700401601844', '2700401661806', '2700401662306', '2700401662325', '2700401662518', '2700401700193', '2700401761986', '2700402062414', '2700402062429', '270040214201A', '2700402142024', '2700402142058', '2700402512132', '2700402512607', '2700402642486', '2700402642490', '2700403160066', '2700403170121', '2700401452113', '270130001014A', '2701300010313', '2701300130188', '2701300130296', '2701300170135', '2701300180455', '2701300630440', '2701300800120', '2701300800436']
# REMOVED blocks_800 from 20 other AGEBs not available in pop_gdf_ageb.
# Printing AGEBs from blocks_800 that won't be used.
# ['2700400190352', '2700400330386', '2700400350386', '2700400560437', '2700400590437', '2700400660390', '2700400671863', '2700400870386', '2700400920441', '2700400980386', '2700401110437', '2700401120437', '2700401200329', '2700401220386', '2700401290329', '2701300060084', '2701300240084', '2701300250084', '2701300270084', '2701300280050']
# --------------------------------------------------------------------------------
# --- Starting city 55/71: Victoria
# INSPECTING AGEBs.
# FOUND 6 blocks_800 in current municipalities.
# ADDED 6 blocks_800 for 6 AGEBs.
# Printing AGEBs with blocks_800 list:
# ['2804100011611', '2804100011880', '2804100012060', '2804100012130', '2804100012639', '2804100013139']
# REMOVED blocks_800 from 0 other AGEBs not available in pop_gdf_ageb.
# Printing AGEBs from blocks_800 that won't be used.
# []
# --------------------------------------------------------------------------------
# --- Starting city 56/71: Matamoros
# INSPECTING AGEBs.
# FOUND 1 blocks_800 in current municipalities.
# ADDED 1 blocks_800 for 1 AGEBs.
# Printing AGEBs with blocks_800 list:
# ['2802200011993']
# REMOVED blocks_800 from 0 other AGEBs not available in pop_gdf_ageb.
# Printing AGEBs from blocks_800 that won't be used.
# []
# --------------------------------------------------------------------------------
# --- Starting city 57/71: Nuevo Laredo
# INSPECTING AGEBs.
# FOUND 1 blocks_800 in current municipalities.
# ADDED 1 blocks_800 for 1 AGEBs.
# Printing AGEBs with blocks_800 list:
# ['2802700013426']
# REMOVED blocks_800 from 0 other AGEBs not available in pop_gdf_ageb.
# Printing AGEBs from blocks_800 that won't be used.
# []
# --------------------------------------------------------------------------------
# --- Starting city 58/71: Reynosa
# INSPECTING AGEBs.
# FOUND 5 blocks_800 in current municipalities.
# ADDED 5 blocks_800 for 5 AGEBs.
# Printing AGEBs with blocks_800 list:
# ['2803200010703', '2803300010414', '2803300011215', '2803300011605', '2803300011624']
# REMOVED blocks_800 from 0 other AGEBs not available in pop_gdf_ageb.
# Printing AGEBs from blocks_800 that won't be used.
# []
# --------------------------------------------------------------------------------
# --- Starting city 59/71: Tampico
# INSPECTING AGEBs.
# FOUND 15 blocks_800 in current municipalities.
# ADDED 15 blocks_800 for 15 AGEBs.
# Printing AGEBs with blocks_800 list:
# ['2800300011644', '2800300012286', '2800300012619', '2800300431112', '3012300010923', '3012300010957', '3012300010976', '3012300010980', '3012300011052', '3012300140834', '3012309040887', '301230014082A', '3013300020402', '3013300070559', '3013300120313']
# REMOVED blocks_800 from 0 other AGEBs not available in pop_gdf_ageb.
# Printing AGEBs from blocks_800 that won't be used.
# []
# --------------------------------------------------------------------------------
# --- Starting city 60/71: Tlaxcala
# INSPECTING AGEBs.
# FOUND 46 blocks_800 in current municipalities.
# ADDED 46 blocks_800 for 46 AGEBs.
# Printing AGEBs with blocks_800 list:
# ['290050001001A', '2900500100221', '2901000010151', '2901000010359', '2901500010181', '2901500010196', '2901500010209', '2901500010213', '2901500320270', '2901500220302', '2901500220317', '290150031029A', '290150032011A', '2901500320266', '2901500320389', '2901800010041', '2902400070104', '2902400110208', '2902600010062', '2902600040024', '2902600050166', '2903100100293', '2903100100310', '2903300110813', '2903400010280', '290340001051A', '2903400020346', '2903400020562', '2903400060420', '2903400060435', '290340006044A', '2903400590011', '290340059005A', '2903500010042', '2903500010057', '2903600010196', '2903600050020', '2903900010075', '290390003022A', '2903900060234', '2904900010029', '2904900010048', '2904900010067', '2905000010049', '2905600010023', '2905600010061']
# REMOVED blocks_800 from 0 other AGEBs not available in pop_gdf_ageb.
# Printing AGEBs from blocks_800 that won't be used.
# []
# --------------------------------------------------------------------------------
# --- Starting city 61/71: Coatzacoalcos
# INSPECTING AGEBs.
# FOUND 9 blocks_800 in current municipalities.
# ADDED 9 blocks_800 for 9 AGEBs.
# Printing AGEBs with blocks_800 list:
# ['
other AGEBs not available in pop_gdf_ageb.
# Printing AGEBs from blocks_800 that won't be used.
# ['3006500120129', '3006500200129', '3006500310129', '3008700200287', '3018200020017']
# --------------------------------------------------------------------------------
# --- Starting city 68/71: Merida
# INSPECTING AGEBs.
# FOUND 37 blocks_800 in current municipalities.
# ADDED 37 blocks_800 for 37 AGEBs.
# Printing AGEBs with blocks_800 list:
# ['3100200010034', '3100200010072', '3101300010127', '3103800010249', '3103800010268', '3103800010427', '3103800050395', '3103800050412', '3103800050446', '3103800050465', '3103900010034', '3104100010530', '3104100010634', '3104100010757', '3104100010776', '310500001562A', '3105000013873', '3105000015969', '3105000016187', '3105000016257', '3105000016350', '3105000016859', '3105000756011', '3105000756562', '3105000756577', '3105000774941', '3105000774956', '3105001114405', '3105001116280', '3105001116295', '3106300010059', '3109500010071', '3110000010054', '3110000010105', '3110100010314', '3110100010329', '3110100010352']
# REMOVED blocks_800 from 0 other AGEBs not available in pop_gdf_ageb.
# Printing AGEBs from blocks_800 that won't be used.
# []
# --------------------------------------------------------------------------------
# --- Starting city 69/71: Zacatecas
# INSPECTING AGEBs.
# FOUND 68 blocks_800 in current municipalities.
# ADDED 67 blocks_800 for 67 AGEBs.
# Printing AGEBs with blocks_800 list:
# ['3201700011449', '3201700011468', '3201700011769', '3201700012023', '3201700012254', '3201700012288', '3201700012339', '3201700012466', '3201700012606', '3201700012682', '3201700012894', '320170001295A', '3201700012998', '3201700092184', '3201700092199', '3201700092216', '3201700092790', '3201700291097', '320170029135A', '3201700291364', '3201700291627', '3201700390402', '3201700390440', '3201700391311', '3201700392381', '3201700392396', '3201700012907', '320170042174A', '3201700430811', '3201700430826', '3201700430830', '320170043217A', '3201700432409', '3203200010076', '3203200010080', '3203200010288', '3203200110146', '3203200110165', '320320011024A', '3203200110343', '3205000010110', '3205000010271', '3205000110159', '3205000110163', '3205000110214', '3205000110248', '3205600010415', '3205600010843', '3205600011324', '3205600011536', '3205600011714', '3205600011748', '3205600011964', '3205600012178', '320560001220A', '3205700010056', '3205700010075', '320570001008A', '3205700010107', '3205700010253', '3205700010624', '3205700010446', '3205700010465', '320570001047A', '3205700010592', '3205700010639', '3205700010643']
# REMOVED blocks_800 from 1 other AGEBs not available in pop_gdf_ageb.
# Printing AGEBs from blocks_800 that won't be used.
# ['3205600280025']

# %% [markdown]
# ## Random AGEB example

# %%
#Example
# Blocks from AGEB '0100100013721' were found in Aguascalientes and were added (Its AGEB has geometry)
ageb_test = '0100100013721'

# %%
# Blocks
blocks_schema = 'censo'
blocks_table = 'censo_inegi_20_mza'
query = f"SELECT * FROM {blocks_schema}.{blocks_table} WHERE \"cvegeo_ageb\" LIKE \'{ageb_test}\'"
blocks_gdf = aup.gdf_from_query(query, geometry_col='geometry')
blocks_gdf = blocks_gdf.set_crs("EPSG:4326")
# Show
print(blocks_gdf.shape)
blocks_gdf.head(2)
# Out:
# (45, 237)
#           nom_ent         nom_mun         nom_loc  pobtot  pobfem  pobmas
# 0  Aguascalientes  Aguascalientes  Aguascalientes     184    91.0    93.0  \
# 1  Aguascalientes  Aguascalientes  Aguascalientes     134    72.0    62.0
#
#    p_0a2  p_0a2_f  p_0a2_m  p_3ymas  ...   loc  ageb  mza  cvegeo_mun
# 0   19.0      9.0     10.0    165.0  ...  0001  3721  037       01001  \
# 1    7.0      4.0      3.0    127.0  ...  0001  3721  001       01001
#
#    cvegeo_loc    cvegeo_ageb        cvegeo_mza  ambito  tipomza
# 0   010010001  0100100013721  0100100013721037  Urbana   Típica  \
# 1   010010001  0100100013721  0100100013721001  Urbana   Típica
#
#                                             geometry
# 0  POLYGON ((-102.23579 21.91211, -102.23571 21.9...
# 1  POLYGON ((-102.23863 21.91033, -102.23852 21.9...
#
# [2 rows x 237 columns]

# %%
# AGEB
ageb_schema = 'censo'
ageb_table = 'censo_inegi_20_ageb'
query = f"SELECT * FROM {ageb_schema}.{ageb_table} WHERE \"cvegeo_ageb\" LIKE \'{ageb_test}\'"
ageb_gdf = aup.gdf_from_query(query, geometry_col='geometry')
ageb_gdf = ageb_gdf.set_crs("EPSG:4326")
# Show
print(ageb_gdf.shape)
ageb_gdf.head(2)
# Out:
# (1, 235)
#           nom_ent         nom_mun            nom_loc  pobtot  pobfem  pobmas
# 0  Aguascalientes  Aguascalientes  Total AGEB urbana    5275  2676.0  2599.0  \
#
#    p_0a2  p_0a2_f  p_0a2_m  p_3ymas  ...  entidad  mun   loc  ageb  mza
# 0  400.0    181.0    219.0   4875.0  ...       01  001  0001  3721  000  \
#
#    cvegeo_mun  cvegeo_loc    cvegeo_ageb        cvegeo_mza
# 0       01001   010010001  0100100013721  0100100013721000  \
#
#                                             geometry
# 0  MULTIPOLYGON (((-102.24044 21.91263, -102.2405...
#
# [1 rows x 235 columns]

# %%
# Load blocks 800
accesibilidad_urbana = "../../../"
input_path = accesibilidad_urbana + "data/external/census/"
census_2020_blocks800 = pd.read_csv(input_path + "census_2020_blocks800.csv")
# Filter for AGEB test
blocks800_df = census_2020_blocks800.loc[census_2020_blocks800.cvegeo_ageb==ageb_test]

# Show
print(census_2020_blocks800.shape)
census_2020_blocks800.head(2)
# Out:
# (8791, 234)
#           nom_ent         nom_mun         nom_loc  pobtot  pobfem  pobmas
# 0  Aguascalientes  Aguascalientes  Aguascalientes       9     NaN     NaN  \
# 1  Aguascalientes  Aguascalientes  Aguascalientes      17     8.0     9.0
#
#    p_0a2  p_0a2_f  p_0a2_m  p_3ymas  ...  vph_sintic  entidad  mun  loc  ageb
# 0    NaN      NaN      NaN      NaN  ...         NaN        1    1    1  3721  \
# 1    0.0      0.0      0.0     17.0  ...         0.0        1    1    1  4113
#
#    mza  cvegeo_mun  cvegeo_loc    cvegeo_ageb        cvegeo_mza
# 0  800        1001    10010001  0100100013721  0100100013721800
# 1  800        1001    10010001  0100100014113  0100100014113800
#
# [2 rows x 234 columns]

# %%
print(f"Population in blocks: {blocks_gdf.pobtot.sum()}.")
print(f"Population in AGEB: {ageb_gdf.pobtot.sum()}.<-----")
print(f"Population in blocks 800: {blocks800_df.pobtot.sum()}.")
print(f"Sum of blocks + blocks 800: {blocks_gdf.pobtot.sum()+blocks800_df.pobtot.sum()}.<-----")
# Out:
# Population in blocks: 5266.
# Population in AGEB: 5275.<-----
# Population in blocks 800: 9.
# Sum of blocks + blocks 800: 5275.<-----
