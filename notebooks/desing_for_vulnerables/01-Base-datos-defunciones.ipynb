# %% [markdown]
# # Revisión de bases de datos de defunciones

# %% [markdown]
# En este Notebook se realizan análisis de los datos de defunciones publicados en los [datos abiertos](http://www.dgis.salud.gob.mx/contenidos/basesdedatos/da_defunciones_gobmx.html) de la Secretaría de Salud. Este trabajo es parte de la investigación de Design for Vulnerables. Con el tratamiendo de esta información se busca identificar aquella información pertinente para estudiar las defunciones por localidades que se puedan relacionar con problemas medio ambientales.

# %% [markdown]
# ## Importar librerías

# %%
import os
import sys

import pandas as pd
import geopandas as gpd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

module_path = os.path.abspath(os.path.join('../../'))
if module_path not in sys.path:
    sys.path.append(module_path)
    import aup
# Out:
# /home/vscode/anaconda3/envs/odc/lib/python3.10/site-packages/osmnx/utils.py:192: UserWarning: The `utils.config` function is deprecated and will be removed in a future release. Instead, use the `settings` module directly to configure a global setting's value. For example, `ox.settings.log_console=True`.
#   warnings.warn(

# %% [markdown]
# ## Carga de archivos

# %%
df_15 = pd.read_csv('../../data/external/defunciones_dfv/DEFUN_2015/conjunto_de_datos15/defunciones_generales_2015.csv')
print(df_15.shape)
df_15.head(5)
# Out:
# (655688, 59)
#    ent_regis  mun_regis  ent_resid  mun_resid  tloc_resid  loc_resid  \
# 0          1          1          1          1          15          1
# 1          1          1          1          1          15          1
# 2          1          1          1          1          15          1
# 3          1          1          1          1          15          1
# 4          1          1          1          1          15          1
#
#    ent_ocurr  mun_ocurr  tloc_ocurr  loc_ocurr  ... anio_cert maternas  \
# 0          1          1          15          1  ...      2015      NaN
# 1          1          1          15          1  ...      2015      NaN
# 2          1          1          15          1  ...      2015      NaN
# 3          1          1          15          1  ...      2015      NaN
# 4          1          1          15          1  ...      2015      NaN
#
#    lengua  cond_act  par_agre  ent_ocules  mun_ocules  loc_ocules  razon_m  \
# ...

# %% [markdown]
# ## Filter data

# %%
mun_id = [51,38,19]
loc_id = [10,41,276]

# %%
df_15.loc[((df_15.ent_resid==8)&
         (df_15.mun_resid==mun_id[0])&
         (df_15.loc_resid==loc_id[0]))|
         ((df_15.ent_resid==8)&
         (df_15.mun_resid==mun_id[1])&
         (df_15.loc_resid==loc_id[1]))|
         ((df_15.ent_resid==8)&
         (df_15.mun_resid==mun_id[2])&
         (df_15.loc_resid==loc_id[2]))]
# Out:
#        ent_regis  mun_regis  ent_resid  mun_resid  tloc_resid  loc_resid  \
# 78355          8         19          8         38           1         41
# 79397          8         51          8         51           2         10
# 79494          8         21          8         38           1         41
# 83369          8         21          8         38           1         41
# 85899          8         38          8         38           1         41
# 87037          8         19          8         38           1         41
# 87042          8         19          8         38           1         41
# 87043          8         19          8         38           1         41
# 87045          8         19          8         38           1         41
# 87108          8         21          8         38           1         41
# 87248          8         21          8         38           1         41
# 90572          8         19          8         51           2         10
# ...
