# %%
import pandas as pd
import numpy as np
import geopandas as gpd

import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    import aup
# Out:
# /home/edgar/anaconda3/envs/geo_env/lib/python3.8/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.1-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.9.1-CAPI-1.14.2). Conversions between both will be slow.
#   warnings.warn(

# %%
complementarias_gdf = gpd.read_file('/home/edgar/SIG/ObsCds/Proyectos/Museo_CienciasAmbientales/Medio_Urbano/Transporte_Publico/vwRutas_complementarias_y_otros_mapa_base_mayo_2021.shp',
                         driver='ESRIShapefile')
troncales_gdf = gpd.read_file('/home/edgar/SIG/ObsCds/Proyectos/Museo_CienciasAmbientales/Medio_Urbano/Transporte_Publico/vwCorredores_troncales_mapa_base_mayo_2021.shp',
                             driver='ESRIShapefile')

# %%
print(complementarias_gdf.shape)
complementarias_gdf.head(2)
# Out:
# (449, 4)
#        Tipo_de_se                               Clasificac Clasifica0  \
# 0  Complementaria  Rutas complementarias y otros servicios   Operando
# 1  Complementaria  Rutas complementarias y otros servicios   Operando
#
#                                             geometry
# 0  LINESTRING (678662.391 2280955.399, 678671.428...
# 1  LINESTRING (681285.232 2288258.855, 681281.106...

# %%
print(troncales_gdf.shape)
troncales_gdf.head(2)
# Out:
# (221, 4)
#            Tipo_de_se            Clasificac                       Clasifica0  \
# 0  T 05, López Mateos  Corredores troncales  Presentadas en grupo de Trabajo
# 1  T 05, López Mateos  Corredores troncales  Presentadas en grupo de Trabajo
#
#                                             geometry
# 0  LINESTRING (661387.867 2270907.072, 661389.125...
# 1  LINESTRING (666791.399 2284313.859, 666760.945...

# %%
rutas_gdf = complementarias_gdf.append(troncales_gdf)
print(rutas_gdf.shape)
rutas_gdf.head(4)
# Out:
# (670, 4)
#               Tipo_de_se                               Clasificac Clasifica0  \
# 0         Complementaria  Rutas complementarias y otros servicios   Operando
# 1         Complementaria  Rutas complementarias y otros servicios   Operando
# 2         Complementaria  Rutas complementarias y otros servicios   Operando
# 3  Alimentadora Macrobús  Rutas complementarias y otros servicios   Operando
#
#                                             geometry
# 0  LINESTRING (678662.391 2280955.399, 678671.428...
# 1  LINESTRING (681285.232 2288258.855, 681281.106...
# 2  LINESTRING (676906.172 2288931.420, 676861.592...
# 3  LINESTRING (672707.921 2279751.215, 672721.691...

# %%
rutas_gdf.plot()
# Out:
# <AxesSubplot:>

# %%
rutas_gdf.to_file('/home/edgar/SIG/ObsCds/Proyectos/Museo_CienciasAmbientales/Medio_Urbano/Transporte_Publico/Rutas_TP.geojson',
                             driver='GeoJSON')

# %% [markdown]
# ## Análisis de transporte público

# %% [markdown]
# ### Red de transporte público

# %%
rutas_gdf = gpd.read_file('/home/edgar/SIG/ObsCds/'+
                          'Proyectos/Museo_CienciasAmbientales'+
                          '/Medio_Urbano/Transporte_Publico/Transporte_Masivo/'+
                          'MacroPeriferico_Imeplan_UTM_v1.geojson',
                         driver='GeoJSON')
paradas_gdf = gpd.read_file('/home/edgar/SIG/ObsCds/'+
                          'Proyectos/Museo_CienciasAmbientales'+
                          '/Medio_Urbano/Transporte_Publico/Transporte_Masivo/'+
                            'Estaciones_MiMacro.geojson',
                         driver='GeoJSON')

# %%
print(rutas_gdf.shape)
rutas_gdf.head(2)
# Out:
# (93, 5)
#   Tipo_de_co         Tipo                                             Nombre  \
# 0     Masivo  Circunvalar  Corredor 3 Circuito perif�rico (Mi Macro Perif...
# 1     Masivo  Circunvalar  Corredor 3 Circuito perif�rico (Mi Macro Perif...
#
#             Estado                                           geometry
# 0  En construcci�n  LINESTRING (662096.413 2284192.153, 662096.413...
# 1  En construcci�n  LINESTRING (664462.242 2292315.052, 664462.242...

# %%
print(paradas_gdf.shape)
paradas_gdf.head(2)
# Out:
# (46, 6)
#       Nombre_de_                  Sistema  Estructura      Estado  \
# 0        Tepeyac  BRT (Bus Rapid Transit)  Superficie  En proceso
# 1  Trompo Magico  BRT (Bus Rapid Transit)  Superficie  En proceso
#
#             L�nea_y_si                        geometry
# 0  Mi Macro Perif�rico  POINT (662096.413 2284192.153)
# 1  Mi Macro Perif�rico  POINT (664462.242 2292315.052)

# %%
paradas_nx, rutas_nx = aup.create_network(paradas_gdf, rutas_gdf)

# %%
print(rutas_nx.shape)
rutas_nx.head(2)
# Out:
# (93, 9)
#   Tipo_de_co         Tipo                                             Nombre  \
# 0     Masivo  Circunvalar  Corredor 3 Circuito perif�rico (Mi Macro Perif...
# 1     Masivo  Circunvalar  Corredor 3 Circuito perif�rico (Mi Macro Perif...
#
#             Estado                                           geometry  \
# 0  En construcci�n  LINESTRING (-103.44406 20.65003, -103.44406 20...
# 1  En construcci�n  LINESTRING (-103.42059 20.72319, -103.42059 20...
#
#                u              v  key  length
# 0  2350147961102  2350147961102    0     0.0
# 1  2352661969143  2352661969143    0     0.0

# %%
paradas_nx = paradas_nx.iloc[paradas_nx.osmid.drop_duplicates().index]
print(paradas_nx.shape)
paradas_nx.head(2)
# Out:
# (46, 7)
#       Nombre_de_                  Sistema  Estructura      Estado  \
# 0        Tepeyac  BRT (Bus Rapid Transit)  Superficie  En proceso
# 1  Trompo Magico  BRT (Bus Rapid Transit)  Superficie  En proceso
#
#             L�nea_y_si                     geometry          osmid
# 0  Mi Macro Perif�rico  POINT (-103.44406 20.65003)  2350147961102
# 1  Mi Macro Perif�rico  POINT (-103.42059 20.72319)  2352661969143

# %% [markdown]
# ## Red OSMnx

# %% [markdown]
# ### Abre red local

# %%
import osmnx as ox

# %%
edges = gpd.read_file('/home/edgar/SIG/ObsCds/Proyectos/Museo_CienciasAmbientales/Medio_Urbano/Vias_Transporte/edges_speed_AMG.geojson', driver='GeoJSON')
print(edges.shape)
edges.head(2)
# Out:
# (414774, 16)
#              id             u             v  key      osmid oneway   length  \
# 0 -1.922695e+09  1.680913e+09  1.680913e+09  0.0  155732288  False   45.603
# 1 -1.922105e+09  4.343498e+09  4.343498e+09  0.0  436461417  False  141.661
#
#    grade  grade_abs bridge junction service tunnel  walkspeed  time_min  \
# 0  0.022      0.022   None     None    None   None   3.703559  0.738797
# 1  0.042      0.042   None     None    None   None   3.453176  2.461404
#
#                                             geometry
# 0  LINESTRING (-103.25834 20.68905, -103.25844 20...
# 1  LINESTRING (-103.19724 20.66496, -103.19742 20...

# %%
nodes = gpd.read_file('/home/edgar/SIG/ObsCds/Proyectos/Museo_CienciasAmbientales/Medio_Urbano/Vias_Transporte/nodes_AMG.geojson', driver='GeoJSON')
print(nodes.shape)
nodes.head(2)
# Out:
# (172090, 5)
#       osmid           x          y  street_count                     geometry
# 0  28751344 -103.306309  20.711533           3.0  POINT (-103.30631 20.71153)
# 1  28753224 -103.316645  20.700650           3.0  POINT (-103.31665 20.70065)

# %%
G = ox.graph_from_gdfs(nodes.set_index('osmid'), edges.set_index(['u','v','key']))

# %% [markdown]
# ### Crea red con transporte público

# %%
paradas_fn = paradas_nx.rename(columns={'osmid':'coord_id'})
print(paradas_fn.shape)
paradas_fn.head(2)
# Out:
# (36440, 13)
#    fid  cat      Tipo_de_se                               Clasificac  \
# 0    1    1  Complementaria  Rutas complementarias y otros servicios
# 1    1    1  Complementaria  Rutas complementarias y otros servicios
#
#   Clasifica0  vertex_pos  vertex_ind  vertex_par  vertex_p_1    distance  \
# 0   Operando           0           0           0           0    0.000000
# 1   Operando          -1           5           0           5  391.464694
#
#        angle                     geometry       coord_id
# 0  71.784975  POINT (-103.28542 20.61928)  2366578957556
# 1   9.373501  POINT (-103.28464 20.62267)  2366663957929

# %%
paradas_osmid = aup.find_nearest(G, nodes.set_index('osmid'), paradas_fn, return_distance= True)

# %%
print(paradas_osmid.shape)
paradas_osmid.head(4)
# Out:
# (36440, 15)
#    fid  cat      Tipo_de_se                               Clasificac  \
# 0    1    1  Complementaria  Rutas complementarias y otros servicios
# 1    1    1  Complementaria  Rutas complementarias y otros servicios
# 2    2    1  Complementaria  Rutas complementarias y otros servicios
# 3    3    1  Complementaria  Rutas complementarias y otros servicios
#
#   Clasifica0  vertex_pos  vertex_ind  vertex_par  vertex_p_1    distance  \
# 0   Operando           0           0           0           0    0.000000
# 1   Operando          -1           5           0           5  391.464694
# 2   Operando          -1          10           0          10  391.464694
# 3   Operando          -1          14           0          14  391.464694
#
#        angle                     geometry       coord_id       osmid  \
# 0  71.784975  POINT (-103.28542 20.61928)  2366578957556  7911972970
# 1   9.373501  POINT (-103.28464 20.62267)  2366663957929  1448560100
# 2  37.884785  POINT (-103.28750 20.62420)  2366367958101  1448560168
# 3  36.925720  POINT (-103.28615 20.62746)  2366510958458  1626459520
#
#    distance_node
# 0      69.639706
# 1       4.743718
# 2      12.158505
# 3      13.938591

# %%
print('media:',round(paradas_osmid.distance_node.mean(),2))
paradas_osmid.distance_node.hist()
# Out:
# media: 30.88
# <AxesSubplot:>

# %% [markdown]
# ### Sobreescribir ids de con osmids en paradas

# %%
rutas_osmid = rutas_nx.merge(paradas_osmid[['coord_id','osmid']], left_on='u', right_on='coord_id')
rutas_osmid = rutas_osmid.merge(paradas_osmid[['coord_id','osmid']], left_on='v', right_on='coord_id')
rutas_osmid.head(2)
# Out:
#      fid  cat      Tipo_de_se                               Clasificac  \
# 0      1    1  Complementaria  Rutas complementarias y otros servicios
# 1  13780  250  Complementaria  Rutas complementarias y otros servicios
#
#   Clasifica0                                           geometry  \
# 0   Operando  LINESTRING (-103.28542 20.61928, -103.28533 20...
# 1   Operando  LINESTRING (-103.28542 20.61928, -103.28533 20...
#
#                u              v  key      length     coord_id_x     osmid_x  \
# 0  2366578957556  2366663957929    0  389.835333  2366578957556  7911972970
# 1  2366578957556  2366662957927    0  387.507594  2366578957556  7911972970
#
#       coord_id_y     osmid_y
# 0  2366663957929  1448560100
# 1  2366662957927  1448560100

# %%
rutas_osmid=rutas_osmid.drop(columns=['u','v','coord_id_x','coord_id_y']).rename(columns={'osmid_x':'u','osmid_y':'v'})

# %%
rutas_osmid = rutas_osmid.to_crs("EPSG:32613")

# %%
rutas_osmid['walkspeed'] = 30
rutas_osmid['time_min'] = rutas_osmid['length']/(1000*rutas_osmid['walkspeed']/60)

# %%
rutas_osmid.head()
# Out:
#      fid  cat      Tipo_de_se                               Clasificac  \
# 0      1    1  Complementaria  Rutas complementarias y otros servicios
# 1  13780  250  Complementaria  Rutas complementarias y otros servicios
# 2      2    1  Complementaria  Rutas complementarias y otros servicios
# 3      3    1  Complementaria  Rutas complementarias y otros servicios
# 4      4    1  Complementaria  Rutas complementarias y otros servicios
#
#   Clasifica0                                           geometry  key  \
# 0   Operando  LINESTRING (-103.28542 20.61928, -103.28533 20...    0
# 1   Operando  LINESTRING (-103.28542 20.61928, -103.28533 20...    0
# 2   Operando  LINESTRING (-103.28464 20.62267, -103.28462 20...    0
# 3   Operando  LINESTRING (-103.28750 20.62420, -103.28740 20...    0
# 4   Operando  LINESTRING (-103.28615 20.62746, -103.28606 20...    0
#
#        length           u           v  walkspeed  time_min
# 0  389.835333  7911972970  1448560100         30  0.779671
# 1  387.507594  7911972970  1448560100         30  0.775015
# 2  389.834610  1448560100  1448560168         30  0.779669
# 3  389.834005  1448560168  1626459520         30  0.779668
# 4  389.832682  1626459520  8771129800         30  0.779665

# %%
paradas_fn.merge(paradas_osmid[['coord_id','osmid']], on='coord_id')
# Out:
#          fid  cat               Tipo_de_se  \
# 0          1    1           Complementaria
# 1          1    1           Complementaria
# 2          2    1           Complementaria
# 3          3    1           Complementaria
# 4          4    1           Complementaria
# ...      ...  ...                      ...
# 36435  37579  670  T 16, Juan Gil Preciado
# 36436  37580  670  T 16, Juan Gil Preciado
# 36437  37581  670  T 16, Juan Gil Preciado
# 36438  37582  670  T 16, Juan Gil Preciado
# 36439  37583  670  T 16, Juan Gil Preciado
#
#                                     Clasificac Clasifica0  vertex_pos  \
# 0      Rutas complementarias y otros servicios   Operando           0
# 1      Rutas complementarias y otros servicios   Operando          -1
# 2      Rutas complementarias y otros servicios   Operando          -1
# 3      Rutas complementarias y otros servicios   Operando          -1
# 4      Rutas complementarias y otros servicios   Operando          -1
# ...                                        ...        ...         ...
# 36435                     Corredores troncales   Operando          -1
# 36436                     Corredores troncales   Operando          -1
# 36437                     Corredores troncales   Operando          -1
# 36438                     Corredores troncales   Operando          -1
# 36439                     Corredores troncales   Operando          -1
#
#        vertex_ind  vertex_par  vertex_p_1    distance       angle  \
# 0               0           0           0    0.000000   71.784975
# 1               5           0           5  391.464694    9.373501
# 2              10           0          10  391.464694   37.884785
# 3              14           0          14  391.464694   36.925720
# 4              13           0          13  391.464694    8.868869
# ...           ...         ...         ...         ...         ...
# 36435           4           0           4  394.912360  143.860428
# 36436          11           0          11  394.912360    6.650223
# 36437          14           0          14  394.912360   80.066762
# 36438          11           0          11  394.912360   88.147322
# 36439          13           0          13  394.912360   84.684102
#
#                           geometry       coord_id     osmid_x  distance_node  \
# 0      POINT (-103.28542 20.61928)  2366578957556  7911972970      69.639706
# 1      POINT (-103.28464 20.62267)  2366663957929  1448560100       4.743718
# 2      POINT (-103.28750 20.62420)  2366367958101  1448560168      12.158505
# 3      POINT (-103.28615 20.62746)  2366510958458  1626459520      13.938591
# 4      POINT (-103.28547 20.63079)  2366584958825  8771129800      10.459439
# ...                            ...            ...         ...            ...
# 36435  POINT (-103.44275 20.81898)  2350469979726  2689210151       5.676870
# 36436  POINT (-103.44024 20.82042)  2350732979882  8393360156      30.282027
# 36437  POINT (-103.43914 20.82294)  2350848980158  6131379217      15.787354
# 36438  POINT (-103.43543 20.82342)  2351233980207  8840219602      35.585750
# 36439  POINT (-103.43186 20.82393)  2351604980260  6131379233       2.451868
#
#           osmid_y
# 0      7911972970
# 1      1448560100
# 2      1448560168
# 3      1626459520
# 4      8771129800
# ...           ...
# 36435  2689210151
# 36436  8393360156
# 36437  6131379217
# 36438  8840219602
# 36439  6131379233
#
# [36440 rows x 16 columns]

# %% [markdown]
# ### Unión de rutas con vialidades

# %%
rutas_osmid = rutas_osmid.to_crs("EPSG:4326")

# %%
rutas_edges = edges.append(rutas_osmid)

# %%
rutas_edges.head(2)
# Out:
#              id             u             v  key      osmid oneway   length  \
# 0 -1.922695e+09  1.680913e+09  1.680913e+09  0.0  155732288  False   45.603
# 1 -1.922105e+09  4.343498e+09  4.343498e+09  0.0  436461417  False  141.661
#
#    grade  grade_abs bridge  ... service tunnel walkspeed  time_min  \
# 0  0.022      0.022   None  ...    None   None  3.703559  0.738797
# 1  0.042      0.042   None  ...    None   None  3.453176  2.461404
#
#                                             geometry fid  cat  Tipo_de_se  \
# 0  LINESTRING (-103.25834 20.68905, -103.25844 20... NaN  NaN         NaN
# 1  LINESTRING (-103.19724 20.66496, -103.19742 20... NaN  NaN         NaN
#
#   Clasificac Clasifica0
# 0        NaN        NaN
# 1        NaN        NaN
#
# [2 rows x 21 columns]

# %% [markdown]
# ### Distance analysis

# %%
museo = nodes.loc[nodes.osmid==999999].copy()

# %%
nodes_analysis = nodes.set_index('osmid')
edges_analysis = rutas_edges.set_index(['u','v','key'])

# %%
nodes.isna().sum()
# Out:
# osmid           0
# x               0
# y               0
# street_count    6
# geometry        0
# dtype: int64

# %%
rutas_edges[~rutas_edges.u.isna()]
# Out:
#                  id             u             v  key      osmid oneway  \
# 0     -1.922695e+09  1.680913e+09  1.680913e+09  0.0  155732288  False
# 1     -1.922105e+09  4.343498e+09  4.343498e+09  0.0  436461417  False
# 2     -1.921712e+09  4.649992e+09  4.649992e+09  0.0  470809481  False
# 3     -1.920991e+09  4.649992e+09  4.649992e+09  0.0  470809480  False
# 4     -1.920729e+09  4.649992e+09  4.649992e+09  0.0  470809480  False
# ...             ...           ...           ...  ...        ...    ...
# 37578           NaN  2.690649e+09  2.689210e+09  0.0        NaN    NaN
# 37579           NaN  2.689210e+09  8.393360e+09  0.0        NaN    NaN
# 37580           NaN  8.393360e+09  6.131379e+09  0.0        NaN    NaN
# 37581           NaN  6.131379e+09  8.840220e+09  0.0        NaN    NaN
# 37582           NaN  8.840220e+09  6.131379e+09  0.0        NaN    NaN
#
#            length  grade  grade_abs bridge  ... service tunnel  walkspeed  \
# 0       45.603000  0.022      0.022   None  ...    None   None   3.703559
# 1      141.661000  0.042      0.042   None  ...    None   None   3.453176
# 2       51.937000  0.000      0.000   None  ...    None   None   4.000000
# 3       13.993000  0.000      0.000   None  ...    None   None   4.000000
# 4      178.729000 -0.056      0.056   None  ...    None   None   3.288049
# ...           ...    ...        ...    ...  ...     ...    ...        ...
# 37578  393.230480    NaN        NaN    NaN  ...     NaN    NaN  30.000000
# 37579  393.229850    NaN        NaN    NaN  ...     NaN    NaN  30.000000
# 37580  393.228860    NaN        NaN    NaN  ...     NaN    NaN  30.000000
# 37581  393.227987    NaN        NaN    NaN  ...     NaN    NaN  30.000000
# 37582  393.227257    NaN        NaN    NaN  ...     NaN    NaN  30.000000
#
#        time_min                                           geometry      fid  \
# 0      0.738797  LINESTRING (-103.25834 20.68905, -103.25844 20...      NaN
# 1      2.461404  LINESTRING (-103.19724 20.66496, -103.19742 20...      NaN
# 2      0.779055  LINESTRING (-103.44378 20.45094, -103.44426 20...      NaN
# 3      0.209895  LINESTRING (-103.44356 20.45154, -103.44369 20...      NaN
# 4      3.261430  LINESTRING (-103.44455 20.44932, -103.44566 20...      NaN
# ...         ...                                                ...      ...
# 37578  0.786461  LINESTRING (-103.44636 20.81887, -103.44287 20...  37579.0
# 37579  0.786460  LINESTRING (-103.44275 20.81898, -103.44269 20...  37580.0
# 37580  0.786458  LINESTRING (-103.44024 20.82042, -103.44021 20...  37581.0
# 37581  0.786456  LINESTRING (-103.43914 20.82294, -103.43883 20...  37582.0
# 37582  0.786455  LINESTRING (-103.43543 20.82342, -103.43528 20...  37583.0
#
#          cat               Tipo_de_se            Clasificac Clasifica0
# 0        NaN                      NaN                   NaN        NaN
# 1        NaN                      NaN                   NaN        NaN
# 2        NaN                      NaN                   NaN        NaN
# 3        NaN                      NaN                   NaN        NaN
# 4        NaN                      NaN                   NaN        NaN
# ...      ...                      ...                   ...        ...
# 37578  670.0  T 16, Juan Gil Preciado  Corredores troncales   Operando
# 37579  670.0  T 16, Juan Gil Preciado  Corredores troncales   Operando
# 37580  670.0  T 16, Juan Gil Preciado  Corredores troncales   Operando
# 37581  670.0  T 16, Juan Gil Preciado  Corredores troncales   Operando
# 37582  670.0  T 16, Juan Gil Preciado  Corredores troncales   Operando
#
# [452356 rows x 21 columns]

# %%
nodes_dist = aup.calculate_distance_nearest_poi(museo, nodes, 
                rutas_edges[~rutas_edges.u.isna()], 'museo', 'osmid', wght='time_min')

# %%
nodes_dist.rename(columns={'dist_museo':'time_museo'}, inplace=True)

# %%
nodes_dist.to_file('/home/edgar/SIG/ObsCds/Proyectos/Museo_CienciasAmbientales/Medio_Urbano/Analisis/nodes_time_AMG_TP.geojson', driver='GeoJSON')
