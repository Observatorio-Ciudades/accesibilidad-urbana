# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os 
import sys
module_path = os.path.abspath(os.path.join('../../../'))
if module_path not in sys.path:
    sys.path.append(module_path)
    import aup
from matplotlib.colors import ListedColormap
import folium
from folium.plugins import MarkerCluster
import leafmap
from minisom import MiniSom
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import silhouette_score
from sklearn.model_selection import ParameterGrid
from sklearn.preprocessing import StandardScaler

# %%
schema = 'projects_research'
table = 'arroyovivo_residuos_hex'
query = f"SELECT * FROM {schema}.{table}"
residuos = aup.gdf_from_query(query, geometry_col='geometry')

print(residuos.shape)
residuos.head(1)
# Out:
# (562, 51)
#             hex_id  res                                           geometry  \
# 0  8a48a20296a7fff   10  POLYGON ((-100.30269 25.63956, -100.30201 25.6...
#
#    aluminio  aluminio_quantity  baterias  baterias_quantity  carton  \
# 0      13.0               24.0       0.0                0.0    36.0
#
#    carton_quantity  cenizas  ...  unicel  unicel_quantity  vidrio  \
# 0             44.0      0.0  ...   207.0            259.0    89.0
#
#    vidrio_quantity  epi  epi_quantity  total_points  most_common_point  \
# 0            137.0  1.0           1.0        1918.0           Plastico
#
#    total_quantity  most_common_quantity
# 0          2669.0     Plastico_quantity
#
# [1 rows x 51 columns]

# %%
residuos.columns
# Out:
# Index(['hex_id', 'res', 'geometry', 'aluminio', 'aluminio_quantity',
#        'baterias', 'baterias_quantity', 'carton', 'carton_quantity', 'cenizas',
#        'cenizas_quantity', 'ceramica', 'ceramica_quantity', 'electronica',
#        'electronica_quantity', 'escombros', 'escombros_quantity', 'goma',
#        'goma_quantity', 'llantas', 'llantas_quantity', 'madera',
#        'madera_quantity', 'metal', 'metal_quantity', 'organico',
#        'organico_quantity', 'otros', 'otros_quantity', 'papel',
#        'papel_quantity', 'pesca', 'pesca_quantity', 'plastico',
#        'plastico_quantity', 'salud e higiene', 'salud e higiene_quantity',
#        'tabaco', 'tabaco_quantity', 'tela', 'tela_quantity', 'unicel',
#        'unicel_quantity', 'vidrio', 'vidrio_quantity', 'epi', 'epi_quantity',
#        'total_points', 'most_common_point', 'total_quantity',
#        'most_common_quantity'],
#       dtype='object')

# %% [markdown]
# ## Estandarización de los datos

# %%
coldatos = ['aluminio', 'aluminio_quantity',
       'baterias', 'baterias_quantity', 'carton', 'carton_quantity', 'cenizas',
       'cenizas_quantity', 'ceramica', 'ceramica_quantity', 'electronica',
       'electronica_quantity', 'escombros', 'escombros_quantity', 'goma',
       'goma_quantity', 'llantas', 'llantas_quantity', 'madera',
       'madera_quantity', 'metal', 'metal_quantity', 'organico',
       'organico_quantity', 'otros', 'otros_quantity', 'papel',
       'papel_quantity', 'pesca', 'pesca_quantity', 'plastico',
       'plastico_quantity', 'salud e higiene', 'salud e higiene_quantity',
       'tabaco', 'tabaco_quantity', 'tela', 'tela_quantity', 'unicel',
       'unicel_quantity', 'vidrio', 'vidrio_quantity', 'epi', 'epi_quantity']

# Create a StandardScaler
scaler = StandardScaler()

# Standardize the selected columns
residuos[coldatos] = scaler.fit_transform(residuos[coldatos])
residuos.head()
# Out:
#             hex_id  res                                           geometry  \
# 0  8a48a20296a7fff   10  POLYGON ((-100.30269 25.63956, -100.30201 25.6...
# 1  8a48a202978ffff   10  POLYGON ((-100.30331 25.63839, -100.30263 25.6...
# 2  8a48a202baaffff   10  POLYGON ((-100.29357 25.64128, -100.29289 25.6...
# 3  8a48a202ba1ffff   10  POLYGON ((-100.29499 25.64119, -100.29431 25.6...
# 4  8a48a202ba0ffff   10  POLYGON ((-100.29641 25.64109, -100.29573 25.6...
#
#     aluminio  aluminio_quantity  baterias  baterias_quantity     carton  \
# 0  11.669761           9.057943 -0.103882          -0.084667  13.630210
# 1   8.900164          12.544630 -0.103882          -0.084667   4.675946
# 2  -0.331826          -0.239891 -0.103882          -0.084667   1.561420
# 3   2.437771           0.922338 -0.103882          -0.084667   0.004156
# 4   0.591373           0.147519 -0.103882          -0.084667   0.393472
#
#    carton_quantity   cenizas  ...     unicel  unicel_quantity     vidrio  \
# 0        12.220525 -0.127573  ...  18.570515        14.079036  14.658037
# 1         3.926608  7.838651  ...   4.922867        12.915738   4.036645
# 2         7.072577 -0.127573  ...   0.009714         1.892108   0.327587
# 3        -0.077352 -0.127573  ...   1.192510         1.227367   8.588670
# 4         0.208646 -0.127573  ...   0.919557         1.116576   2.856490
#
#    vidrio_quantity       epi  epi_quantity  total_points  most_common_point  \
# 0        12.070278  4.546442      2.893470        1918.0           Plastico
# 1         4.656423 -0.167765     -0.151718        1122.0           Plastico
# 2         0.497432 -0.167765     -0.151718         847.0           Plastico
# 3         4.475598 -0.167765     -0.151718         810.0           Plastico
# 4         3.209818 -0.167765     -0.151718         708.0           Plastico
#
#    total_quantity  most_common_quantity
# 0          2669.0     Plastico_quantity
# 1          2473.0     Plastico_quantity
# 2          2994.0     Plastico_quantity
# 3          1672.0     Plastico_quantity
# 4          1820.0     Plastico_quantity
#
# [5 rows x 51 columns]

# %% [markdown]
# ### Verificar estandarización

# %%
print("Media después de estandarización:")
print(residuos[coldatos].mean())

print("\nDesviación estándar después de estandarización:")
print(residuos[coldatos].std())
# Out:
# Media después de estandarización:
# aluminio                   -5.057244e-17
# aluminio_quantity          -2.528622e-17
# baterias                    6.321555e-18
# baterias_quantity          -1.264311e-17
# carton                      0.000000e+00
# carton_quantity             0.000000e+00
# cenizas                    -6.321555e-18
# cenizas_quantity            0.000000e+00
# ceramica                    5.057244e-17
# ceramica_quantity          -2.528622e-17
# electronica                 0.000000e+00
# electronica_quantity       -2.528622e-17
# escombros                   2.528622e-17
# escombros_quantity          0.000000e+00
# goma                        2.528622e-17
# goma_quantity               2.528622e-17
# llantas                     0.000000e+00
# llantas_quantity            0.000000e+00
# madera                      2.528622e-17
# madera_quantity             0.000000e+00
# metal                       2.528622e-17
# metal_quantity              0.000000e+00
# organico                    2.528622e-17
# organico_quantity           5.057244e-17
# otros                       0.000000e+00
# otros_quantity              3.792933e-17
# papel                      -2.528622e-17
# papel_quantity              0.000000e+00
# pesca                       9.482332e-18
# pesca_quantity             -6.321555e-18
# plastico                    5.057244e-17
# plastico_quantity           0.000000e+00
# salud e higiene            -7.585866e-17
# salud e higiene_quantity    0.000000e+00
# tabaco                      2.528622e-17
# tabaco_quantity            -5.057244e-17
# tela                        0.000000e+00
# tela_quantity              -3.792933e-17
# unicel                      2.528622e-17
# unicel_quantity             5.057244e-17
# vidrio                      5.057244e-17
# vidrio_quantity             2.528622e-17
# epi                        -2.528622e-17
# epi_quantity               -6.321555e-18
# dtype: float64
#
# Desviación estándar después de estandarización:
# aluminio                    1.000891
# aluminio_quantity           1.000891
# baterias                    1.000891
# baterias_quantity           1.000891
# carton                      1.000891
# carton_quantity             1.000891
# cenizas                     1.000891
# cenizas_quantity            1.000891
# ceramica                    1.000891
# ceramica_quantity           1.000891
# electronica                 1.000891
# electronica_quantity        1.000891
# escombros                   1.000891
# escombros_quantity          1.000891
# goma                        1.000891
# goma_quantity               1.000891
# llantas                     1.000891
# llantas_quantity            1.000891
# madera                      1.000891
# madera_quantity             1.000891
# metal                       1.000891
# metal_quantity              1.000891
# organico                    1.000891
# organico_quantity           1.000891
# otros                       1.000891
# otros_quantity              1.000891
# papel                       1.000891
# papel_quantity              1.000891
# pesca                       1.000891
# pesca_quantity              1.000891
# plastico                    1.000891
# plastico_quantity           1.000891
# salud e higiene             1.000891
# salud e higiene_quantity    1.000891
# tabaco                      1.000891
# tabaco_quantity             1.000891
# tela                        1.000891
# tela_quantity               1.000891
# unicel                      1.000891
# unicel_quantity             1.000891
# vidrio                      1.000891
# vidrio_quantity             1.000891
# epi                         1.000891
# epi_quantity                1.000891
# dtype: float64

# %% [markdown]
# # Dividir Dataset en Material y Material_quantity

# %% [markdown]
# ## Material

# %%
col_material = ['hex_id', 'res','geometry', 'aluminio', 'baterias', 'carton','cenizas','ceramica','electronica','escombros',
                'goma','llantas','madera','metal','organico','otros','papel','pesca','plastico','salud e higiene',
                'tabaco','tela','unicel','vidrio','epi','total_points', 'most_common_point'] 
data_material = residuos[col_material].copy()
print(data_material.shape)
# Out:
# (562, 27)

# %% [markdown]
# ### Res 11

# %%
data_material_11 = data_material[data_material['res'] == 11].copy()
print(data_material_11.shape)
data_material_11.head(2)
# Out:
# (420, 27)
#             hex_id  res                                           geometry  \
# 6  8b48a202baacfff   11  POLYGON ((-100.29357 25.64128, -100.29339 25.6...
# 9  8b48a20296a6fff   11  POLYGON ((-100.30220 25.63975, -100.30201 25.6...
#
#    aluminio  baterias    carton   cenizas  ceramica  electronica  escombros  \
# 6 -0.331826 -0.103882  1.561420 -0.127573 -0.329080    -0.220429   4.817522
# 9  3.360970 -0.103882  2.340051 -0.127573  0.665238     2.257194  -0.034706
#
#    ...     pesca  plastico  salud e higiene    tabaco       tela    unicel  \
# 6  ... -0.134595  2.010942         0.588397 -0.455406  12.467905  0.009714
# 9  ... -0.134595  3.213488         2.034515 -0.455406   2.349179  4.376961
#
#      vidrio       epi  total_points  most_common_point
# 6 -0.009600 -0.167765         656.0           Plastico
# 9  4.879613 -0.167765         517.0           Plastico
#
# [2 rows x 27 columns]

# %% [markdown]
# ### SOM

# %%
data_material_11.values.shape
# Out:
# (420, 27)

# %%
data = data_material_11.iloc[:, 3:-2].values
scaler = MinMaxScaler()
data_normalized = scaler.fit_transform(data)
neurons_a = 15
neurons_b = 15
som = MiniSom(neurons_a, neurons_b, data_normalized.values.shape[1], random_seed=0, learning_rate=.1, sigma=1.5)
som.pca_weights_init(data_normalized.values)
som.train(data_normalized.values, 10000, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 6
#       4 neurons_a = 15
#       5 neurons_b = 15
# ----> 6 som = MiniSom(neurons_a, neurons_b, data_normalized.values.shape[1], random_seed=0, learning_rate=.1, sigma=1.5)
#       7 som.pca_weights_init(data_normalized.values)
#       8 som.train(data_normalized.values, 10000, verbose=True)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
# Assuming 'gdf' is your GeoDataFrame
# Extract the relevant columns for clustering
#columns_for_clustering = data_material_11.iloc[, 3:-2]

# Select the data and normalize it
data = data_material_11.iloc[:, 3:-2].values
scaler = MinMaxScaler()
data_normalized = scaler.fit_transform(data)

# Set the SOM parameters (you might need to tune these based on your data)
som_size = (2000, 2000)  # Adjust the grid size based on the expected number of clusters
learning_rate = 0.5
sigma = 1.0
epochs = 1000

# Initialize the SOM
som = MiniSom(som_size[0], som_size[1], len(columns_for_clustering), sigma=sigma, learning_rate=learning_rate)

# Train the SOM
som.train(data_normalized, 1000, random_order=True, verbose=True)

winning_nodes = np.array([som.winner(data_point) for data_point in data_normalized])

# Convert winning_nodes to tuples
winning_nodes_tuples = [tuple(node) for node in winning_nodes]

# Create a new DataFrame with 'cluster' information
cluster_df = pd.DataFrame({'cluster': som.labels_map(data_normalized, winning_nodes_tuples)})

# Reset the index of both DataFrames
data_material_11.reset_index(drop=True, inplace=True)
cluster_df.reset_index(drop=True, inplace=True)

# Concatenate the two DataFrames
data_material_11 = pd.concat([data_material_11, cluster_df], axis=1)
# Out:
#  [ 1000 / 1000 ] 100% - 0:00:04 left

# %%
# Print or inspect the resulting GeoDataFrame
data_material_11.head()
# Out:
#             hex_id  res                                           geometry  \
# 0  8b48a202baacfff   11  POLYGON ((-100.29357 25.64128, -100.29339 25.6...
# 1  8b48a20296a6fff   11  POLYGON ((-100.30220 25.63975, -100.30201 25.6...
# 2  8b48a202ba0afff   11  POLYGON ((-100.29585 25.64177, -100.29567 25.6...
# 3  8b48a202baa5fff   11  POLYGON ((-100.29320 25.64050, -100.29302 25.6...
# 4  8b48a20296a5fff   11  POLYGON ((-100.30312 25.63985, -100.30294 25.6...
#
#    aluminio  baterias    carton   cenizas  ceramica  electronica  escombros  \
# 0 -0.331826 -0.103882  1.561420 -0.127573 -0.329080    -0.220429   4.817522
# 1  3.360970 -0.103882  2.340051 -0.127573  0.665238     2.257194  -0.034706
# 2 -0.331826 -0.103882  0.393472 -0.127573 -0.329080    -0.220429   5.874443
# 3 -0.331826 -0.103882 -0.385159 -0.127573  0.665238    -0.220429   9.621708
# 4  3.360970 -0.103882  2.729367 -0.127573  0.665238    -0.220429   0.061377
#
#    ...  plastico  salud e higiene    tabaco       tela    unicel    vidrio  \
# 0  ...  2.010942         0.588397 -0.455406  12.467905  0.009714 -0.009600
# 1  ...  3.213488         2.034515 -0.455406   2.349179  4.376961  4.879613
# 2  ...  2.508966         1.070436 -0.455406   3.513925  0.646604  1.676336
# 3  ...  1.792298        -0.375682 -0.455406   1.621214  0.009714  1.676336
# 4  ...  3.444279         2.034515  0.667129   0.529265  2.830228  0.833368
#
#         epi  total_points  most_common_point       cluster
# 0 -0.167765         656.0           Plastico  {(9, 25): 1}
# 1 -0.167765         517.0           Plastico  {(18, 3): 3}
# 2 -0.167765         490.0           Plastico  {(18, 4): 1}
# 3 -0.167765         452.0          Escombros  {(43, 0): 1}
# 4  4.546442         430.0           Plastico  {(43, 1): 3}
#
# [5 rows x 28 columns]

# %%
data_material_11['cluster']
# Out:
# 0      {(9, 25): 1}
# 1      {(18, 3): 3}
# 2      {(18, 4): 1}
# 3      {(43, 0): 1}
# 4      {(43, 1): 3}
#            ...
# 415             NaN
# 416             NaN
# 417             NaN
# 418             NaN
# 419             NaN
# Name: cluster, Length: 420, dtype: object

# %%
pd.isna(data_material_11).sum( )
# Out:
# hex_id                 0
# res                    0
# geometry               0
# aluminio               0
# baterias               0
# carton                 0
# cenizas                0
# ceramica               0
# electronica            0
# escombros              0
# goma                   0
# llantas                0
# madera                 0
# metal                  0
# organico               0
# otros                  0
# papel                  0
# pesca                  0
# plastico               0
# salud e higiene        0
# tabaco                 0
# tela                   0
# unicel                 0
# vidrio                 0
# epi                    0
# total_points           0
# most_common_point      0
# cluster              358
# dtype: int64

# %% [markdown]
# ### Res 10

# %%
data_material_10 = data_material[data_material['res'] == 10].copy()
print(data_material_10.shape)
data_material_10.head(2)
# Out:
# (142, 27)
#             hex_id  res                                           geometry  \
# 0  8a48a20296a7fff   10  POLYGON ((-100.30269 25.63956, -100.30201 25.6...
# 1  8a48a202978ffff   10  POLYGON ((-100.30331 25.63839, -100.30263 25.6...
#
#     aluminio  baterias     carton   cenizas  ceramica  electronica  escombros  \
# 0  11.669761 -0.103882  13.630210 -0.127573  9.614101     2.257194   0.782005
# 1   8.900164 -0.103882   4.675946  7.838651  1.659556     4.734816   0.974173
#
#    ...     pesca   plastico  salud e higiene    tabaco      tela     unicel  \
# 0  ... -0.134595  14.206453        13.603459  6.841071  5.843415  18.570515
# 1  ... -0.134595   8.837513         5.408790  3.473467  5.625026   4.922867
#
#       vidrio       epi  total_points  most_common_point
# 0  14.658037  4.546442        1918.0           Plastico
# 1   4.036645 -0.167765        1122.0           Plastico
#
# [2 rows x 27 columns]

# %% [markdown]
# ## Material Quantity

# %% [markdown]
# ### Res 11

# %% [markdown]
# ### Res 10
