# %% [markdown]
# ### Libraries

# %%
import geopandas as gpd
from geopandas.tools import overlay
import matplotlib.pyplot as plt
import os 
import sys
module_path = os.path.abspath(os.path.join('../../'))
if module_path not in sys.path:
    sys.path.append(module_path)
    import aup
# Out:
# /tmp/ipykernel_5086/3924256960.py:1: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /opt/conda/lib/python3.10/site-packages/osmnx/utils.py:192: UserWarning: The `utils.config` function is deprecated and will be removed in a future release. Instead, use the `settings` module directly to configure a global setting's value. For example, `ox.settings.log_console=True`.
#   warnings.warn(

# %% [markdown]
# ### GeoDataFrame Object of 'Espacios Públicos en CDMX'

# %%
schema = 'espacios_publicos'
table = 'ep_cdmx'
gdf = aup.gdf_from_db(table,schema)
gdf.head()
# Out:
#   id                  geo_point_2d  \
# 0  0  19.4877568178,-99.2060645931
# 1  1   19.3887689803,-99.116393168
# 2  2  19.3928871121,-99.0869912505
# 3  3   19.383106069,-99.1073609486
# 4  4  19.3822134465,-99.1028423436
#
#                                            geo_shape  \
# 0  {'type': 'MultiPolygon', 'coordinates': [[[[-9...
# 1  {'type': 'MultiPolygon', 'coordinates': [[[[-9...
# 2  {'type': 'MultiPolygon', 'coordinates': [[[[-9...
# 3  {'type': 'MultiPolygon', 'coordinates': [[[[-9...
# 4  {'type': 'MultiPolygon', 'coordinates': [[[[-9...
#
#                          subcat_sed subcve_sed  gid cve_delg    delegacion  \
# 0                         Panteones        604  268        2  Azcapotzalco
# 1                        Deportivos        601   87        8     Iztacalco
# 2  Camellones centrales y laterales        203  180        8     Iztacalco
# 3           Unidades habitacionales        602   89        8     Iztacalco
# 4           Unidades habitacionales        602   90        8     Iztacalco
#
#                                            categoria   superficie  \
# 0               Equipamientos urbanos con vegetación  6660.027554
# 1               Equipamientos urbanos con vegetación  2917.257837
# 2  Áreas verdes complementarias o ligadas a la re...  1086.305646
# 3               Equipamientos urbanos con vegetación  3605.704046
# 4               Equipamientos urbanos con vegetación  19619.36158
#
#      perimetro cve_sedema                                           geometry
# 0   329.264738        600  POLYGON ((-99.20639 19.48819, -99.20556 19.487...
# 1  272.2436142        600  POLYGON ((-99.11679 19.38904, -99.11637 19.388...
# 2  425.0436555        200  POLYGON ((-99.08651 19.39367, -99.08648 19.393...
# 3  269.2094365        600  POLYGON ((-99.10780 19.38333, -99.10688 19.383...
# 4  798.4092267        600  POLYGON ((-99.10389 19.38315, -99.10355 19.383...

# %%
gdf.shape
# Out:
# (11609, 13)

# %%
gdf['subcat_sed'].unique()
# Out:
# array(['Panteones', 'Deportivos', 'Camellones centrales y laterales',
#        'Unidades habitacionales', 'Instituciones académicas públicas',
#        'Plazas', 'Asistencia Social con vegetación CDMX', 'Parques',
#        'Veg. Arbórea, arbustiva y herbácea de glorietas', 'Vialidades',
#        'Instituciones académicas privadas', 'Arboledas',
#        'Instituciones de salud pub/priv', 'Jardines públicos', 'Canales',
#        'Jardineras públicas y privadas', 'Azoteas verdes', 'Bordos',
#        'Terrenos baldíos', 'AVA', 'Depresiones orográficas', 'ANP',
#        'Alamedas', 'Promontorios', 'Colinas', 'Cerros',
#        'Zona de recarga de manto acuíferos'], dtype=object)

# %% [markdown]
# ### Plot'Espacios Públicos'

# %%
#gdf.plot()
f, axx = plt.subplots(1, figsize=(8, 8))
axx = gdf.plot(axes=axx, alpha=1)
#gdf.xlim(-103.8, -102.8)
#gdf.ylim(20.3, 21)
plt.show()
#trabajar con resolución 11
#city: gdl
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/plotting.py:649: FutureWarning: 'axes' is deprecated, please use 'ax' instead (for consistency with pandas)
#   warnings.warn(

# %% [markdown]
# ### GeoDataFrame Object of 'CDMX' in Hexagons

# %%
hex_schema = "hexgrid"
hex_table = "hexgrid_8_city"
c = 'ZMVM'
query = f'SELECT * FROM {hex_schema}.{hex_table} WHERE \"metropolis\" LIKE \'{c}\''
hex_cdmx = aup.gdf_from_query(query, geometry_col='geometry')
hex_cdmx
# Out:
#                                                geometry         hex_id_8  \
# 0     POLYGON ((-99.17740 19.48241, -99.17776 19.487...  884995b8c1fffff
# 1     POLYGON ((-99.15333 19.47646, -99.15369 19.481...  884995b817fffff
# 2     POLYGON ((-99.17559 19.45667, -99.17107 19.459...  884995baa5fffff
# 3     POLYGON ((-99.14917 19.48454, -99.15369 19.481...  884995b83bfffff
# 4     POLYGON ((-99.16726 19.47282, -99.16274 19.475...  884995b813fffff
# ...                                                 ...              ...
# 9023  POLYGON ((-99.05470 19.69090, -99.05958 19.693...  884995a9a5fffff
# 9024  POLYGON ((-99.06198 19.65930, -99.05744 19.662...  884995a9e5fffff
# 9025  POLYGON ((-99.04945 19.68353, -99.05434 19.685...  88499506d3fffff
# 9026  POLYGON ((-99.05994 19.69828, -99.06483 19.700...  884995a9a7fffff
# 9027  POLYGON ((-99.05470 19.69090, -99.05016 19.693...  884995069bfffff
#
#      CVEGEO metropolis
# 0     09002       ZMVM
# 1     09002       ZMVM
# 2     09002       ZMVM
# 3     09002       ZMVM
# 4     09002       ZMVM
# ...     ...        ...
# 9023  15125       ZMVM
# 9024  15125       ZMVM
# 9025  15125       ZMVM
# 9026  15125       ZMVM
# 9027  15125       ZMVM
#
# [9028 rows x 4 columns]

# %% [markdown]
# Solo Distrito Federal

# %%
selected_values = ['09002', '09003', '09004', '09005', '09006', '09007', '09008', '09009', '09010', '09011', '09012', '09013', '09014', '09015', '09016', '09017']
hex_cdmx = hex_cdmx[hex_cdmx['CVEGEO'].isin(selected_values)]
hex_cdmx['CVEGEO'].unique()
# Out:
# array(['09002', '09003', '09004', '09005', '09006', '09007', '09008',
#        '09009', '09010', '09011', '09012', '09013', '09014', '09015',
#        '09016', '09017'], dtype=object)

# %% [markdown]
# ### Plot 'Hexagons-CDMX'

# %%
f, ax = plt.subplots(1, figsize=(8, 8))
ax = hex_cdmx.plot(axes=ax, cmap = 'viridis',alpha= 1)
plt.show()

# %%
import leafmap

# %% [markdown]
# ### Intersección Espacial

# %%
m = leafmap.Map()
m.add_gdf(gdf, layer_name="Espacios públicos", zoom_to_layer=True)
m.add_gdf(hex_cdmx, layer_name="Hexagonos")
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
#Segundo paso: Ver variables dependientes para el modelo de predicción
