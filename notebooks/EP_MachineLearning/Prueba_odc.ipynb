# %%
pip install odc
# Out:
# Collecting odc
#   Downloading odc-0.1.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting GeoAlchemy2<0.16.0,>=0.15.2 (from odc)
#   Downloading GeoAlchemy2-0.15.2-py3-none-any.whl.metadata (2.1 kB)
# Collecting SQLAlchemy<3.0.0,>=2.0.35 (from odc)
#   Downloading SQLAlchemy-2.0.36-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Collecting func-timeout<5.0.0,>=4.3.5 (from odc)
#   Using cached func_timeout-4.3.5.tar.gz (44 kB)
#   Preparing metadata (setup.py) ... done
# Collecting geopandas<2.0.0,>=1.0.1 (from odc)
#   Downloading geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting h3<4.0.0,>=3.7.7 (from odc)
#   Downloading h3-3.7.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting igraph<0.12.0,>=0.11.6 (from odc)
#   Downloading igraph-0.11.8-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting matplotlib<4.0.0,>=3.9.2 (from odc)
#   Downloading matplotlib-3.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting networkx<4.0,>=3.3 (from odc)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting numpy<3.0.0,>=2.1.1 (from odc)
#   Downloading numpy-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 241.5 kB/s eta 0:00:0000:0100:01
# Collecting pandas<3.0.0,>=2.2.2 (from odc)
#   Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 667.7 kB/s eta 0:00:00a 0:00:01
# Collecting planetary-computer<2.0.0,>=1.0.0 (from odc)
#   Downloading planetary_computer-1.0.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting psycopg2-binary<3.0.0,>=2.9.9 (from odc)
#   Downloading psycopg2_binary-2.9.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting pymannkendall<2.0.0,>=1.4.3 (from odc)
#   Using cached pymannkendall-1.4.3-py3-none-any.whl.metadata (14 kB)
# Collecting pyproj<4.0.0,>=3.6.1 (from odc)
#   Downloading pyproj-3.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting pystac<2.0.0,>=1.10.1 (from odc)
#   Downloading pystac-1.11.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting pystac-client<0.9.0,>=0.8.3 (from odc)
#   Downloading pystac_client-0.8.5-py3-none-any.whl.metadata (5.1 kB)
# Collecting python-dateutil<3.0.0,>=2.9.0.post0 (from odc)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting python-dotenv<2.0.0,>=1.0.1 (from odc)
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting rasterio<2.0.0,>=1.3.11 (from odc)
#   Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting scikit-learn<2.0.0,>=1.5.2 (from odc)
#   Downloading scikit_learn-1.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting scipy<2.0.0,>=1.14.1 (from odc)
#   Downloading scipy-1.15.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 677.6 kB/s eta 0:00:000:0100:01
# Collecting shapely<3.0.0,>=2.0.6 (from odc)
#   Downloading shapely-2.0.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting tqdm<5.0.0,>=4.66.5 (from odc)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 740.1 kB/s eta 0:00:00 0:00:01m
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from GeoAlchemy2<0.16.0,>=0.15.2->odc) (23.2)
# Collecting pyogrio>=0.7.2 (from geopandas<2.0.0,>=1.0.1->odc)
#   Downloading pyogrio-0.10.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting texttable>=1.6.2 (from igraph<0.12.0,>=0.11.6->odc)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib<4.0.0,>=3.9.2->odc)
#   Downloading contourpy-1.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib<4.0.0,>=3.9.2->odc)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib<4.0.0,>=3.9.2->odc)
#   Downloading fonttools-4.55.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (165 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.1/165.1 kB 1.1 MB/s eta 0:00:0000:0100:01
# Collecting kiwisolver>=1.3.1 (from matplotlib<4.0.0,>=3.9.2->odc)
#   Downloading kiwisolver-1.4.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Collecting pillow>=8 (from matplotlib<4.0.0,>=3.9.2->odc)
#   Downloading pillow-11.1.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib<4.0.0,>=3.9.2->odc)
#   Downloading pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas<3.0.0,>=2.2.2->odc) (2023.3.post1)
# Collecting tzdata>=2022.7 (from pandas<3.0.0,>=2.2.2->odc)
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting click>=7.1 (from planetary-computer<2.0.0,>=1.0.0->odc)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting pydantic>=1.7.3 (from planetary-computer<2.0.0,>=1.0.0->odc)
#   Downloading pydantic-2.10.4-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: requests>=2.25.1 in /opt/conda/lib/python3.11/site-packages (from planetary-computer<2.0.0,>=1.0.0->odc) (2.31.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from pyproj<4.0.0,>=3.6.1->odc) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.9.0.post0->odc) (1.16.0)
# Collecting affine (from rasterio<2.0.0,>=1.3.11->odc)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /opt/conda/lib/python3.11/site-packages (from rasterio<2.0.0,>=1.3.11->odc) (23.1.0)
# Collecting cligj>=0.5 (from rasterio<2.0.0,>=1.3.11->odc)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting click-plugins (from rasterio<2.0.0,>=1.3.11->odc)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Collecting joblib>=1.2.0 (from scikit-learn<2.0.0,>=1.5.2->odc)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn<2.0.0,>=1.5.2->odc)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/conda/lib/python3.11/site-packages (from SQLAlchemy<3.0.0,>=2.0.35->odc) (4.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from SQLAlchemy<3.0.0,>=2.0.35->odc) (3.0.0)
# Collecting annotated-types>=0.6.0 (from pydantic>=1.7.3->planetary-computer<2.0.0,>=1.0.0->odc)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic>=1.7.3->planetary-computer<2.0.0,>=1.0.0->odc)
#   Downloading pydantic_core-2.27.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting typing-extensions>=4.6.0 (from SQLAlchemy<3.0.0,>=2.0.35->odc)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: jsonschema~=4.18 in /opt/conda/lib/python3.11/site-packages (from pystac[validation]>=1.10.0->pystac-client<0.9.0,>=0.8.3->odc) (4.19.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.25.1->planetary-computer<2.0.0,>=1.0.0->odc) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.25.1->planetary-computer<2.0.0,>=1.0.0->odc) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.25.1->planetary-computer<2.0.0,>=1.0.0->odc) (2.0.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.11/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client<0.9.0,>=0.8.3->odc) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.11/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client<0.9.0,>=0.8.3->odc) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client<0.9.0,>=0.8.3->odc) (0.10.6)
# Downloading odc-0.1.0-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 724.2 kB/s eta 0:00:000:00:01
# Downloading GeoAlchemy2-0.15.2-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.6/323.6 kB 1.2 MB/s eta 0:00:0000:0100:01
# Downloading h3-3.7.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 1.9 MB/s eta 0:00:0000:0100:01
# Downloading igraph-0.11.8-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 3.3 MB/s eta 0:00:0000:0100:01
# Downloading matplotlib-3.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 7.2 MB/s eta 0:00:0000:0100:01
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 9.4 MB/s eta 0:00:00:00:0100:01
# Downloading numpy-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 8.9 MB/s eta 0:00:0000:0100:01m
# Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 9.2 MB/s eta 0:00:0000:0100:01
# Downloading planetary_computer-1.0.0-py3-none-any.whl (14 kB)
# Downloading psycopg2_binary-2.9.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 8.5 MB/s eta 0:00:00:00:010:01m
# Using cached pymannkendall-1.4.3-py3-none-any.whl (12 kB)
# Downloading pyproj-3.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 9.3 MB/s eta 0:00:0000:0100:01m
# Downloading pystac-1.11.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 5.5 MB/s eta 0:00:00
# Downloading pystac_client-0.8.5-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 1.4 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 5.9 MB/s eta 0:00:00:00:01
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 9.2 MB/s eta 0:00:00:00:0100:01
# Downloading scikit_learn-1.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 9.0 MB/s eta 0:00:0000:0100:01
# Downloading scipy-1.15.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (40.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 MB 9.4 MB/s eta 0:00:00:00:0100:01
# Downloading shapely-2.0.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 11.0 MB/s eta 0:00:0000:0100:01
# Downloading SQLAlchemy-2.0.36-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 8.6 MB/s eta 0:00:00:00:0100:01
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 1.6 MB/s eta 0:00:00ta 0:00:01
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading contourpy-1.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (326 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.2/326.2 kB 4.0 MB/s eta 0:00:00ta 0:00:01
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.55.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 10.3 MB/s eta 0:00:0000:0100:01
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 3.9 MB/s eta 0:00:00:00:01
# Downloading kiwisolver-1.4.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 7.7 MB/s eta 0:00:00:00:0100:01
# Downloading pillow-11.1.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 9.9 MB/s eta 0:00:00:00:0100:01
# Downloading pydantic-2.10.4-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.8/431.8 kB 6.0 MB/s eta 0:00:00:00:01
# Downloading pydantic_core-2.27.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 8.5 MB/s eta 0:00:00:00:0100:01
# Downloading pyogrio-0.10.0-cp311-cp311-manylinux_2_28_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 9.1 MB/s eta 0:00:00:00:0100:01
# Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 2.8 MB/s eta 0:00:00ta 0:00:01
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 5.2 MB/s eta 0:00:00ta 0:00:01
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Building wheels for collected packages: func-timeout
#   Building wheel for func-timeout (setup.py) ... done
#   Created wheel for func-timeout: filename=func_timeout-4.3.5-py3-none-any.whl size=15080 sha256=946769063e8098152b1f48795af7555f2882a4bf0cc87407cb963b2e265f4e60
#   Stored in directory: /home/jovyan/.cache/pip/wheels/07/e6/86/f23164d12c3134966614102db8e7956ab359faf7ffd78703ce
# Successfully built func-timeout
# Installing collected packages: texttable, h3, func-timeout, tzdata, typing-extensions, tqdm, threadpoolctl, python-dotenv, python-dateutil, pyproj, pyparsing, psycopg2-binary, pillow, numpy, networkx, kiwisolver, joblib, igraph, fonttools, cycler, click, annotated-types, affine, SQLAlchemy, shapely, scipy, pystac, pyogrio, pydantic-core, pandas, contourpy, cligj, click-plugins, scikit-learn, rasterio, pymannkendall, pydantic, matplotlib, geopandas, GeoAlchemy2, pystac-client, planetary-computer, odc
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.8.0
#     Uninstalling typing_extensions-4.8.0:
#       Successfully uninstalled typing_extensions-4.8.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.2
#     Uninstalling python-dateutil-2.8.2:
#       Successfully uninstalled python-dateutil-2.8.2
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.22
#     Uninstalling SQLAlchemy-2.0.22:
#       Successfully uninstalled SQLAlchemy-2.0.22
# Successfully installed GeoAlchemy2-0.15.2 SQLAlchemy-2.0.36 affine-2.4.0 annotated-types-0.7.0 click-8.1.8 click-plugins-1.1.1 cligj-0.7.2 contourpy-1.3.1 cycler-0.12.1 fonttools-4.55.3 func-timeout-4.3.5 geopandas-1.0.1 h3-3.7.7 igraph-0.11.8 joblib-1.4.2 kiwisolver-1.4.8 matplotlib-3.10.0 networkx-3.4.2 numpy-2.2.1 odc-0.1.0 pandas-2.2.3 pillow-11.1.0 planetary-computer-1.0.0 psycopg2-binary-2.9.10 pydantic-2.10.4 pydantic-core-2.27.2 pymannkendall-1.4.3 pyogrio-0.10.0 pyparsing-3.2.1 pyproj-3.7.0 pystac-1.11.0 pystac-client-0.8.5 python-dateutil-2.9.0.post0 python-dotenv-1.0.1 rasterio-1.4.3 scikit-learn-1.6.0 scipy-1.15.0 shapely-2.0.6 texttable-1.7.0 threadpoolctl-3.5.0 tqdm-4.67.1 typing-extensions-4.12.2 tzdata-2024.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install osmnx
# Out:
# Collecting osmnx
#   Downloading osmnx-2.0.1-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: geopandas>=1.0 in /opt/conda/lib/python3.11/site-packages (from osmnx) (1.0.1)
# Requirement already satisfied: networkx>=2.5 in /opt/conda/lib/python3.11/site-packages (from osmnx) (3.4.2)
# Requirement already satisfied: numpy>=1.22 in /opt/conda/lib/python3.11/site-packages (from osmnx) (2.2.1)
# Requirement already satisfied: pandas>=1.4 in /opt/conda/lib/python3.11/site-packages (from osmnx) (2.2.3)
# Requirement already satisfied: requests>=2.27 in /opt/conda/lib/python3.11/site-packages (from osmnx) (2.31.0)
# Requirement already satisfied: shapely>=2.0 in /opt/conda/lib/python3.11/site-packages (from osmnx) (2.0.6)
# Requirement already satisfied: pyogrio>=0.7.2 in /opt/conda/lib/python3.11/site-packages (from geopandas>=1.0->osmnx) (0.10.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from geopandas>=1.0->osmnx) (23.2)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/conda/lib/python3.11/site-packages (from geopandas>=1.0->osmnx) (3.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.4->osmnx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.4->osmnx) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.4->osmnx) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.27->osmnx) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.27->osmnx) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.27->osmnx) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests>=2.27->osmnx) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.4->osmnx) (1.16.0)
# Downloading osmnx-2.0.1-py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.6/99.6 kB 909.6 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: osmnx
# Successfully installed osmnx-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
    import osmnx as ox
    import geopandas as gpd
    import numpy as np
    import odc

# %%
# Example: Using functions to download and process an OSMnx network, and analyze POIs
def main():
    # Step 1: Define an area of interest (AOI)
    # Create a GeoDataFrame representing the boundary of the city (for example, using a polygon)
    polygon = gpd.GeoDataFrame.from_file("../data/raw/city_boundary.geojson").unary_union
    city = "ExampleCity"
    
    # Step 2: Create the network using the create_osmnx_network function
    print("\n--- Creating OSMnx Network ---")
    G, nodes, edges = odc.create_osmnx_network(
        aoi=gpd.GeoDataFrame(geometry=[polygon]),
        how="from_polygon",
        network_type="walk"
        )
    
    # Step 3: Download or retrieve the graph
    print("\n--- Downloading Graph ---")
    graph = odc.download_graph(polygon, city, network_type="walk", save=True)
    
    # Step 4: Define points of interest (POIs)
    # Load POIs as a GeoDataFrame (example file with POIs for the city)
    pois = gpd.read_file("../data/raw/pois.geojson")
    
    # Step 5: Analyze time to nearest POI using pois_time
    print("\n--- Calculating Time to POIs ---")
    walking_speed = walking_speed  # in km/hr
    proximity_measure = "time_min"
    pois_name = "amenity_shop"

    nodes_with_time = odc.pois_time(
        G=graph,
        nodes=nodes,
        edges=edges,
        pois=pois,
        pois_name=pois_name,
        prox_measure=proximity_measure,
        walking_speed=walking_speed,
        count_pois=(True, 10),  # Count POIs within a 10-minute range
        projected_crs="EPSG:6372",
        preprocessed_nearest=(False, "")
    )

    # Save results to a file for further analysis
    print("\n--- Saving Results ---")
    nodes_with_time.to_file(f"../data/processed/nodes_with_{poi_name}_time.geojson", driver="GeoJSON")


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[7], line 49
#      45     nodes_with_time.to_file(f"../data/processed/nodes_with_{poi_name}_time.geojson", driver="GeoJSON")
#      48 if __name__ == "__main__":
# ---> 49     main()
#
# Cell In[7], line 5, in main()
#       2 def main():
#       3     # Step 1: Define an area of interest (AOI)
#       4     # Create a GeoDataFrame representing the boundary of the city (for example, using a polygon)
# ----> 5     polygon = gpd.GeoDataFrame.from_file("../data/raw/city_boundary.geojson").unary_union
#       6     city = "ExampleCity"
#       8     # Step 2: Create the network using the create_osmnx_network function
#
# File /opt/conda/lib/python3.11/site-packages/geopandas/geodataframe.py:658, in GeoDataFrame.from_file(cls, filename, **kwargs)
#     609 @classmethod
#     610 def from_file(cls, filename, **kwargs):
#     611     """Alternate constructor to create a ``GeoDataFrame`` from a file.
#     612
#     613     It is recommended to use :func:`geopandas.read_file` instead.
#    (...)
#     656
#     657     """
# --> 658     return geopandas.io.file._read_file(filename, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/geopandas/io/file.py:294, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     291             from_bytes = True
#     293 if engine == "pyogrio":
# --> 294     return _read_file_pyogrio(
#     295         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     296     )
#     298 elif engine == "fiona":
#     299     if pd.api.types.is_file_like(filename):
#
# File /opt/conda/lib/python3.11/site-packages/geopandas/io/file.py:547, in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     538     warnings.warn(
#     539         "The 'include_fields' and 'ignore_fields' keywords are deprecated, and "
#     540         "will be removed in a future release. You can use the 'columns' keyword "
#    (...)
#     543         stacklevel=3,
#     544     )
#     545     kwargs["columns"] = kwargs.pop("include_fields")
# --> 547 return pyogrio.read_dataframe(path_or_bytes, bbox=bbox, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/pyogrio/geopandas.py:265, in read_dataframe(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, fid_as_index, use_arrow, on_invalid, arrow_to_pandas_kwargs, **kwargs)
#     260 if not use_arrow:
#     261     # For arrow, datetimes are read as is.
#     262     # For numpy IO, datetimes are read as string values to preserve timezone info
#     263     # as numpy does not directly support timezones.
#     264     kwargs["datetime_as_string"] = True
# --> 265 result = read_func(
#     266     path_or_buffer,
#     267     layer=layer,
#     268     encoding=encoding,
#     269     columns=columns,
#     270     read_geometry=read_geometry,
#     271     force_2d=gdal_force_2d,
#     272     skip_features=skip_features,
#     273     max_features=max_features,
#     274     where=where,
#     275     bbox=bbox,
#     276     mask=mask,
#     277     fids=fids,
#     278     sql=sql,
#     279     sql_dialect=sql_dialect,
#     280     return_fids=fid_as_index,
#     281     **kwargs,
#     282 )
#     284 if use_arrow:
#     285     meta, table = result
#
# File /opt/conda/lib/python3.11/site-packages/pyogrio/raw.py:198, in read(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, return_fids, datetime_as_string, **kwargs)
#      59 """Read OGR data source into numpy arrays.
#      60
#      61 IMPORTANT: non-linear geometry types (e.g., MultiSurface) are converted
#    (...)
#     194
#     195 """
#     196 dataset_kwargs = _preprocess_options_key_value(kwargs) if kwargs else {}
# --> 198 return ogr_read(
#     199     get_vsi_path_or_buffer(path_or_buffer),
#     200     layer=layer,
#     201     encoding=encoding,
#     202     columns=columns,
#     203     read_geometry=read_geometry,
#     204     force_2d=force_2d,
#     205     skip_features=skip_features,
#     206     max_features=max_features or 0,
#     207     where=where,
#     208     bbox=bbox,
#     209     mask=_mask_to_wkb(mask),
#     210     fids=fids,
#     211     sql=sql,
#     212     sql_dialect=sql_dialect,
#     213     return_fids=return_fids,
#     214     dataset_kwargs=dataset_kwargs,
#     215     datetime_as_string=datetime_as_string,
#     216 )
#
# File pyogrio/_io.pyx:1240, in pyogrio._io.ogr_read()
#
# File pyogrio/_io.pyx:220, in pyogrio._io.ogr_open()
#
# DataSourceError: ../data/raw/city_boundary.geojson: No such file or directory
