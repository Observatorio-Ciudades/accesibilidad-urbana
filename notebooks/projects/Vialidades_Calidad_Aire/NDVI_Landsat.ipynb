# %%
# Aguascalientes
import pandas as pd
import geopandas as gpd

import os
import sys
module_path = os.path.abspath(os.path.join('../../../'))
if module_path not in sys.path:
    sys.path.append(module_path)
    import aup
# Out:
# /Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/data.py:24: FutureWarning: The `utils.config` function is deprecated and will be removed in the v2.0.0 release. Instead, use the `settings` module directly to configure a global setting's value. For example, `ox.settings.log_console=True`.
#   ox.config(

# %%
gdf = gpd.read_file('../../../data/external/Aguascalientes_poligono.shp') #Pongo la shape de Aguascalientes
print(gdf.shape)
gdf.plot()
# Out:
# (350, 8)
# <AxesSubplot:>

# %%
gdf = gdf.to_crs("EPSG:4326")

# %%
band_name_dict = {'nir08':[False],
                      'red':[False],
                 'eq':["(nir08-red)/(nir08+red)"]}
index_analysis = 'ndvi'
tmp_dir = f'../../../data/processed/temp_{index_analysis}/'
res = [8,11] # 8, 11
freq = 'MS'
start_date = '2010-01-01'
end_date = '2010-12-31'
satellite = "landsat-c2-l2"
save = False # True
del_data = False # True
city = 'Aguascalientes'
query = {"eo:cloud_cover": {"lt": 10},
        "platform": {"in": ["landsat-7"]}}

# %%
df_len = aup.download_raster_from_pc(gdf, index_analysis, city, freq,
                                        start_date, end_date, tmp_dir, 
                                     band_name_dict,query=query,satellite=satellite)
# Out:
#   0%|                                                                                            | 0/12 [00:00<?, ?it/s]/Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:763: RuntimeWarning: overflow encountered in cast
#   raster_array[b][0] = raster_array[b][0].astype('float16')
# /Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:763: RuntimeWarning: overflow encountered in cast
#   raster_array[b][0] = raster_array[b][0].astype('float16')
# /Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:763: RuntimeWarning: overflow encountered in cast
#   raster_array[b][0] = raster_array[b][0].astype('float16')
# /Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:763: RuntimeWarning: overflow encountered in cast
#   raster_array[b][0] = raster_array[b][0].astype('float16')
# ...

# %%
band_name_dict = {'nir08':[False],
                      'red':[False],
                 'eq':["(nir08-red)/(nir08+red)"]}
index_analysis = 'ndvi'
tmp_dir = f'../../../data/processed/temp_{index_analysis}/'
res = [8,11] # 8, 11
freq = 'MS'
start_date = '2020-01-01'
end_date = '2020-12-31'
satellite = "landsat-c2-l2"
save = False # True
del_data = False # True
city = 'Aguascalientes2020'
query = {"eo:cloud_cover": {"lt": 10},
        "platform": {"in": ["landsat-8"]}}

# %%
df_len = aup.download_raster_from_pc(gdf, index_analysis, city, freq,
                                        start_date, end_date, tmp_dir, 
                                     band_name_dict,query=query,satellite=satellite)
# Out:
# ...
# 100%|██████████████████████████████████████████| 12/12 [29:50<00:00, 149.20s/it]

# %%
# Querétaro
import pandas as pd
import geopandas as gpd

import os
import sys
module_path = os.path.abspath(os.path.join('../../../'))
if module_path not in sys.path:
    sys.path.append(module_path)
    import aup

# %%
gdf = gpd.read_file('../../../data/external/Queretaro_poligono.shp') #Pongo la shape de Aguascalientes
print(gdf.shape)
gdf.plot()
# Out:
# (407, 8)
# <AxesSubplot:>

# %%
gdf = gdf.to_crs("EPSG:4326")

# %%
band_name_dict = {'nir08':[False],
                      'red':[False],
                 'eq':["(nir08-red)/(nir08+red)"]}
index_analysis = 'ndvi'
tmp_dir = f'../../../data/processed/temp_{index_analysis}/'
res = [8,11] # 8, 11
freq = 'MS'
start_date = '2010-01-01'
end_date = '2010-12-31'
satellite = "landsat-c2-l2"
save = False # True
del_data = False # True
city = 'Queretaro'
query = {"eo:cloud_cover": {"lt": 50},
        "platform": {"in": ["landsat-7"]}}

# %%
df_len = aup.download_raster_from_pc(gdf, index_analysis, city, freq,
                                        start_date, end_date, tmp_dir, 
                                     band_name_dict,query=query,satellite=satellite)
# Out:
#   0%|                                                    | 0/12 [00:00<?, ?it/s]/Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:763: RuntimeWarning: overflow encountered in cast
#   raster_array[b][0] = raster_array[b][0].astype('float16')
# /Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:763: RuntimeWarning: overflow encountered in cast
#   raster_array[b][0] = raster_array[b][0].astype('float16')
#   8%|███▋                                        | 1/12 [01:13<13:33, 73.93s/it]/Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:763: RuntimeWarning: overflow encountered in cast
#   raster_array[b][0] = raster_array[b][0].astype('float16')
# /Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:763: RuntimeWarning: overflow encountered in cast
#   raster_array[b][0] = raster_array[b][0].astype('float16')
# ...

# %%
band_name_dict = {'nir08':[False],
                      'red':[False],
                 'eq':["(nir08-red)/(nir08+red)"]}
index_analysis = 'ndvi'
tmp_dir = f'../../../data/processed/temp_{index_analysis}/'
res = [8,11] # 8, 11
freq = 'MS'
start_date = '2020-01-01'
end_date = '2020-12-31'
satellite = "landsat-c2-l2"
save = False # True
del_data = False # True
city = 'Queretaro2020'
query = {"eo:cloud_cover": {"lt": 20},
        "platform": {"in": ["landsat-8"]}}

# %%
df_len = aup.download_raster_from_pc(gdf, index_analysis, city, freq,
                                        start_date, end_date, tmp_dir, 
                                     band_name_dict,query=query,satellite=satellite)
# Out:
# ...
# 100%|███████████████████████████████████████████| 12/12 [14:08<00:00, 70.73s/it]

# %%
# Morelia
gdf = gpd.read_file('../../../data/external/Morelia_poligono.shp') #Pongo la shape de Aguascalientes
print(gdf.shape)
gdf.plot()
# Out:
# (367, 8)
# <AxesSubplot:>

# %%
gdf = gdf.to_crs("EPSG:4326")

# %%
band_name_dict = {'nir08':[False],
                      'red':[False],
                 'eq':["(nir08-red)/(nir08+red)"]}
index_analysis = 'ndvi'
tmp_dir = f'../../../data/processed/temp_{index_analysis}/'
res = [8,11] # 8, 11
freq = 'MS'
start_date = '2010-01-01'
end_date = '2010-12-31'
satellite = "landsat-c2-l2"
save = False # True
del_data = False # True
city = 'Morelia'
query = {"eo:cloud_cover": {"lt": 40},
        "platform": {"in": ["landsat-7"]}}

# %%
df_len = aup.download_raster_from_pc(gdf, index_analysis, city, freq,
                                        start_date, end_date, tmp_dir, 
                                     band_name_dict,query=query,satellite=satellite)
# Out:
#   0%|                                                    | 0/12 [00:00<?, ?it/s]/Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:763: RuntimeWarning: overflow encountered in cast
#   raster_array[b][0] = raster_array[b][0].astype('float16')
# /Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:763: RuntimeWarning: overflow encountered in cast
#   raster_array[b][0] = raster_array[b][0].astype('float16')
#   8%|███▌                                       | 1/12 [01:41<18:34, 101.35s/it]/Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:763: RuntimeWarning: overflow encountered in cast
#   raster_array[b][0] = raster_array[b][0].astype('float16')
# /Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:763: RuntimeWarning: overflow encountered in cast
#   raster_array[b][0] = raster_array[b][0].astype('float16')
# ...

# %%
band_name_dict = {'nir08':[False],
                      'red':[False],
                 'eq':["(nir08-red)/(nir08+red)"]}
index_analysis = 'ndvi'
tmp_dir = f'../../../data/processed/temp_{index_analysis}/'
res = [8,11] # 8, 11
freq = 'MS'
start_date = '2020-01-01'
end_date = '2020-12-31'
satellite = "landsat-c2-l2"
save = False # True
del_data = False # True
city = 'Morelia2020'
query = {"eo:cloud_cover": {"lt": 60},
        "platform": {"in": ["landsat-8"]}}

# %%
df_len = aup.download_raster_from_pc(gdf, index_analysis, city, freq,
                                        start_date, end_date, tmp_dir, 
                                     band_name_dict,query=query,satellite=satellite)
# Out:
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 101.33it/s]
# ---------------------------------------------------------------------------
# AvailableData                             Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df_len = aup.download_raster_from_pc(gdf, index_analysis, city, freq,
#       2                                         start_date, end_date, tmp_dir,
#       3                                      band_name_dict,query=query,satellite=satellite)
#
# File ~/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:163, in download_raster_from_pc(gdf, index_analysis, city, freq, start_date, end_date, tmp_dir, band_name_dict, query, satellite, projection_crs, compute_unavailable_dates)
#     160 if compute_unavailable_dates:
#     161     # Starts raster interpolation by predicting points from existing values and updates missing months percentage
#     162     log('Starting raster interpolation')
# ...

# %%
# San Luis Potosí
gdf = gpd.read_file('../../../data/external/SanLuisPotosi_poligono.shp') #Pongo la shape de Aguascalientes
print(gdf.shape)
gdf.plot()
# Out:
# (451, 8)
# <AxesSubplot:>

# %%
gdf = gdf.to_crs("EPSG:4326")

# %%
band_name_dict = {'nir08':[False],
                      'red':[False],
                 'eq':["(nir08-red)/(nir08+red)"]}
index_analysis = 'ndvi'
tmp_dir = f'../../../data/processed/temp_{index_analysis}/'
res = [8,11] # 8, 11
freq = 'MS'
start_date = '2010-01-01'
end_date = '2010-12-31'
satellite = "landsat-c2-l2"
save = False # True
del_data = False # True
city = 'SanLuisPotosi'
query = {"eo:cloud_cover": {"lt": 10},
        "platform": {"in": ["landsat-7"]}}

# %%
df_len = aup.download_raster_from_pc(gdf, index_analysis, city, freq,
                                        start_date, end_date, tmp_dir, 
                                     band_name_dict,query=query,satellite=satellite)
# Out:
#   0%|                                                                                            | 0/12 [00:00<?, ?it/s]/Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:763: RuntimeWarning: overflow encountered in cast
#   raster_array[b][0] = raster_array[b][0].astype('float16')
# /Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:763: RuntimeWarning: overflow encountered in cast
#   raster_array[b][0] = raster_array[b][0].astype('float16')
#  17%|██████████████                                                                      | 2/12 [01:01<05:08, 30.85s/it]/Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:763: RuntimeWarning: overflow encountered in cast
#   raster_array[b][0] = raster_array[b][0].astype('float16')
# /Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:763: RuntimeWarning: overflow encountered in cast
# ...

# %%
band_name_dict = {'nir08':[False],
                      'red':[False],
                 'eq':["(nir08-red)/(nir08+red)"]}
index_analysis = 'ndvi'
tmp_dir = f'../../../data/processed/temp_{index_analysis}/'
res = [8,11] # 8, 11
freq = 'MS'
start_date = '2020-01-01'
end_date = '2020-12-31'
satellite = "landsat-c2-l2"
save = False # True
del_data = False # True
city = 'SanLuisPotosi2020'
query = {"eo:cloud_cover": {"lt": 10},
        "platform": {"in": ["landsat-8"]}}
query = {"eo:cloud_cover": {"lt": 10},
        "platform": {"in": ["landsat-7"]}}

# %%
df_len = aup.download_raster_from_pc(gdf, index_analysis, city, freq,
                                        start_date, end_date, tmp_dir, 
                                     band_name_dict,query=query,satellite=satellite)
# Out:
#   0%|                                                    | 0/12 [00:00<?, ?it/s]/Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:763: RuntimeWarning: overflow encountered in cast
#   raster_array[b][0] = raster_array[b][0].astype('float16')
#   8%|███▌                                       | 1/12 [02:12<24:20, 132.76s/it]/Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:763: RuntimeWarning: overflow encountered in cast
#   raster_array[b][0] = raster_array[b][0].astype('float16')
# /Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:763: RuntimeWarning: overflow encountered in cast
#   raster_array[b][0] = raster_array[b][0].astype('float16')
#  17%|███████▏                                   | 2/12 [03:44<18:09, 108.91s/it]/Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:763: RuntimeWarning: overflow encountered in cast
# ...

# %%
gdf = gdf.to_crs("EPSG:4326")

# %%
band_name_dict = {'nir08':[False],
                      'red':[False],
                 'eq':["(nir08-red)/(nir08+red)"]}
index_analysis = 'ndvi'
tmp_dir = f'../../../data/processed/temp_{index_analysis}/'
res = [8,11] # 8, 11
freq = 'MS'
start_date = '2010-01-01'
end_date = '2010-12-31'
satellite = "landsat-c2-l2"
save = False # True
del_data = False # True
city = 'Irapuato'
query = {"eo:cloud_cover": {"lt": 10},
        "platform": {"in": ["landsat-7"]}}

# %%
df_len = aup.download_raster_from_pc(gdf, index_analysis, city, freq,
                                        start_date, end_date, tmp_dir, 
                                     band_name_dict,query=query,satellite=satellite)
# Out:
#   0%|                                                                                            | 0/12 [00:00<?, ?it/s]/Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:763: RuntimeWarning: overflow encountered in cast
#   raster_array[b][0] = raster_array[b][0].astype('float16')
# /Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:763: RuntimeWarning: overflow encountered in cast
#   raster_array[b][0] = raster_array[b][0].astype('float16')
#   8%|███████                                                                             | 1/12 [01:20<14:40, 80.05s/it]/Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:763: RuntimeWarning: overflow encountered in cast
#   raster_array[b][0] = raster_array[b][0].astype('float16')
# /Users/eileenyuen/Repos/observatorio_ciudades/accesibilidad-urbana/aup/raster.py:763: RuntimeWarning: overflow encountered in cast
# ...

# %%
# Irapuato 2020

# %%
gdf = gpd.read_file('../../../data/external/Irapuato_poligono.shp') #Pongo la shape de Aguascalientes
print(gdf.shape)
gdf.plot()
# Out:
# (201, 8)
# <AxesSubplot:>

# %%
gdf = gdf.to_crs("EPSG:4326")

# %%
band_name_dict = {'nir08':[False],
                      'red':[False],
                 'eq':["(nir08-red)/(nir08+red)"]}
index_analysis = 'ndvi'
tmp_dir = f'../../../data/processed/temp_{index_analysis}/'
res = [8,11] # 8, 11
freq = 'MS'
start_date = '2020-01-01'
end_date = '2020-12-31'
satellite = "landsat-c2-l2"
save = False # True
del_data = False # True
city = 'Irapuato2020'
query = {"eo:cloud_cover": {"lt": 35},
        "platform": {"in": ["landsat-8"]}}

# %%
df_len = aup.download_raster_from_pc(gdf, index_analysis, city, freq,
                                        start_date, end_date, tmp_dir, 
                                     band_name_dict,query=query,satellite=satellite)
# Out:
# ...
# 100%|███████████████████████████████████████████| 12/12 [13:00<00:00, 65.06s/it]
