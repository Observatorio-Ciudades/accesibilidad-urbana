# %%
import geopandas as gpd
import pandas as pd
import numpy as np

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import os
import sys
module_path = os.path.abspath(os.path.join('../../../'))
if module_path not in sys.path:
    sys.path.append(module_path)
    import aup

# %%
import psycopg2

#Conectar a la base de datos
conn = psycopg2.connect(
    host = "hippocampus.cswst4rid7eb.us-east-2.rds.amazonaws.com",
    database = "postgres",
    user= "odc_writer",
    password = "writejacobs1918"
)

cur = conn.cursor()

#Ejecutar la consulta para obtener los nombres de las columnas
cur.execute("""
    SELECT column_name 
    FROM information_schema.columns 
    WHERE table_schema = 'raster_analysis' 
    AND table_name = 'ndvi_analysis_hex';
""")

#Obtener los resultados
columns = cur.fetchall()

#Imprimir los nombres de las columnas
for column in columns:
    print(column[0])

cur.close()
conn.close()
# Out:
# hex_id
# geometry
# res
# ndvi_mean
# ndvi_std
# ndvi_median
# ndvi_max
# ndvi_min
# ndvi_diff
# ndvi_tend
# city

# %%
hex_schema = "raster_analysis"
hex_tablee = "ndvi_analysis_hex"
hex_id = "hex_id"
c1 = 'Guadalajara'
n = '11'
query_ndvi = f'''
SELECT * FROM {hex_schema}.{hex_tablee} 
WHERE "city" IN ('{c1}') 
AND "res" = {n}
'''
intt_gdl = aup.gdf_from_query(query_ndvi, geometry_col='geometry')
intt_gdl.head(10)
# Out:
#             hex_id                                           geometry  res  \
# 0  8b49aa24c78bfff  POLYGON ((-103.52481 20.48558, -103.52464 20.4...   11
# 1  8b49aa24c448fff  POLYGON ((-103.52520 20.48168, -103.52502 20.4...   11
# 2  8b49aa24c603fff  POLYGON ((-103.52699 20.48649, -103.52681 20.4...   11
# 3  8b49aa24c634fff  POLYGON ((-103.52628 20.48447, -103.52611 20.4...   11
# 4  8b49aa24c4ebfff  POLYGON ((-103.52240 20.48244, -103.52223 20.4...   11
# 5  8b49aa24c7b5fff  POLYGON ((-103.52373 20.48279, -103.52355 20.4...   11
# 6  8b49aa24eb4dfff  POLYGON ((-103.52202 20.48633, -103.52185 20.4...   11
# 7  8b49aa24c72bfff  POLYGON ((-103.52870 20.48295, -103.52852 20.4...   11
# 8  8b49aa24c4ddfff  POLYGON ((-103.52098 20.48306, -103.52081 20.4...   11
# 9  8b49aa24c4c1fff  POLYGON ((-103.52150 20.48236, -103.52133 20.4...   11
#
#    ndvi_mean  ndvi_std  ndvi_median  ndvi_max  ndvi_min  ndvi_diff  ndvi_tend  \
# ...

# %% [markdown]
# ### Download network

# %%
type = "urban"
city = "Guadalajara"
query_urban = f"SELECT * FROM hexgrid.hexgrid_8_city_2020 WHERE \"city\" LIKE \'{city}\' AND \"type\" LIKE \'{type}\'"

# %%
hex_gdf = aup.gdf_from_query(query_urban, geometry_col='geometry')
print(hex_gdf.shape)
hex_gdf.head(2)
# Out:
# (1132, 6)
#           hex_id_8                                           geometry CVEGEO  \
# 0  88498c9421fffff  POLYGON ((-103.28663 20.69309, -103.28209 20.6...  14039
# 1  88498c9405fffff  POLYGON ((-103.30025 20.68392, -103.29571 20.6...  14039
#
#         NOMGEO         city   type
# 0  Guadalajara  Guadalajara  urban
# 1  Guadalajara  Guadalajara  urban

# %%
_, nodes, edges = aup.graph_from_hippo(hex_gdf, schema='osmnx', edges_folder='edges_osmnx_23_line', nodes_folder='nodes_osmnx_23_point')

# %%
print(edges.shape)
edges.head(2)
# Out:
# (414636, 16)
#                                osmid  oneway lanes  name      highway  \
# u          v          key
# 4303977502 4303977514 0    431149558    True  None  None  residential
# 4303977503 4303977514 0    431149502    True  None  None  residential
#
#                           maxspeed   length  \
# u          v          key
# 4303977502 4303977514 0       None  147.496
# 4303977503 4303977514 0       None   49.994
#
#                                                                     geometry  \
# u          v          key
# 4303977502 4303977514 0    LINESTRING (-103.50987 20.45796, -103.51121 20...
# 4303977503 4303977514 0    LINESTRING (-103.51136 20.45798, -103.51121 20...
#
#                           bridge   ref junction tunnel   access width service  \
# u          v          key
# 4303977502 4303977514 0     None  None     None   None  private  None    None
# 4303977503 4303977514 0     None  None     None   None  private  None    None
#
# ...

# %%
edges = edges.reset_index()
edges
# Out:
#                  u           v  key      osmid  oneway lanes  \
# 0       4303977502  4303977514    0  431149558    True  None
# 1       4303977503  4303977514    0  431149502    True  None
# 2       4303977508  4303977503    0  431149546    True  None
# 3       4303977517  4303977508    0  431149546    True  None
# 4       4303977519  4303977505    0  431149521    True  None
# ...            ...         ...  ...        ...     ...   ...
# 414631  8669578133  8432758360    0  908170488   False  None
# 414632  8753025784  1754556621    0  163775733   False  None
# 414633  8760908969  6142976278    0  908170483   False  None
# 414634  8776316843  1754154719    0  163737788    True  None
# 414635  8776316844  1754187546    0  163741839    True  None
#
#                              name      highway maxspeed   length  \
# 0                            None  residential     None  147.496
# 1                            None  residential     None   49.994
# ...

# %% [markdown]
# ### sjoin para edges y ndvi

# %%
intt_gdl = intt_gdl.set_crs("EPSG:4326")
edges = edges.set_crs("EPSG:4326")

# %%
inter_join = gpd.sjoin(edges, intt_gdl, op='intersects')
inter_join.head(3)
# Out:
#                 u           v  key      osmid  oneway lanes  name  \
# 0      4303977502  4303977514    0  431149558    True  None  None
# 64834  4303977499  4303977502    0  901369700    True  None  None
# 64835  4303977500  4303977502    0  901369702   False  None  None
#
#            highway maxspeed   length  ...           hex_id res ndvi_mean  \
# 0      residential     None  147.496  ...  8b49aa241891fff  11  0.195943
# 64834  residential     None   49.115  ...  8b49aa241891fff  11  0.195943
# 64835  residential     None   23.071  ...  8b49aa241891fff  11  0.195943
#
#        ndvi_std ndvi_median  ndvi_max  ndvi_min ndvi_diff ndvi_tend  \
# 0      0.075429    0.180098  0.323646  0.129969  0.193677 -0.001444
# 64834  0.075429    0.180098  0.323646  0.129969  0.193677 -0.001444
# 64835  0.075429    0.180098  0.323646  0.129969  0.193677 -0.001444
#
#         city_right
# 0      Guadalajara
# 64834  Guadalajara
# 64835  Guadalajara
#
# [3 rows x 30 columns]

# %%
# Calcular el promedio de ndvi_mean para cada par único (u, v)
ndvi_mean_grouped = inter_join.groupby(["u", "v"])["ndvi_mean"].mean().reset_index()

ndvi_mean_grouped = ndvi_mean_grouped.rename(columns={"ndvi_mean": "ndvi_mean_mean"})

inter_join = inter_join.merge(ndvi_mean_grouped, on=["u", "v"], how="left")

inter_join.head(3)
# Out:
#             u           v  key      osmid  oneway lanes  name      highway  \
# 0  4303977502  4303977514    0  431149558    True  None  None  residential
# 1  4303977499  4303977502    0  901369700    True  None  None  residential
# 2  4303977500  4303977502    0  901369702   False  None  None  residential
#
#   maxspeed   length  ... res ndvi_mean  ndvi_std ndvi_median  ndvi_max  \
# 0     None  147.496  ...  11  0.195943  0.075429    0.180098  0.323646
# 1     None   49.115  ...  11  0.195943  0.075429    0.180098  0.323646
# 2     None   23.071  ...  11  0.195943  0.075429    0.180098  0.323646
#
#    ndvi_min ndvi_diff ndvi_tend   city_right  ndvi_mean_mean
# 0  0.129969  0.193677 -0.001444  Guadalajara        0.206181
# 1  0.129969  0.193677 -0.001444  Guadalajara        0.228514
# 2  0.129969  0.193677 -0.001444  Guadalajara        0.218842
#
# [3 rows x 31 columns]

# %%
inter_join = inter_join[["hex_id", "geometry", "u", "v", "ndvi_mean", "ndvi_mean_mean"]]
inter_join.head(3)
# Out:
#             hex_id                                           geometry  \
# 0  8b49aa241891fff  LINESTRING (-103.50987 20.45796, -103.51121 20...
# 1  8b49aa241891fff  LINESTRING (-103.51002 20.45754, -103.50987 20...
# 2  8b49aa241891fff  LINESTRING (-103.50967 20.45789, -103.50987 20...
#
#             u           v  ndvi_mean  ndvi_mean_mean
# 0  4303977502  4303977514   0.195943        0.206181
# 1  4303977499  4303977502   0.195943        0.228514
# 2  4303977500  4303977502   0.195943        0.218842
