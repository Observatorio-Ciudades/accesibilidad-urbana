# %%
import os
import sys

import pandas as pd
import geopandas as gpd
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import colors
import seaborn as sns

from pandas.api.types import CategoricalDtype

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

module_path = os.path.abspath(os.path.join('../../../'))
if module_path not in sys.path:
    sys.path.append(module_path)
    import aup
# Out:
# /usr/local/python/lib/python3.10/site-packages/osmnx/utils.py:192: UserWarning: The `utils.config` function is deprecated and will be removed in a future release. Instead, use the `settings` module directly to configure a global setting's value. For example, `ox.settings.log_console=True`.
#   warnings.warn(

# %%
# Analysis name
index_analysis = 'ndwi'

# Analysed raster data from local directory:
tmp_dir = f'../../../data/processed/tmp_{index_analysis}/'

# %%
#Load data
city = 'presa_cerroprieto'
r = 12
dam_complete_dataset = pd.read_csv(tmp_dir+'local_save/'+f'{city}_{index_analysis}_HexRes{r}_.csv')
dam_complete_dataset = dam_complete_dataset.drop(columns=['Unnamed: 0'])
dam_complete_dataset
# Out:
#                    hex_id  res      ndwi  month  year               city
# 0         8c48b5a969101ff   12  0.881836      1  2016  presa_cerroprieto
# 1         8c48b5ab67601ff   12  0.845337      1  2016  presa_cerroprieto
# 2         8c48b514d6dd3ff   12  0.882107      1  2016  presa_cerroprieto
# 3         8c48b5ab66049ff   12  0.937354      1  2016  presa_cerroprieto
# 4         8c48b5ab3d669ff   12 -0.663520      1  2016  presa_cerroprieto
# ...                   ...  ...       ...    ...   ...                ...
# 11096227  8c48b5ab0729dff   12 -0.502167     12  2022  presa_cerroprieto
# 11096228  8c48b506591c9ff   12 -0.268270     12  2022  presa_cerroprieto
# 11096229  8c48b514ba4d3ff   12  0.218058     12  2022  presa_cerroprieto
# 11096230  8c48b5a9615ddff   12 -0.305176     12  2022  presa_cerroprieto
# 11096231  8c48b514dadbbff   12 -0.249851     12  2022  presa_cerroprieto
#
# [11096232 rows x 6 columns]

# %%
#Load data
city = 'presa_cerroprieto'
r = 12
new_dam_complete_dataset = pd.read_csv(tmp_dir+'local_save/'+f'{city}_{index_analysis}_HexRes{r}_v0.csv')
new_dam_complete_dataset = new_dam_complete_dataset.drop(columns=['Unnamed: 0'])
new_dam_complete_dataset
# Out:
#                    hex_id  res      ndwi  month  year               city
# 0         8c48b5149d749ff   12  0.877502      1  2016  presa_cerroprieto
# 1         8c48b5a9648c3ff   12 -0.443542      1  2016  presa_cerroprieto
# 2         8c48b5ab6a5a7ff   12 -0.586589      1  2016  presa_cerroprieto
# 3         8c48b51482a87ff   12  0.819933      1  2016  presa_cerroprieto
# 4         8c48b5a969863ff   12  0.846289      1  2016  presa_cerroprieto
# ...                   ...  ...       ...    ...   ...                ...
# 12153011  8c48b5a94cc27ff   12 -0.254978      8  2023  presa_cerroprieto
# 12153012  8c48b5a948cd3ff   12 -0.249064      8  2023  presa_cerroprieto
# 12153013  8c48b5ab0db1dff   12 -0.273895      8  2023  presa_cerroprieto
# 12153014  8c48b51495023ff   12 -0.297607      8  2023  presa_cerroprieto
# 12153015  8c48b5ab632ebff   12 -0.359701      8  2023  presa_cerroprieto
#
# [12153016 rows x 6 columns]

# %%
old_dam_year = dam_complete_dataset.loc[dam_complete_dataset.year == 2023]
new_dam_year = new_dam_complete_dataset.loc[new_dam_complete_dataset.year == 2023]

# %%
analysis_bydate = pd.DataFrame()  

for month in old_dam_year.month.unique():
    presa_gdf_month = old_dam_year.loc[(old_dam_year.month == month)]
    
    temp = presa_gdf_month.ndwi.mean()
    print(temp)

# %%
analysis_bydate = pd.DataFrame()  

for month in new_dam_year.month.unique():
    presa_gdf_month = new_dam_year.loc[(new_dam_year.month == month)]
    
    temp = presa_gdf_month.ndwi.mean()
    print(temp)
# Out:
# -0.20778881604446492
# -0.17389621923498128
# -0.17803417280438363
# -0.2869235207432175
# -0.2671491562579052
# -0.2473746672612345
# -0.22268444763630885
# -0.2105853093843328
