# %% [markdown]
# # 20250903 debug ndvi - Solved

# %% [markdown]
# Notebook used to debug NDVI, since after the fixes made to temperature (available_datasets()), running using sentinel satellite is not working.
#
# __Identified issue:__ Was using sentinel with band 'nir08' (common name used in landsat) instead of 'nir' (common name used in sentinel).

# %% [markdown]
# ## __Import libraries__

# %%
from pathlib import Path
current_path = Path().resolve()
for parent in current_path.parents:
    if parent.name == "accesibilidad-urbana":
        project_root = parent
        break
print(project_root)
# Out:
# /home/observatorio/Documents/repos/accesibilidad-urbana

# %%
import os
import sys

import pandas as pd
import geopandas as gpd
import osmnx as ox
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

module_path = os.path.abspath(os.path.join('../../'))
if module_path not in sys.path:
    sys.path.append(module_path)
    import aup

# %% [markdown]
# ## __From Script 19: Config notebook__

# %%
city = 'Culiacan'

# %%
band_name_dict = {'nir08':[False], #If GSD(resolution) of band is different, set True.
                  'red':[False], #If GSD(resolution) of band is different, set True.
                  'eq':['(nir08-red)/(nir08+red)']}
sat_query = {"eo:cloud_cover": {"lt": 10}}
index_analysis = 'ndvi'
tmp_dir = str(module_path)+f'/data/processed/tmp_{index_analysis}/'
res = [8,11]
freq = 'MS'
start_date = '2018-01-01'
end_date = '2023-12-31'
satellite = "sentinel-2-l2a"
save = True  # True
del_data = False # True

print(tmp_dir)
# Out:
# /home/observatorio/Documents/repos/accesibilidad-urbana/notebooks/data/processed/tmp_ndvi/

# %% [markdown]
# ## __From Script 19: Main function__

# %% [markdown]
# ### __Main function__ - Create hex_city

# %%
###############################
### Create city area of interest with biggest hexs
big_res = min(res)
schema_hex = 'hexgrid'
table_hex = f'hexgrid_{big_res}_city_2020'

# Download hexagons with type=urban
type = 'urban'
query = f"SELECT hex_id_{big_res},geometry FROM {schema_hex}.{table_hex} WHERE \"city\" = '{city}\' AND \"type\" = '{type}\'"
hex_urban = aup.gdf_from_query(query, geometry_col='geometry')

# Download hexagons with type=rural within 500m buffer
poly = hex_urban.to_crs("EPSG:6372").buffer(500).reset_index()
poly = poly.to_crs("EPSG:4326")
poly_wkt = poly.dissolve().geometry.to_wkt()[0]
type = 'rural'
query = f"SELECT hex_id_{big_res},geometry FROM {schema_hex}.{table_hex} WHERE \"city\" = '{city}\' AND \"type\" = '{type}\' AND (ST_Intersects(geometry, \'SRID=4326;{poly_wkt}\'))"
hex_rural = aup.gdf_from_query(query, geometry_col='geometry')

# Concatenate urban and rural hex
hex_city = pd.concat([hex_urban, hex_rural])

# Show
print(f'Downloaded {len(hex_city)} hexagon features')
print(hex_city.shape)
print(hex_city.crs)
hex_city.head(2)
# Out:
# Downloaded 490 hexagon features
# (490, 2)
# EPSG:4326
#           hex_id_8                                           geometry
# 0  88480285a1fffff  POLYGON ((-107.35366 24.75914, -107.34904 24.7...
# 1  884802b86dfffff  POLYGON ((-107.36458 24.83744, -107.35997 24.8...

# %% [markdown]
# ### __a - Try whole download_raster_from_pc() function__

# %%
df_len = aup.download_raster_from_pc(hex_city, index_analysis, city, freq,
                                     start_date, end_date, tmp_dir, band_name_dict, 
                                     query=sat_query, satellite=satellite,
                                     compute_unavailable_dates=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_len = aup.download_raster_from_pc(hex_city, index_analysis, city, freq,
#       2                                      start_date, end_date, tmp_dir, band_name_dict,
#       3                                      query=sat_query, satellite=satellite,
#       4                                      compute_unavailable_dates=True)
#
# File ~/Documents/repos/accesibilidad-urbana/aup/raster.py:144, in download_raster_from_pc(gdf, index_analysis, city, freq, start_date, end_date, tmp_dir, band_name_dict, query, satellite, projection_crs, compute_unavailable_dates)
#     140 # log(f"{len(date_list)} dates available with avg {round(df_clouds['avg_cloud'].mean(),2)}% clouds.")
#     141
#     142 # Create dictionary from links (assets_hrefs is a dict. of dates and links with structure {available_date:{band_n:[link]}})
#     143 band_name_list = list(band_name_dict.keys())[:-1]
# --> 144 assets_hrefs = link_dict(band_name_list, items, date_list)
#     145 log('Created dictionary from items')
#     147 # Analyze available data according to raster properties (Creates df_len for the first time)
#
# File ~/Documents/repos/accesibilidad-urbana/aup/raster.py:316, in link_dict(band_name_list, items, date_list)
#     314         for b in band_name_list:
#     315             assets_hrefs[i.datetime.date()].update({b:[]})
# --> 316             assets_hrefs[i.datetime.date()][b].append(pc.sign(find_asset_by_band_common_name(i,b).href))
#     318 return assets_hrefs
#
# File ~/Documents/repos/accesibilidad-urbana/aup/raster.py:286, in find_asset_by_band_common_name(item, common_name)
#     284     if asset_bands and asset_bands[0].common_name == common_name:
#     285         return asset
# --> 286 raise KeyError(f"{common_name} band not found")
#
# KeyError: 'nir08 band not found'

# %% [markdown]
# ### __b - download_raster_from_pc() Step by step debug__

# %%
# Rename variables for argument compatibility inside download_raster_from_pc function
gdf = hex_city.copy()
query = sat_query.copy()
projection_crs = "EPSG:6372"
compute_unavailable_dates = True

# %%
# Create area of interest coordinates from hexagons to download raster data
print('Extracting bounding coordinates from hexagons')
# Create buffer around hexagons
poly = gdf.to_crs(projection_crs).buffer(500)
poly = poly.to_crs("EPSG:4326")
poly = gpd.GeoDataFrame(geometry=poly).dissolve().geometry
# Extract coordinates from polygon as DataFrame
coord_val = poly.bounds
# Get coordinates for bounding box
n = coord_val.maxy.max()
s = coord_val.miny.min()
e = coord_val.maxx.max()
w = coord_val.minx.min()

# Set the coordinates for the area of interest
area_of_interest = {
    "type": "Polygon",
    "coordinates": [
        [
            [e, s],
            [w, s],
            [w, n],
            [e, n],
            [e, s],
        ]
    ],
}
area_of_interest
# Out:
# Extracting bounding coordinates from hexagons
# {'type': 'Polygon',
#  'coordinates': [[[np.float64(-107.1869514428522),
#     np.float64(24.290122506007737)],
#    [np.float64(-107.66177810594223), np.float64(24.290122506007737)],
#    [np.float64(-107.66177810594223), np.float64(24.9447728471052)],
#    [np.float64(-107.1869514428522), np.float64(24.9447728471052)],
#    [np.float64(-107.1869514428522), np.float64(24.290122506007737)]]]}

# %%
# Create time of interest (Creates a list for all to-be-analysed-months with structure [start_day/end_day,(...)])
print('Defining time of interest')
time_of_interest = aup.create_time_of_interest(start_date, end_date, freq=freq)
time_of_interest
# Out:
# Defining time of interest
# ['2018-01-01/2018-01-31',
#  '2018-02-01/2018-02-28',
#  '2018-03-01/2018-03-31',
#  '2018-04-01/2018-04-30',
#  '2018-05-01/2018-05-31',
#  '2018-06-01/2018-06-30',
#  '2018-07-01/2018-07-31',
#  '2018-08-01/2018-08-31',
#  '2018-09-01/2018-09-30',
#  '2018-10-01/2018-10-31',
#  '2018-11-01/2018-11-30',
#  '2018-12-01/2018-12-31',
#  '2019-01-01/2019-01-31',
#  '2019-02-01/2019-02-28',
#  '2019-03-01/2019-03-31',
#  '2019-04-01/2019-04-30',
#  '2019-05-01/2019-05-31',
#  '2019-06-01/2019-06-30',
#  '2019-07-01/2019-07-31',
#  '2019-08-01/2019-08-31',
#  '2019-09-01/2019-09-30',
#  '2019-10-01/2019-10-31',
#  '2019-11-01/2019-11-30',
#  '2019-12-01/2019-12-31',
#  '2020-01-01/2020-01-31',
#  '2020-02-01/2020-02-29',
#  '2020-03-01/2020-03-31',
#  '2020-04-01/2020-04-30',
#  '2020-05-01/2020-05-31',
#  '2020-06-01/2020-06-30',
#  '2020-07-01/2020-07-31',
#  '2020-08-01/2020-08-31',
#  '2020-09-01/2020-09-30',
#  '2020-10-01/2020-10-31',
#  '2020-11-01/2020-11-30',
#  '2020-12-01/2020-12-31',
#  '2021-01-01/2021-01-31',
#  '2021-02-01/2021-02-28',
#  '2021-03-01/2021-03-31',
#  '2021-04-01/2021-04-30',
#  '2021-05-01/2021-05-31',
#  '2021-06-01/2021-06-30',
#  '2021-07-01/2021-07-31',
#  '2021-08-01/2021-08-31',
#  '2021-09-01/2021-09-30',
#  '2021-10-01/2021-10-31',
#  '2021-11-01/2021-11-30',
#  '2021-12-01/2021-12-31',
#  '2022-01-01/2022-01-31',
#  '2022-02-01/2022-02-28',
#  '2022-03-01/2022-03-31',
#  '2022-04-01/2022-04-30',
#  '2022-05-01/2022-05-31',
#  '2022-06-01/2022-06-30',
#  '2022-07-01/2022-07-31',
#  '2022-08-01/2022-08-31',
#  '2022-09-01/2022-09-30',
#  '2022-10-01/2022-10-31',
#  '2022-11-01/2022-11-30',
#  '2022-12-01/2022-12-31',
#  '2023-01-01/2023-01-31',
#  '2023-02-01/2023-02-28',
#  '2023-03-01/2023-03-31',
#  '2023-04-01/2023-04-30',
#  '2023-05-01/2023-05-31',
#  '2023-06-01/2023-06-30',
#  '2023-07-01/2023-07-31',
#  '2023-08-01/2023-08-31',
#  '2023-09-01/2023-09-30',
#  '2023-10-01/2023-10-31',
#  '2023-11-01/2023-11-30',
#  '2023-12-01/2023-12-31']

# %%
# Gather items for time and area of interest (Creates of list of available image items)
print('Gathering items for time and area of interest')
items = aup.gather_items(time_of_interest, area_of_interest, query=query, satellite=satellite)
print(f'Fetched {len(items)} items')
items
# Out:
# Gathering items for time and area of interest
# Fetched 750 items
# [<Item id=S2B_MSIL2A_20180129T174559_R098_T13RBH_20201014T095806>,
#  <Item id=S2B_MSIL2A_20180129T174559_R098_T13QBG_20201014T095800>,
#  <Item id=S2A_MSIL2A_20231204T174711_R098_T13QBG_20241107T131635>,
#  <Item id=S2A_MSIL2A_20231204T174711_R098_T13QBG_20231205T021539>,
#  <Item id=S2A_MSIL2A_20231204T174711_R098_T12RZN_20241107T131635>,
#  <Item id=S2A_MSIL2A_20231204T174711_R098_T12RZN_20231205T021544>,
#  <Item id=S2A_MSIL2A_20231204T174711_R098_T12QZM_20241107T131635>,
#  <Item id=S2A_MSIL2A_20231204T174711_R098_T12QZM_20231205T021540>]

# %%
# Count available tiles for area of interest (Creates a list of available tiles, inside create_raster_by_month() logs available tiles per date vs total of area of interest)
aoi_tiles = []
for i in items:
    # Retrieve current tile
    if satellite == "sentinel-2-l2a":
        tile = i.properties['s2:mgrs_tile']
    elif satellite == "landsat-c2-l2":
        tile = i.properties['landsat:wrs_path']+i.properties['landsat:wrs_row']
    # Append if first find
    if tile not in aoi_tiles:
        aoi_tiles.append(tile)
print(f'Area of interest composed of {len(aoi_tiles)} tile: {aoi_tiles}.')
# Out:
# Area of interest composed of 4 tile: ['13RBH', '13QBG', '12RZN', '12QZM'].

# %%
print('Checking available tiles for area of interest')
# df_clouds, date_list = arrange_items(items, satellite=satellite)
date_list = aup.available_datasets(items, satellite, query)
# log(f"{len(date_list)} dates available with avg {round(df_clouds['avg_cloud'].mean(),2)}% clouds.")
date_list
# Out:
# Checking available tiles for area of interest
# [datetime.date(2023, 1, 8),
#  datetime.date(2023, 1, 13),
#  datetime.date(2022, 3, 19),
#  datetime.date(2022, 2, 7),
#  datetime.date(2022, 2, 22),
#  datetime.date(2022, 12, 24),
#  datetime.date(2023, 12, 29),
#  datetime.date(2023, 12, 9),
#  datetime.date(2023, 12, 14),
#  datetime.date(2022, 11, 29),
#  datetime.date(2023, 12, 4),
#  datetime.date(2022, 10, 20),
#  datetime.date(2022, 10, 10),
#  datetime.date(2023, 4, 28),
#  datetime.date(2023, 1, 18),
#  datetime.date(2022, 2, 27),
#  datetime.date(2023, 2, 27),
#  datetime.date(2022, 4, 28),
#  datetime.date(2023, 3, 4),
#  datetime.date(2022, 5, 28),
#  datetime.date(2022, 4, 13),
#  datetime.date(2023, 4, 8),
#  datetime.date(2023, 4, 23),
#  datetime.date(2022, 12, 14),
#  datetime.date(2023, 3, 19),
#  datetime.date(2023, 5, 13),
#  datetime.date(2022, 5, 3),
#  datetime.date(2021, 12, 4),
#  datetime.date(2023, 6, 27),
#  datetime.date(2018, 12, 10),
#  datetime.date(2019, 3, 10),
#  datetime.date(2022, 12, 19),
#  datetime.date(2022, 3, 9),
#  datetime.date(2023, 6, 12),
#  datetime.date(2021, 11, 4),
#  datetime.date(2019, 12, 25),
#  datetime.date(2022, 11, 24),
#  datetime.date(2020, 1, 4),
#  datetime.date(2020, 10, 30),
#  datetime.date(2022, 6, 17),
#  datetime.date(2023, 5, 28),
#  datetime.date(2019, 4, 19),
#  datetime.date(2019, 3, 20),
#  datetime.date(2018, 3, 30),
#  datetime.date(2022, 5, 13),
#  datetime.date(2021, 12, 24),
#  datetime.date(2020, 4, 3),
#  datetime.date(2020, 2, 18),
#  datetime.date(2023, 5, 8),
#  datetime.date(2023, 8, 6),
#  datetime.date(2018, 12, 20),
#  datetime.date(2021, 3, 19),
#  datetime.date(2021, 1, 28),
#  datetime.date(2018, 3, 5),
#  datetime.date(2018, 4, 19),
#  datetime.date(2018, 1, 29),
#  datetime.date(2020, 4, 13),
#  datetime.date(2020, 4, 23),
#  datetime.date(2020, 2, 13),
#  datetime.date(2021, 1, 18),
#  datetime.date(2018, 4, 14),
#  datetime.date(2023, 2, 2),
#  datetime.date(2018, 3, 20),
#  datetime.date(2023, 4, 18),
#  datetime.date(2020, 11, 19),
#  datetime.date(2019, 4, 9),
#  datetime.date(2018, 4, 9),
#  datetime.date(2020, 11, 29),
#  datetime.date(2019, 4, 24),
#  datetime.date(2019, 4, 14),
#  datetime.date(2019, 2, 28),
#  datetime.date(2019, 4, 29),
#  datetime.date(2021, 3, 24),
#  datetime.date(2019, 1, 24),
#  datetime.date(2019, 3, 25),
#  datetime.date(2023, 10, 30),
#  datetime.date(2019, 6, 28),
#  datetime.date(2021, 4, 13),
#  datetime.date(2021, 2, 12),
#  datetime.date(2021, 11, 14),
#  datetime.date(2021, 11, 29),
#  datetime.date(2018, 5, 9),
#  datetime.date(2018, 11, 15),
#  datetime.date(2023, 5, 18),
#  datetime.date(2020, 3, 24),
#  datetime.date(2021, 11, 19),
#  datetime.date(2021, 2, 22),
#  datetime.date(2021, 5, 28),
#  datetime.date(2020, 12, 14),
#  datetime.date(2019, 11, 15),
#  datetime.date(2021, 4, 18),
#  datetime.date(2019, 1, 19),
#  datetime.date(2021, 5, 8),
#  datetime.date(2019, 12, 20),
#  datetime.date(2021, 5, 3),
#  datetime.date(2019, 5, 9),
#  datetime.date(2022, 1, 3),
#  datetime.date(2021, 6, 17),
#  datetime.date(2021, 6, 7),
#  datetime.date(2020, 1, 29),
#  datetime.date(2019, 6, 18),
#  datetime.date(2018, 5, 19),
#  datetime.date(2022, 5, 23),
#  datetime.date(2018, 5, 24),
#  datetime.date(2019, 5, 29),
#  datetime.date(2020, 5, 13),
#  datetime.date(2020, 10, 15),
#  datetime.date(2022, 4, 23),
#  datetime.date(2020, 11, 14),
#  datetime.date(2022, 3, 4),
#  datetime.date(2022, 6, 22),
#  datetime.date(2021, 10, 5),
#  datetime.date(2020, 4, 28),
#  datetime.date(2019, 5, 19),
#  datetime.date(2020, 6, 22),
#  datetime.date(2020, 3, 4),
#  datetime.date(2021, 4, 8),
#  datetime.date(2018, 11, 5),
#  datetime.date(2021, 3, 14),
#  datetime.date(2021, 5, 18),
#  datetime.date(2020, 5, 8),
#  datetime.date(2018, 8, 2),
#  datetime.date(2019, 5, 24),
#  datetime.date(2020, 6, 17),
#  datetime.date(2020, 5, 18),
#  datetime.date(2021, 5, 23),
#  datetime.date(2020, 4, 18),
#  datetime.date(2021, 5, 13),
#  datetime.date(2019, 6, 23),
#  datetime.date(2021, 11, 24),
#  datetime.date(2018, 11, 30),
#  datetime.date(2019, 11, 30),
#  datetime.date(2023, 10, 15),
#  datetime.date(2020, 9, 5),
#  datetime.date(2018, 5, 14),
#  datetime.date(2020, 11, 24),
#  datetime.date(2019, 10, 26),
#  datetime.date(2021, 12, 9),
#  datetime.date(2020, 3, 14),
#  datetime.date(2023, 3, 14),
#  datetime.date(2022, 10, 25),
#  datetime.date(2022, 10, 30),
#  datetime.date(2023, 1, 3),
#  datetime.date(2020, 12, 19),
#  datetime.date(2019, 6, 13),
#  datetime.date(2020, 10, 25),
#  datetime.date(2022, 12, 9),
#  datetime.date(2021, 10, 20),
#  datetime.date(2020, 8, 1),
#  datetime.date(2022, 2, 17),
#  datetime.date(2021, 10, 15),
#  datetime.date(2021, 6, 2),
#  datetime.date(2019, 12, 10),
#  datetime.date(2022, 10, 5),
#  datetime.date(2022, 9, 30),
#  datetime.date(2019, 10, 1),
#  datetime.date(2018, 9, 16),
#  datetime.date(2022, 3, 24),
#  datetime.date(2023, 12, 19),
#  datetime.date(2019, 10, 6),
#  datetime.date(2022, 11, 14),
#  datetime.date(2022, 9, 15),
#  datetime.date(2022, 4, 18),
#  datetime.date(2018, 1, 14),
#  datetime.date(2023, 8, 16),
#  datetime.date(2019, 12, 30),
#  datetime.date(2021, 9, 30),
#  datetime.date(2023, 8, 11),
#  datetime.date(2019, 8, 2),
#  datetime.date(2020, 9, 30),
#  datetime.date(2023, 11, 19),
#  datetime.date(2021, 10, 25),
#  datetime.date(2018, 7, 18),
#  datetime.date(2018, 7, 3),
#  datetime.date(2019, 9, 6),
#  datetime.date(2022, 9, 25),
#  datetime.date(2020, 7, 22),
#  datetime.date(2020, 12, 29),
#  datetime.date(2021, 8, 1),
#  datetime.date(2020, 9, 25),
#  datetime.date(2021, 1, 8),
#  datetime.date(2023, 2, 22),
#  datetime.date(2020, 10, 5),
#  datetime.date(2018, 5, 29),
#  datetime.date(2021, 10, 10),
#  datetime.date(2019, 10, 11),
#  datetime.date(2023, 9, 15),
#  datetime.date(2023, 7, 7),
#  datetime.date(2023, 6, 7),
#  datetime.date(2020, 9, 15),
#  datetime.date(2023, 9, 20),
#  datetime.date(2019, 9, 11),
#  datetime.date(2022, 1, 8),
#  datetime.date(2021, 8, 21),
#  datetime.date(2019, 10, 16),
#  datetime.date(2018, 1, 19),
#  datetime.date(2020, 12, 4),
#  datetime.date(2020, 9, 10),
#  datetime.date(2019, 7, 28),
#  datetime.date(2019, 10, 21),
#  datetime.date(2023, 10, 25),
#  datetime.date(2018, 6, 28),
#  datetime.date(2023, 9, 30),
#  datetime.date(2019, 12, 15),
#  datetime.date(2023, 7, 12),
#  datetime.date(2020, 8, 26),
#  datetime.date(2019, 1, 9),
#  datetime.date(2020, 10, 20),
#  datetime.date(2018, 7, 13),
#  datetime.date(2021, 9, 25),
#  datetime.date(2018, 10, 26),
#  datetime.date(2022, 9, 10),
#  datetime.date(2023, 9, 10),
#  datetime.date(2021, 10, 30),
#  datetime.date(2020, 10, 10),
#  datetime.date(2020, 6, 2),
#  datetime.date(2019, 9, 26),
#  datetime.date(2021, 7, 22),
#  datetime.date(2019, 9, 16),
#  datetime.date(2020, 11, 9)]

# %%
# Create dictionary from links (assets_hrefs is a dict. of dates and links with structure {available_date:{band_n:[link]}})
band_name_list = list(band_name_dict.keys())[:-1]
assets_hrefs = aup.link_dict(band_name_list, items, date_list)
print('Created dictionary from items')
assets_hrefs
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 3
#       1 # Create dictionary from links (assets_hrefs is a dict. of dates and links with structure {available_date:{band_n:[link]}})
#       2 band_name_list = list(band_name_dict.keys())[:-1]
# ----> 3 assets_hrefs = aup.link_dict(band_name_list, items, date_list)
#       4 print('Created dictionary from items')
#       5 assets_hrefs
#
# File ~/Documents/repos/accesibilidad-urbana/aup/raster.py:316, in link_dict(band_name_list, items, date_list)
#     314         for b in band_name_list:
#     315             assets_hrefs[i.datetime.date()].update({b:[]})
# --> 316             assets_hrefs[i.datetime.date()][b].append(pc.sign(find_asset_by_band_common_name(i,b).href))
#     318 return assets_hrefs
#
# File ~/Documents/repos/accesibilidad-urbana/aup/raster.py:286, in find_asset_by_band_common_name(item, common_name)
#     284     if asset_bands and asset_bands[0].common_name == common_name:
#     285         return asset
# --> 286 raise KeyError(f"{common_name} band not found")
#
# KeyError: 'nir08 band not found'

# %% [markdown]
# #### __b-01 - link_dict() Step by step debug__

# %%
import planetary_computer as pc

# %%
assets_hrefs = {}

for i in items:
    # only takes into account dates that are in the date list
    if i.datetime.date() not in date_list:
        continue
    # if date already in dictionary, append link to list
    if i.datetime.date() in list(assets_hrefs.keys()):
        for b in band_name_list:
            assets_hrefs[i.datetime.date()][b].append(pc.sign(aup.find_asset_by_band_common_name(i,b).href))
    # if date not in dictionary, create new dictionary entry
    else:
        assets_hrefs[i.datetime.date()] = {}
        for b in band_name_list:
            assets_hrefs[i.datetime.date()].update({b:[]})
            assets_hrefs[i.datetime.date()][b].append(pc.sign(aup.find_asset_by_band_common_name(i,b).href))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 16
#      14 for b in band_name_list:
#      15     assets_hrefs[i.datetime.date()].update({b:[]})
# ---> 16     assets_hrefs[i.datetime.date()][b].append(pc.sign(aup.find_asset_by_band_common_name(i,b).href))
#
# File ~/Documents/repos/accesibilidad-urbana/aup/raster.py:286, in find_asset_by_band_common_name(item, common_name)
#     284     if asset_bands and asset_bands[0].common_name == common_name:
#     285         return asset
# --> 286 raise KeyError(f"{common_name} band not found")
#
# KeyError: 'nir08 band not found'

# %% [markdown]
# ##### __b-02 - find_asset_by_band_common_name() Step by step debug__

# %%
from pystac.extensions.eo import EOExtension as eo

# %%
i
# Out:
# <Item id=S2B_MSIL2A_20180129T174559_R098_T13RBH_20201014T095806>

# %%
common_name = 'nir'
for asset in i.assets.values():
        asset_bands = eo.ext(asset).bands
        if asset_bands and asset_bands[0].common_name == common_name:
            print(asset)
# Out:
# <Asset href=https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/13/R/BH/2018/01/29/S2B_MSIL2A_20180129T174559_N0212_R098_T13RBH_20201014T095806.SAFE/GRANULE/L2A_T13RBH_A004700_20180129T174553/IMG_DATA/R10m/T13RBH_20180129T174559_B08_10m.tif>
